# %% [markdown]
# # 2D Poisson's ratio deterministic adjoint-based inversion: role of number of observations
#
# This notebook contains several deterministic adjoint-based inversion of the surface geodetic data for the heterogeneous Poisson's ratio structure, assuming the knowledge of the fault slip distribution, as a function of the number of surface gedetic stations.

# %%
# Load libraries
import dolfin as dl
import ufl
import pandas as pd
import math
import numpy as np
# Load libraries for plotting
import matplotlib.pyplot as plt
from cmcrameri import cm
import matplotlib.tri as tri
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
from matplotlib.patches import Rectangle, Polygon
import matplotlib.patches as patches
import matplotlib as mpl
from matplotlib.collections import LineCollection
from matplotlib import rc
rc('text', usetex=True)
rc('font', family='serif', size=16)
rc('legend', fontsize=16)
TINY_SIZE = 14
SMALL_SIZE = 20
MEDIUM_SIZE = 30
BIGGER_SIZE = 40
plt.rc('font', size=SMALL_SIZE)
plt.rc('axes', titlesize=SMALL_SIZE)
plt.rc('axes', labelsize=SMALL_SIZE)
plt.rc('xtick', labelsize=SMALL_SIZE)
plt.rc('ytick', labelsize=SMALL_SIZE)
plt.rc('legend', fontsize=SMALL_SIZE)
plt.rc('figure', titlesize=BIGGER_SIZE)

import sys, os
#sys.path.append( os.environ.get('HIPPYLIB_BASE_DIR', "...") )
import hippylib as hp
# Load TV regularization class and observation operator
from pointwiseStateObs import PointwiseStateObservation
from TVprior import *

# Make results reproducible
np.random.seed(seed=1)

# Set parameters compiler
dl.parameters["form_compiler"]["quadrature_degree"] = 5
dl.parameters["form_compiler"]["optimize"] = True
# Mute FFC and UFL warnings
import logging
logging.getLogger('FFC').setLevel(logging.WARNING)
logging.getLogger('UFL').setLevel(logging.WARNING)
dl.set_log_active(False)

# %%
# Define functions
# Define the compliance matrix for elasticity
def AEsigma(s, mu, nu):
    A = 1./(2.*mu)*( s - nu/( 1 + nu*(dim-2) )*ufl.tr(s)*ufl.Identity(dim) )
    return A

# Define the asymmetry operator
def asym(s): 
    as_ = s[0,1] - s[1,0]
    return as_

# Define the tangent operator
def T(n):
    T_operator = ufl.as_vector( [n[1], -n[0]] )
    return T_operator

# Class to define different properties in the subdomains with anomaly built-in
class K_Triangle(dl.UserExpression):
    def __init__(self, subdomains, k_0, k_1, **kwargs):
        super().__init__(**kwargs)
        self.subdomains = subdomains
        self.k_0 = k_0
        self.k_1 = k_1

    def eval_cell(self, values, x, cell):
        if self.subdomains[cell.index] == triangle_surface:
            values[0] = self.k_0
        else:
            values[0] = self.k_1

    def value_shape(self):
        return ()

# %%
# Mesh
path = "../Mesh/"
name = "Mesh_CurvedFault_Triangle_PaperII"
mesh = dl.Mesh(path + name + '.xml')
xmin = -700.; xmax = 400.; ymin = -500.; ymax = 0.
# Extract dimension of the mesh
dim = mesh.topology().dim()
# Define normal component to boundaries
n = dl.FacetNormal(mesh)
# Define boundaries
boundaries = dl.MeshFunction("size_t", mesh, path + name + '_facet_region.xml')
subdomains = dl.MeshFunction("size_t", mesh, path + name + '_physical_region.xml')
top = 1
left = 2
bottom = 3
right = 4
fault = 5
blockleft = 7
blockright = 8
triangle = 9
triangle_surface = 10
ds = dl.Measure('ds')(domain=mesh, subdomain_data=boundaries)
dS = dl.Measure('dS')(domain=mesh, subdomain_data=boundaries)

# Define sep
sep = "\n"+"#"*80+"\n"

# %%
# Create function to interpolate in a region of interest (small portion of the domain)
def get_dx_for_error_evaluation(mesh, xmin, xmax, ymin, ymax):
    class LimitedDomain(dl.SubDomain):
        def inside(self, x, on_boundary):
            x_range = dl.between(x[0], (xmin, xmax))
            y_range = dl.between(x[1], (ymin, ymax))
            return x_range and y_range
    
    # Marker the subdomain
    marker_errors = dl.MeshFunction("size_t", mesh, dim)
    aroundFaultEdges = LimitedDomain()
    marker_errors.set_all(20)
    aroundFaultEdges.mark(marker_errors, 21)
    my_dx = dl.Measure("dx", domain=mesh, subdomain_data=marker_errors)
    
    return my_dx(21)

# %%
# The linear coseismic inversion problem
# Define the weak formulation of the FORWARD problem
def pde_varf(u, m, p):
    # Split the STATE and ADJOINT variables. Use dl.split() and not
    # .split(deepcopy=True), since the latter breaks FEniCS symbolic differentiation
    sigma, uu, r = dl.split(u)
    tau, w, q = dl.split(p)
    u0 = dl.Constant((0., 0.))
    # Define the weak formulation of the forward problem
    nu_expr = 0.25*(1. + ufl.tanh(m))
    J = ufl.inner( AEsigma(sigma, mu, nu_expr), tau )*ufl.dx \
        + ufl.inner( ufl.div(tau), uu )*ufl.dx \
        + ufl.inner( asym(tau), r )*ufl.dx \
        + ufl.inner( ufl.div(sigma), w )*ufl.dx + ufl.inner( asym(sigma), q )*ufl.dx \
        + ufl.inner( f, w )*ufl.dx \
        - ufl.inner( u0, tau*n )*ds(bottom) \
        - ufl.inner( ufl.avg(slip), ufl.dot(  T(n('+')), tau('+')*n('+') ) )*dS(fault)
    return J

# %%
# Create a function the solve the Poisson's ratio deterministic adjoint-based inversion
def solveInverseProblem(k, targets, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps, verbose=True):
    
    # Define function spaces
    # Use VectorFunctionSpace if the unknown is a vector field.
    # Use FunctionSpace object for scalar fields.
    BDM = dl.VectorFunctionSpace(mesh, "BDM", k)    # stress (tensor field, since BDM is a vector field)
    DGv = dl.VectorFunctionSpace(mesh, "DG", k-1)   # displacement (vector field)
    DGr = dl.FunctionSpace(mesh, "DG", k-1)         # rotation (scalar field)
    ME_element = dl.MixedElement([BDM.ufl_element(), DGv.ufl_element(), DGr.ufl_element()])
    Vu = dl.FunctionSpace(mesh, ME_element)
    n = dl.FacetNormal(mesh)
    # Define function space for the model parameter (scalar), which is continuous
    Vm = dl.FunctionSpace(mesh, "CG", 1)
    # Combine the STATE, PARAMETER and ADJOINT function spaces
    Vh = [Vu, Vm, Vu]
    # Print the dofs of STATE, PARAMETER and ADJOINT variables
    ndofs = [ Vh[hp.STATE].dim(), Vh[hp.PARAMETER].dim(), Vh[hp.ADJOINT].dim() ]
    ndofs_state = [ Vu.sub(0).dim(), Vu.sub(1).dim(), Vu.sub(2).dim() ]
    if verbose:
        print( sep, "Set up the mesh and finite element spaces", sep )
        print( "Number of dofs: STATE={0}, PARAMETER={1}, ADJOINT={2}".format(*ndofs) )
        print( "Number of STATE and ADJOINT dofs: STRESS={0}, DISPLACEMENT={1}, ROTATION={2}".format(*ndofs_state) )

    # Define the STATE and ADJOINT Dirichlet BCs
    zero_tensor = dl.Expression( (("0.", "0."), ("0.", "0.")), degree=5 )
    bc = dl.DirichletBC(Vh[hp.STATE].sub(0), zero_tensor, boundaries, top)
    bc0 = dl.DirichletBC(Vh[hp.STATE].sub(0), zero_tensor, boundaries, top)

    # Define the PDE problem
    pde = hp.PDEVariationalProblem(Vh, pde_varf, bc, bc0, is_fwd_linear=True)

    # Print the number of observations (observed surface horizontal and vertical displacements)
    if verbose:
        print( "Number of observation points: {0}".format(targets.shape[0]) )
    # Define the Misfit function to calculate the data misfit
    misfit = PointwiseStateObservation(Vh[hp.STATE], targets, indicator_vec=dl.interpolate(dl.Constant((0,0,0,0,1,1,0)), Vh[hp.STATE]).vector())
    # Define the regularization component
    reg_handler = vectorTVH1L2handler(gamma_val_TV, gamma_val_H1, delta_val_L2, eps=eps)
    reg = NonGaussian_Prior(Vh[hp.PARAMETER], reg_handler)
    
    # Define the true model PARAMETER
    mtrue = dl.interpolate(mtrue_expr, Vh[hp.PARAMETER]).vector()
    # Define the starting model (initial guess) 'm_0'
    m0 = dl.interpolate(m0_expr, Vh[hp.PARAMETER]).vector()
    # Define slip
    slip_int = dl.interpolate(slip, Vh[hp.PARAMETER]).vector()

    # Solve FORWARD problem for the STATE variables & generate synthetic observations
    utrue = pde.generate_state() # all dofs STATE variables and PETSC vector (not FEniCS Function)
    x = [utrue, mtrue, None]
    pde.solveFwd(x[hp.STATE], x)
    # Generate true observations by using the observation operator 'B'
    misfit.B.mult(x[hp.STATE], misfit.d)
        
    # Pollute true observations with random noise and generate synthetic data
    MAX = misfit.d.norm("linf") 
    hp.Random().normal_perturb(noise_std_dev, misfit.d) # Comment if no data noise
    misfit.noise_variance = noise_std_dev*noise_std_dev
    print( "The MAX displacement (m) is: %.4f and standard deviation of the noise (m) is: %.6f" %(MAX, noise_std_dev) )
    print( "Noise variance = {0}".format(noise_std_dev*noise_std_dev) )

    # Extract x,y coordinates of the fault for plotting
    bc1 = dl.DirichletBC(Vm, 10, boundaries, fault)
    um = dl.Function(Vm)
    bc1.apply(um.vector())
    # Extract x,y coordinates of the fault and values
    xslip = dl.interpolate(dl.Expression("x[0]", degree=5), Vm)
    yslip = dl.interpolate(dl.Expression("x[1]", degree=5), Vm)
    xf = xslip.vector()[um.vector() == 10] # x coordinate fault
    yf = yslip.vector()[um.vector() == 10] # y coordinate fault
    slip_mag = slip_int[um.vector() == 10]
    # Sort the values
    idx = np.argsort(xf)
    xf = xf[idx]; yf = yf[idx]
    
    # Construct the "Model" --> objective function
    model = hp.Model(pde, reg, misfit)

    if verbose:
        print( sep, "Solve the deterministic inverse problem", sep)
    m = reg.mean.copy()
    parameters = hp.ReducedSpaceNewtonCG_ParameterList()
    parameters["rel_tolerance"] = 1e-12 
    parameters["abs_tolerance"] = 1e-9  
    parameters["max_iter"]      = 100   
    parameters["globalization"] = "LS"
    parameters["LS"]["c_armijo"] = 1e-5 
    parameters["GN_iter"] = 5
    if verbose == False:
        parameters["print_level"] = -1

    if verbose:
        parameters.showMe()
    solver = hp.ReducedSpaceNewtonCG(model, parameters)
    # Create a vector containig the solution of the inverse problem (MAP point)
    x = solver.solve([None, m, None])
    # Print solver convergence
    if verbose:
        if solver.converged:
            print( "\nConverged in ", solver.it, " iterations.")
        else:
            print( "\nNot Converged")

        print ("Termination reason: ", solver.termination_reasons[solver.reason])
        print ("Final gradient norm: ", solver.final_grad_norm)
        print ("Final cost: ", solver.final_cost)

    # Convert from m to Poisson's ratio
    mtrue_fun = hp.vector2Function(mtrue, Vh[hp.PARAMETER])
    poisson_true = dl.project(dl.Constant(0.25)*(dl.Constant(1.) + ufl.tanh(mtrue_fun)), Vh[hp.PARAMETER] )
    m_fun = hp.vector2Function(m, Vh[hp.PARAMETER])
    poisson = dl.project(dl.Constant(0.25)*(dl.Constant(1.) + ufl.tanh(m_fun)), Vh[hp.PARAMETER] )
    # Print the range of the MAP point
    if verbose:
        print( min(poisson.vector()[:]), max(poisson.vector()[:]) )

    # Calculate relative error in the domain
    lef, rig, bot, topp = -200., 100., -150., 0.
    my_dx = get_dx_for_error_evaluation(mesh, lef, rig, bot, topp)
    # Absolute L1-norm
    #rel_error = dl.assemble( abs(poisson_true-poisson)*my_dx ) 
    # Relative L2-norm
    rel_error = dl.sqrt( dl.assemble( dl.inner(poisson_true-poisson, poisson_true-poisson)*my_dx ) / dl.assemble( dl.inner(poisson_true, poisson_true)*my_dx ) ) * 100
    if verbose:
        print( "The relative error is: %.1f per cent" %rel_error )
        
        
    # Look spectum Hessian misfit generalized eigenproblem
    model.setPointForHessianEvaluations(x, gauss_newton_approx=False)
    Hmisfit = hp.ReducedHessian(model, misfit_only=True)
    k_evec = 80
    p_evec = 20
    if verbose:
        print( "Single/Double Pass Algorithm. Requested eigenvectors: {0}; Oversampling {1}".format(k_evec, p_evec) )
    Omega = hp.MultiVector(x[hp.PARAMETER], k_evec+p_evec)
    hp.Random().normal(1., Omega)
    # Consider also the mass matrix for the generalized eigenproblem
    trial = dl.TrialFunction(Vh[hp.PARAMETER])
    test = dl.TestFunction(Vh[hp.PARAMETER])
    Mvarf = ufl.inner(trial, test)*ufl.dx
    M = dl.assemble(Mvarf, keep_diagonal=True)
    M.ident_zeros()
    M_solver = hp.PETScKrylovSolver(Vh[hp.PARAMETER].mesh().mpi_comm(), "cg", "jacobi")
    M_solver.set_operator(M) # reg.Msolver
    # Solve the eigenvalue problem: H_misfit v = lambda M_i v
    #lmbda, V = hp.doublePassG(Hmisfit, M, M_solver, Omega, k_evec)
    lmbda, V = hp.doublePass(Hmisfit, Omega, k_evec, s=1)
    lmbda_R, V_R = hp.doublePassG(Hmisfit, reg.R, reg.Rsolver, Omega, k_evec)
    
    # Calculate EIG
    posterior = hp.GaussianLRPosterior(reg, lmbda_R, V_R)
    posterior.mean = x[hp.PARAMETER]
    kl_dist = posterior.klDistanceFromPrior()
    if verbose:
        print ("KL-Distance from prior: ", kl_dist)
    
        
    return( mesh, Vh, targets, xf, yf, utrue, poisson_true, poisson, rel_error, lmbda, lmbda_R, noise_std_dev, kl_dist )

# %%
### DEFINE COMMON PARAMETERS ###
# Define order of elements (k = 1 --> linear; k = 2 --> quadratic)
k = 1
# Define body force
f = dl.Constant((0., 0.))
# Define the true model PARAMETER
mu = 30e9         # Young's modulus
nu_b = -0.2      # background Poisson's ratio
nu_background = 0.25*(1.+np.tanh(nu_b))
nu_i = 0.425     # anomaly Poisson's ratio
nu_anomaly = 0.25*(1.+np.tanh(nu_i))
print( "The Poisson's ratio for the anomaly is: nu = %.2f while the background nu = %.2f" %(nu_anomaly, nu_background) )
mtrue_expr = K_Triangle(subdomains, nu_i, nu_b, degree=0)
# Define the expression for starting model
m0_expr = dl.Constant(0.0)
# Choose the fault slip
slip = dl.Expression(('u0*exp(-(pow((x[1]-xc),2)/(pow(std,2))))'), u0=-10., xc=-20., std=15., degree=5)

# Choose data noise
noise_std_dev = 0.002
# Out:
# The Poisson's ratio for the anomaly is: nu = 0.35 while the background nu = 0.20

# %%
# Define the axes range
lef, rig, topp, bot = -200., 100., 0., -150.

# Define colormaps and level for contourf
cmap_1 = plt.get_cmap("Blues")
cmap_2 = plt.get_cmap("viridis", 21)
cmap_3 = plt.get_cmap("RdBu_r")
cmap_4 = plt.get_cmap("RdBu_r", 21)
levels_ux = np.linspace(-0.5, 0.5, 21)
levels_uy = np.linspace(-0.5, 0.5, 21)
levels_m = np.linspace(nu_background-1e-5, nu_anomaly+1e-3, 21)
colors = [ cmap_1(0.3), cmap_1(0.6), cmap_1(0.9) ]

# Create the perimeter of the triangular anomaly
xy_triangle = np.array([ [-160.0,-5.0], [-30.0,-5.0], [-95.0, -55.0] ]) 

# For labels of subplots (a,b,c,d)
props = dict(boxstyle='round', lw=0.25, facecolor='ivory', alpha=0.95)

# %%
# Generate random surface observations
ntargets_1 = 1 
targets_x1 = np.linspace(-180., 0., ntargets_1) 
targets_y1 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_1)
targets_1 = np.zeros([ntargets_1, dim])
targets_1[:,0] = targets_x1; targets_1[:,1] = targets_y1

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_1, xf, yf, utrue, mtrue, m_1, rel_error_1, lmbda_1, lmbda_R_1, noise_std_dev_1, kl_dist_1 ) = solveInverseProblem(k, targets_1, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 1
# The MAX displacement (m) is: 1.1308 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    5.547663e+01    6.126360e+00    4.935027e+01   -2.065658e+03   1.618811e+02   1.000000e+00   5.000000e-01
#   2   3    4.286755e+01    3.211077e+00    3.965648e+01   -1.997785e+01   5.721785e+00   1.000000e+00   1.880043e-01
#   3   3    4.122683e+01    3.064618e+00    3.816221e+01   -2.131290e+00   1.903412e+00   1.000000e+00   1.084347e-01
#   4   3    4.065210e+01    3.050260e+00    3.760184e+01   -6.574660e-01   9.055434e-01   1.000000e+00   7.479225e-02
#   5   3    4.036185e+01    3.045938e+00    3.731591e+01   -3.196074e-01   7.255757e-01   1.000000e+00   6.694888e-02
#   6   4    3.995805e+01    3.045445e+00    3.691260e+01   -3.609043e+00   6.227236e-01   1.250000e-01   6.202255e-02
#   7   4    3.985004e+01    3.045242e+00    3.680480e+01   -1.074207e+00   7.279296e-01   2.500000e-01   6.705739e-02
#   8   3    3.981477e+01    3.046973e+00    3.676779e+01   -1.274711e+01   1.819394e+00   6.250000e-02   1.060145e-01
#   9   3    3.973485e+01    3.045887e+00    3.668896e+01   -6.851546e-01   6.986859e-01   1.250000e-01   6.569660e-02
#  10   3    3.971864e+01    3.044681e+00    3.667395e+01   -4.120934e-01   6.126311e-01   1.250000e-01   6.151789e-02
#  11   3    3.970024e+01    3.042586e+00    3.665765e+01   -9.431813e-01   1.432578e+00   2.500000e-01   9.407215e-02
#  12   3    3.967076e+01    3.042306e+00    3.662846e+01   -4.966423e-01   8.616790e-01   6.250000e-02   7.295830e-02
#  13   3    3.966167e+01    3.040547e+00    3.662113e+01   -6.487589e-02   8.162396e-01   2.500000e-01   7.100857e-02
#  14   2    3.964834e+01    3.036272e+00    3.661207e+01   -3.781752e-02   1.004097e+00   1.000000e+00   7.875710e-02
#  15   3    3.964771e+01    3.035919e+00    3.661179e+01   -5.129167e-03   2.778927e-01   5.000000e-01   4.143244e-02
#  16   3    3.964657e+01    3.035576e+00    3.661099e+01   -2.056414e-03   4.735973e-01   1.000000e+00   5.408870e-02
#  17   3    3.964642e+01    3.035585e+00    3.661084e+01   -2.501525e-04   1.071038e-01   1.000000e+00   2.572198e-02
#  18   3    3.964641e+01    3.035585e+00    3.661083e+01   -2.037803e-05   2.415217e-02   1.000000e+00   1.221462e-02
#  19   4    3.964641e+01    3.035585e+00    3.661083e+01   -2.222110e-07   2.554108e-03   1.000000e+00   3.972113e-03
#  20   5    3.964641e+01    3.035585e+00    3.661083e+01   -3.790365e-11   3.631888e-05   1.000000e+00   4.736616e-04
#  21   4    3.964641e+01    3.035585e+00    3.661083e+01   -1.356862e-18   6.987377e-09   1.000000e+00   6.569904e-06
#
# Converged in  21  iterations.
# Termination reason:  Norm of the gradient less than tolerance
# Final gradient norm:  6.547940961388256e-11
# Final cost:  39.64641093360201
# 0.23631078345157921 0.33886204110718565
# The relative error is: 24.8 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  41.627185927683776

# %%
# Generate random surface observations
ntargets_2 = 5 
targets_x2 = np.linspace(-180., 0., ntargets_2) 
targets_y2 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_2)
targets_2 = np.zeros([ntargets_2, dim])
targets_2[:,0] = targets_x2; targets_2[:,1] = targets_y2

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_2, xf, yf, utrue, mtrue, m_2, rel_error_2, lmbda_2, lmbda_R_2, noise_std_dev_2, kl_dist_2 ) = solveInverseProblem(k, targets_2, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 5
# The MAX displacement (m) is: 2.0974 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    2.661978e+03    2.612467e+03    4.951117e+01   -3.388057e+04   2.588967e+03   1.000000e+00   5.000000e-01
#   2   3    1.276299e+02    7.998384e+01    4.764610e+01   -5.096885e+03   5.050539e+02   1.000000e+00   4.416779e-01
#   3   4    6.983709e+01    2.148144e+01    4.835565e+01   -1.147779e+02   8.691286e+01   1.000000e+00   1.832225e-01
#   4  11    6.001858e+01    1.716381e+01    4.285477e+01   -3.429868e+01   1.218674e+01   5.000000e-01   6.860891e-02
#   5   1    5.618166e+01    1.315191e+01    4.302975e+01   -7.673232e+00   3.767995e+01   1.000000e+00   1.206402e-01
#   6  16    5.384830e+01    1.254208e+01    4.130622e+01   -2.330389e+01   5.357228e+00   1.250000e-01   4.548905e-02
#   7   9    5.213415e+01    1.023970e+01    4.189446e+01   -6.757365e+00   7.628286e+00   1.000000e+00   5.428130e-02
#   8  11    5.193479e+01    1.025685e+01    4.167794e+01   -1.910892e+01   7.985412e+00   1.250000e-01   5.553738e-02
#   9   9    5.176148e+01    1.040811e+01    4.135338e+01   -2.601051e+01   9.651034e+00   1.250000e-01   6.105534e-02
#  10   1    5.145476e+01    1.004481e+01    4.140995e+01   -6.125229e-01   1.208704e+01   1.000000e+00   6.832769e-02
#  11  17    5.103826e+01    1.007475e+01    4.096351e+01   -2.516422e+01   3.927526e+00   6.250000e-02   3.894900e-02
#  12  17    5.053316e+01    1.007630e+01    4.045686e+01   -4.173531e+01   6.077323e+00   3.125000e-02   4.844990e-02
#  13  15    5.053140e+01    1.006325e+01    4.046815e+01   -7.316664e+00   5.649836e+00   6.250000e-02   4.671482e-02
#  14  12    5.040307e+01    1.006018e+01    4.034289e+01   -2.256626e+01   6.167800e+00   3.125000e-02   4.880922e-02
#  15  10    5.022163e+01    1.005535e+01    4.016629e+01   -7.458755e+00   5.710373e+00   3.125000e-02   4.696442e-02
#  16   9    4.990390e+01    1.026095e+01    3.964295e+01   -1.129352e+00   5.935233e+00   1.000000e+00   4.788016e-02
#  17  14    4.979775e+01    1.012695e+01    3.967080e+01   -2.567133e+00   2.776541e+00   2.500000e-01   3.274830e-02
#  18  17    4.965748e+01    1.012720e+01    3.953028e+01   -3.885322e+01   2.563384e+00   7.812500e-03   3.146615e-02
#  19  17    4.964304e+01    1.012497e+01    3.951807e+01   -7.983210e+00   2.353609e+00   1.562500e-02   3.015115e-02
#  20  12    4.959246e+01    1.012287e+01    3.946959e+01   -7.531972e+00   2.523042e+00   1.562500e-02   3.121756e-02
#  21  14    4.955852e+01    1.011330e+01    3.944522e+01   -1.662344e+00   2.288823e+00   6.250000e-02   2.973328e-02
#  22  12    4.954333e+01    1.010291e+01    3.944042e+01   -2.558159e+00   2.369493e+00   6.250000e-02   3.025272e-02
#  23  15    4.953804e+01    1.010018e+01    3.943786e+01   -6.597799e+00   2.050904e+00   1.562500e-02   2.814553e-02
#  24  12    4.949139e+01    1.009759e+01    3.939381e+01   -5.803398e+00   2.259931e+00   1.562500e-02   2.954503e-02
#  25  14    4.945520e+01    1.005662e+01    3.939858e+01   -6.640782e-01   1.997919e+00   2.500000e-01   2.777958e-02
#  26  15    4.941628e+01    1.005509e+01    3.936119e+01   -7.808565e+00   1.841615e+00   1.562500e-02   2.667081e-02
#  27  14    4.939820e+01    1.005109e+01    3.934712e+01   -1.683604e+00   1.556943e+00   3.125000e-02   2.452297e-02
#  28  14    4.938967e+01    9.998092e+00    3.939158e+01   -4.568227e-01   1.749777e+00   5.000000e-01   2.599729e-02
#  29  17    4.932135e+01    9.997687e+00    3.932366e+01   -8.848370e+00   1.182390e+00   7.812500e-03   2.137062e-02
#  30  14    4.931939e+01    9.986276e+00    3.933312e+01   -1.582728e-01   1.130694e+00   2.500000e-01   2.089822e-02
#  31  12    4.931079e+01    9.984371e+00    3.932642e+01   -6.405325e-01   1.249333e+00   6.250000e-02   2.196726e-02
#  32  14    4.930184e+01    9.982443e+00    3.931940e+01   -3.088910e-01   1.041424e+00   6.250000e-02   2.005629e-02
#  33  12    4.929118e+01    9.959204e+00    3.933197e+01   -4.196690e-02   1.058365e+00   1.000000e+00   2.021876e-02
#  34  15    4.928493e+01    9.958831e+00    3.932610e+01   -9.306920e-02   7.876459e-01   1.250000e-01   1.744224e-02
#  35  14    4.928076e+01    9.956473e+00    3.932429e+01   -6.973749e-03   5.475680e-01   1.000000e+00   1.454306e-02
#  36  17    4.927950e+01    9.956619e+00    3.932288e+01   -2.172826e-03   1.068626e-01   1.000000e+00   6.424653e-03
#  37  17    4.927936e+01    9.956743e+00    3.932262e+01   -2.501868e-04   3.050936e-02   1.000000e+00   3.432838e-03
#  38  17    4.927936e+01    9.956767e+00    3.932259e+01   -5.887811e-06   4.152926e-03   1.000000e+00   1.266525e-03
#  39  20    4.927936e+01    9.956767e+00    3.932259e+01   -4.044508e-09   9.923854e-05   1.000000e+00   1.957839e-04
#  40  20    4.927936e+01    9.956767e+00    3.932259e+01   -2.367724e-15   7.576524e-08   3.125000e-02   5.409682e-06
#  41  21    4.927936e+01    9.956767e+00    3.932259e+01   -2.222257e-15   7.353535e-08   9.765625e-04   5.329480e-06
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  7.35353490401277e-08
# Final cost:  49.27935931949607
# 0.22876356001681408 0.3766554473009721
# The relative error is: 21.3 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  62.01252256908627

# %%
# Generate random surface observations
ntargets_3 = 10 
targets_x3 = np.linspace(-180., 0., ntargets_3) 
targets_y3 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_3)
targets_3 = np.zeros([ntargets_3, dim])
targets_3[:,0] = targets_x3; targets_3[:,1] = targets_y3

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_3, xf, yf, utrue, mtrue, m_3, rel_error_3, lmbda_3, lmbda_R_3, noise_std_dev_3, kl_dist_3 ) = solveInverseProblem(k, targets_3, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 10
# The MAX displacement (m) is: 2.4835 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    5.510584e+03    5.460285e+03    5.029863e+01   -7.341586e+04   5.561532e+03   1.000000e+00   5.000000e-01
#   2   1    1.786275e+03    1.734973e+03    5.130206e+01   -7.446088e+03   1.329776e+03   1.000000e+00   4.889811e-01
#   3   3    2.930057e+02    2.441939e+02    4.881181e+01   -3.007503e+03   2.062192e+02   1.000000e+00   1.925606e-01
#   4   5    9.975421e+01    5.121103e+01    4.854319e+01   -3.814324e+02   1.253425e+02   1.000000e+00   1.501246e-01
#   5   8    8.229140e+01    3.571703e+01    4.657437e+01   -3.465447e+01   3.126040e+01   1.000000e+00   7.497216e-02
#   6  10    7.898817e+01    3.461986e+01    4.436831e+01   -1.115669e+01   1.732485e+01   5.000000e-01   5.581328e-02
#   7   1    7.813462e+01    3.370424e+01    4.443039e+01   -1.702572e+00   2.544975e+01   1.000000e+00   6.764637e-02
#   8  31    7.747383e+01    3.352698e+01    4.394684e+01   -3.537523e+01   4.383973e+00   1.250000e-01   2.807609e-02
#   9  21    7.696354e+01    3.362818e+01    4.333536e+01   -1.078774e+02   7.998322e+00   3.125000e-02   3.792296e-02
#  10  26    7.656078e+01    3.331246e+01    4.324831e+01   -3.516426e+01   1.084516e+01   1.250000e-01   4.415915e-02
#  11   9    7.531167e+01    3.332646e+01    4.198521e+01   -6.603574e+01   1.067654e+01   3.125000e-02   4.381451e-02
#  12   4    7.497823e+01    3.300505e+01    4.197317e+01   -6.675316e-01   1.262153e+01   1.000000e+00   4.763858e-02
#  13  28    7.490261e+01    3.294677e+01    4.195584e+01   -1.210597e+01   3.781620e+00   1.250000e-01   2.607604e-02
#  14  24    7.456331e+01    3.291485e+01    4.164846e+01   -5.017541e+01   4.235643e+00   3.125000e-02   2.759704e-02
#  15  22    7.421752e+01    3.292002e+01    4.129750e+01   -2.236020e+01   5.821673e+00   3.125000e-02   3.235390e-02
#  16  17    7.412340e+01    3.289478e+01    4.122861e+01   -1.235878e+01   6.203430e+00   3.125000e-02   3.339787e-02
#  17  18    7.398345e+01    3.288471e+01    4.109875e+01   -1.181599e+01   6.217631e+00   1.562500e-02   3.343607e-02
#  18  18    7.343164e+01    3.241542e+01    4.101622e+01   -2.382518e+00   6.035977e+00   5.000000e-01   3.294402e-02
#  19  13    7.333309e+01    3.244590e+01    4.088719e+01   -1.087165e+01   6.850714e+00   1.250000e-01   3.509706e-02
#  20   2    7.323547e+01    3.233962e+01    4.089585e+01   -1.951074e-01   9.682778e+00   1.000000e+00   4.172562e-02
#  21  25    7.301339e+01    3.228865e+01    4.072474e+01   -1.234612e+00   2.014764e+00   2.500000e-01   1.903333e-02
#  22  19    7.301133e+01    3.217160e+01    4.083973e+01   -7.788450e-01   2.422192e+00   2.500000e-01   2.086926e-02
#  23  19    7.296522e+01    3.216664e+01    4.079859e+01   -7.435255e+00   2.795681e+00   1.250000e-01   2.242057e-02
#  24  17    7.290996e+01    3.204936e+01    4.086061e+01   -5.909432e-01   3.334774e+00   2.500000e-01   2.448702e-02
#  25  18    7.287438e+01    3.211976e+01    4.075463e+01   -1.682159e+00   2.980399e+00   1.250000e-01   2.314941e-02
#  26  17    7.281865e+01    3.205003e+01    4.076862e+01   -4.975751e-01   2.597633e+00   1.250000e-01   2.161184e-02
#  27  17    7.280171e+01    3.192732e+01    4.087440e+01   -3.167318e-01   2.321114e+00   2.500000e-01   2.042918e-02
#  28  23    7.279311e+01    3.198213e+01    4.081098e+01   -9.296940e-01   1.877629e+00   1.250000e-01   1.837417e-02
#  29  19    7.277730e+01    3.186844e+01    4.090886e+01   -3.003923e-01   1.583080e+00   2.500000e-01   1.687152e-02
#  30  23    7.276741e+01    3.191686e+01    4.085055e+01   -7.125432e-01   1.359382e+00   1.250000e-01   1.563412e-02
#  31  23    7.273678e+01    3.186621e+01    4.087056e+01   -2.691770e-01   1.209944e+00   1.250000e-01   1.474977e-02
#  32  16    7.272013e+01    3.175195e+01    4.096818e+01   -3.280199e-02   9.657659e-01   1.000000e+00   1.317767e-02
#  33  26    7.271779e+01    3.175110e+01    4.096669e+01   -4.376367e-03   2.384519e-01   1.000000e+00   6.547918e-03
#  34  30    7.271736e+01    3.175323e+01    4.096413e+01   -6.532566e-04   7.422968e-02   1.000000e+00   3.653352e-03
#  35  36    7.271716e+01    3.175545e+01    4.096171e+01   -3.478234e-04   3.440570e-02   1.000000e+00   2.487242e-03
#  36  36    7.271714e+01    3.175630e+01    4.096083e+01   -3.391156e-05   1.022167e-02   1.000000e+00   1.355701e-03
#  37  38    7.271714e+01    3.175636e+01    4.096078e+01   -1.414045e-07   6.493693e-04   1.000000e+00   3.417029e-04
#  38  44    7.271714e+01    3.175636e+01    4.096078e+01   -1.988234e-12   2.435667e-06   1.000000e+00   2.092723e-05
#  39  34    7.271714e+01    3.175636e+01    4.096078e+01   -3.666715e-19   1.037804e-08   1.000000e+00   1.366031e-06
#
# Converged in  39  iterations.
# Termination reason:  Norm of (g, dm) less than tolerance
# Final gradient norm:  1.037803789847688e-08
# Final cost:  72.71713751135132
# 0.18751678846557496 0.3763116591219062
# The relative error is: 21.0 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  78.33358388236337

# %%
# Generate random surface observations
ntargets_4 = 17 
targets_x4 = np.linspace(-180., 0., ntargets_4) 
targets_y4 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_4)
targets_4 = np.zeros([ntargets_4, dim])
targets_4[:,0] = targets_x4; targets_4[:,1] = targets_y4

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_4, xf, yf, utrue, mtrue, m_4, rel_error_4, lmbda_4, lmbda_R_4, noise_std_dev_4, kl_dist_4 ) = solveInverseProblem(k, targets_4, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 17
# The MAX displacement (m) is: 2.6317 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    8.820936e+03    8.769763e+03    5.117256e+01   -1.340572e+05   1.004149e+04   1.000000e+00   5.000000e-01
#   2   1    2.878316e+03    2.826094e+03    5.222182e+01   -1.180827e+04   2.308703e+03   1.000000e+00   4.794960e-01
#   3   3    4.726547e+02    4.234132e+02    4.924155e+01   -4.842944e+03   3.719866e+02   1.000000e+00   1.924707e-01
#   4   5    1.626122e+02    1.135891e+02    4.902310e+01   -6.176579e+02   2.262928e+02   1.000000e+00   1.501192e-01
#   5  13    1.301670e+02    8.463577e+01    4.553119e+01   -1.086208e+02   6.702133e+01   5.000000e-01   8.169726e-02
#   6   1    1.206154e+02    7.493228e+01    4.568314e+01   -1.898060e+01   1.092053e+02   1.000000e+00   1.042852e-01
#   7  34    1.144431e+02    6.818614e+01    4.625692e+01   -1.677807e+02   3.665505e+01   6.250000e-02   6.041821e-02
#   8   7    1.064378e+02    5.951457e+01    4.692320e+01   -1.619576e+01   4.094805e+01   1.000000e+00   6.385833e-02
#   9  38    1.035167e+02    5.828114e+01    4.523552e+01   -3.008036e+01   1.032332e+01   2.500000e-01   3.206348e-02
#  10   1    1.025120e+02    5.721357e+01    4.529847e+01   -2.006108e+00   3.644117e+01   1.000000e+00   6.024168e-02
#  11  34    1.015646e+02    5.687805e+01    4.468651e+01   -6.523263e+01   8.914052e+00   6.250000e-02   2.979467e-02
#  12  23    1.003539e+02    5.614913e+01    4.420481e+01   -1.884985e+01   1.114091e+01   1.250000e-01   3.330897e-02
#  13  19    9.992169e+01    5.551129e+01    4.441040e+01   -1.519651e+01   1.254081e+01   1.250000e-01   3.533977e-02
#  14  15    9.974113e+01    5.525266e+01    4.448847e+01   -1.432300e+01   1.367153e+01   1.250000e-01   3.689857e-02
#  15  10    9.904065e+01    5.489312e+01    4.414754e+01   -1.144976e+01   1.679195e+01   1.250000e-01   4.089324e-02
#  16  11    9.858621e+01    5.421990e+01    4.436631e+01   -5.331414e+00   1.709788e+01   2.500000e-01   4.126407e-02
#  17  11    9.850542e+01    5.404294e+01    4.446248e+01   -8.317257e+00   1.496612e+01   1.250000e-01   3.860606e-02
#  18  10    9.834161e+01    5.398117e+01    4.436044e+01   -6.548520e+00   1.526380e+01   1.250000e-01   3.898812e-02
#  19  10    9.804700e+01    5.391001e+01    4.413699e+01   -7.407062e+00   1.545031e+01   6.250000e-02   3.922559e-02
#  20   1    9.790697e+01    5.374948e+01    4.415749e+01   -2.799266e-01   1.503199e+01   1.000000e+00   3.869094e-02
#  21  36    9.790565e+01    5.360931e+01    4.429634e+01   -5.005501e+00   4.493501e+00   1.250000e-01   2.115404e-02
#  22  31    9.782872e+01    5.351894e+01    4.430978e+01   -1.781685e+01   7.175913e+00   1.250000e-01   2.673250e-02
#  23  10    9.777005e+01    5.349427e+01    4.427578e+01   -6.022795e+00   1.564679e+01   1.250000e-01   3.947422e-02
#  24   9    9.747479e+01    5.346121e+01    4.401357e+01   -7.292695e+00   1.569372e+01   6.250000e-02   3.953337e-02
#  25   3    9.733434e+01    5.331221e+01    4.402213e+01   -2.808020e-01   1.529901e+01   1.000000e+00   3.903307e-02
#  26  40    9.713824e+01    5.326498e+01    4.387326e+01   -4.028989e+00   2.709821e+00   6.250000e-02   1.642749e-02
#  27  31    9.697735e+01    5.315682e+01    4.382053e+01   -1.512409e+00   2.934785e+00   1.250000e-01   1.709579e-02
#  28  22    9.678597e+01    5.238213e+01    4.440383e+01   -8.302756e-01   3.318511e+00   1.000000e+00   1.817911e-02
#  29  20    9.664615e+01    5.249242e+01    4.415374e+01   -4.183632e+00   4.698635e+00   1.250000e-01   2.163151e-02
#  30   2    9.663407e+01    5.247340e+01    4.416067e+01   -2.416314e-02   4.187609e+00   1.000000e+00   2.042133e-02
#  31  36    9.659591e+01    5.248186e+01    4.411405e+01   -3.883277e-01   1.452194e+00   1.250000e-01   1.202578e-02
#  32  36    9.658004e+01    5.250334e+01    4.407670e+01   -1.525563e-01   1.397475e+00   5.000000e-01   1.179704e-02
#  33  32    9.657126e+01    5.250890e+01    4.406237e+01   -6.121193e-01   1.536357e+00   2.500000e-01   1.236935e-02
#  34  35    9.654409e+01    5.248755e+01    4.405653e+01   -1.307577e-01   1.055055e+00   2.500000e-01   1.025034e-02
#  35  36    9.653759e+01    5.249245e+01    4.404514e+01   -1.919197e-02   6.487448e-01   1.000000e+00   8.037813e-03
#  36  28    9.653582e+01    5.249586e+01    4.403997e+01   -1.268038e-02   6.531838e-01   1.000000e+00   8.065265e-03
#  37  31    9.653403e+01    5.249518e+01    4.403885e+01   -9.392756e-03   3.691717e-01   2.500000e-01   6.063385e-03
#  38  43    9.653326e+01    5.249632e+01    4.403694e+01   -1.245228e-03   1.849773e-01   1.000000e+00   4.292005e-03
#  39  47    9.653298e+01    5.249792e+01    4.403507e+01   -4.512184e-04   6.018856e-02   1.000000e+00   2.448262e-03
#  40  51    9.653293e+01    5.249910e+01    4.403384e+01   -8.495251e-05   1.823759e-02   1.000000e+00   1.347673e-03
#  41  53    9.653293e+01    5.249935e+01    4.403358e+01   -2.523590e-06   2.930717e-03   1.000000e+00   5.402415e-04
#  42  58    9.653293e+01    5.249936e+01    4.403358e+01   -2.259937e-09   1.044016e-04   1.000000e+00   1.019658e-04
#  43  66    9.653293e+01    5.249936e+01    4.403358e+01   -2.518053e-15   1.332227e-07   1.000000e+00   3.642420e-06
#  44  57    9.653293e+01    5.249936e+01    4.403358e+01   -4.716006e-18   3.662327e-08   5.000000e-01   1.909763e-06
#
# Converged in  44  iterations.
# Termination reason:  Norm of the gradient less than tolerance
# Final gradient norm:  9.215134759720525e-09
# Final cost:  96.53293253192757
# 0.16707586551400197 0.3740786331221047
# The relative error is: 17.7 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  88.09389903503705

# %%
# Generate random surface observations
ntargets_5 = 23 
targets_x5 = np.linspace(-180., 0., ntargets_5) 
targets_y5 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_5)
targets_5 = np.zeros([ntargets_5, dim])
targets_5[:,0] = targets_x5; targets_5[:,1] = targets_y5

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_5, xf, yf, utrue, mtrue, m_5, rel_error_5, lmbda_5, lmbda_R_5, noise_std_dev_5, kl_dist_5 ) = solveInverseProblem(k, targets_5, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 23
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    1.201982e+04    1.196879e+04    5.102280e+01   -1.800228e+05   1.340011e+04   1.000000e+00   5.000000e-01
#   2   1    3.937520e+03    3.885503e+03    5.201693e+01   -1.606411e+04   3.016092e+03   1.000000e+00   4.744255e-01
#   3   3    6.061713e+02    5.570046e+02    4.916670e+01   -6.714905e+03   5.131665e+02   1.000000e+00   1.956928e-01
#   4   5    1.808429e+02    1.319745e+02    4.886836e+01   -8.470361e+02   3.118517e+02   1.000000e+00   1.525527e-01
#   5  13    1.616303e+02    1.168564e+02    4.477390e+01   -1.276579e+02   6.700702e+01   5.000000e-01   7.071409e-02
#   6   1    1.313141e+02    8.630321e+01    4.501086e+01   -6.007730e+01   2.255072e+02   1.000000e+00   1.297257e-01
#   7  19    1.267599e+02    8.211961e+01    4.464030e+01   -4.439835e+01   3.740848e+01   5.000000e-01   5.283611e-02
#   8   1    1.167680e+02    7.196781e+01    4.480019e+01   -1.990793e+01   1.327195e+02   1.000000e+00   9.952064e-02
#   9  34    1.151600e+02    7.177847e+01    4.338156e+01   -6.560941e+01   1.878742e+01   3.125000e-02   3.744375e-02
#  10  18    1.119907e+02    6.896742e+01    4.302329e+01   -1.056995e+01   1.848857e+01   5.000000e-01   3.714475e-02
#  11   4    1.113297e+02    6.826339e+01    4.306635e+01   -1.317000e+00   2.729890e+01   1.000000e+00   4.513551e-02
#  12  46    1.109926e+02    6.794987e+01    4.304269e+01   -1.231660e+01   5.438924e+00   2.500000e-01   2.014662e-02
#  13   2    1.105083e+02    6.746189e+01    4.304644e+01   -9.676687e-01   3.358355e+01   1.000000e+00   5.006211e-02
#  14  38    1.097965e+02    6.736257e+01    4.243393e+01   -1.786289e+01   4.800226e+00   6.250000e-02   1.892678e-02
#  15  15    1.097348e+02    6.678653e+01    4.294827e+01   -2.331740e+00   1.160525e+01   5.000000e-01   2.942884e-02
#  16  10    1.096607e+02    6.686819e+01    4.279251e+01   -2.834044e+00   1.661638e+01   5.000000e-01   3.521389e-02
#  17   5    1.093773e+02    6.664612e+01    4.273123e+01   -5.578758e-01   2.007991e+01   1.000000e+00   3.871032e-02
#  18  44    1.092138e+02    6.657128e+01    4.264257e+01   -9.049418e+00   4.749534e+00   6.250000e-02   1.882657e-02
#  19  25    1.090237e+02    6.651538e+01    4.250829e+01   -5.976744e+00   5.249902e+00   6.250000e-02   1.979344e-02
#  20  20    1.089973e+02    6.646686e+01    4.253046e+01   -3.179786e+00   6.052836e+00   6.250000e-02   2.125324e-02
#  21  15    1.089731e+02    6.642087e+01    4.255226e+01   -4.102264e+00   6.049608e+00   6.250000e-02   2.124758e-02
#  22  19    1.089278e+02    6.637503e+01    4.255274e+01   -3.199594e+00   6.452337e+00   6.250000e-02   2.194342e-02
#  23  15    1.089092e+02    6.633229e+01    4.257694e+01   -3.653875e+00   6.600022e+00   6.250000e-02   2.219313e-02
#  24  18    1.088754e+02    6.629167e+01    4.258377e+01   -3.014242e+00   6.866466e+00   6.250000e-02   2.263666e-02
#  25  14    1.088539e+02    6.625408e+01    4.259986e+01   -3.344465e+00   6.943769e+00   6.250000e-02   2.276373e-02
#  26  17    1.088337e+02    6.621644e+01    4.261730e+01   -2.862750e+00   7.142597e+00   6.250000e-02   2.308734e-02
#  27  14    1.088098e+02    6.618662e+01    4.262316e+01   -3.232651e+00   7.178693e+00   6.250000e-02   2.314560e-02
#  28  19    1.087954e+02    6.615185e+01    4.264350e+01   -2.777018e+00   7.360061e+00   6.250000e-02   2.343616e-02
#  29  14    1.087716e+02    6.612693e+01    4.264464e+01   -3.148240e+00   7.358696e+00   6.250000e-02   2.343399e-02
#  30  17    1.087610e+02    6.609470e+01    4.266626e+01   -2.725396e+00   7.515716e+00   6.250000e-02   2.368269e-02
#  31  14    1.087375e+02    6.607344e+01    4.266406e+01   -3.085469e+00   7.499613e+00   6.250000e-02   2.365730e-02
#  32  15    1.087187e+02    6.604369e+01    4.267497e+01   -2.507588e+00   7.637298e+00   6.250000e-02   2.387348e-02
#  33  14    1.087121e+02    6.602132e+01    4.269075e+01   -3.028120e+00   7.501077e+00   6.250000e-02   2.365961e-02
#  34  15    1.086890e+02    6.599604e+01    4.269296e+01   -2.571714e+00   7.612286e+00   6.250000e-02   2.383435e-02
#  35  13    1.086847e+02    6.597584e+01    4.270884e+01   -2.987290e+00   7.501960e+00   6.250000e-02   2.366100e-02
#  36  17    1.086744e+02    6.595287e+01    4.272155e+01   -2.768153e+00   7.608036e+00   6.250000e-02   2.382770e-02
#  37  12    1.086533e+02    6.593802e+01    4.271529e+01   -2.974453e+00   7.594054e+00   6.250000e-02   2.380579e-02
#  38  17    1.085759e+02    6.592534e+01    4.265056e+01   -2.698530e+00   7.720235e+00   3.125000e-02   2.400275e-02
#  39   3    1.085471e+02    6.588922e+01    4.265787e+01   -5.761442e-02   7.534106e+00   1.000000e+00   2.371164e-02
#  40  42    1.082418e+02    6.527401e+01    4.296783e+01   -6.918161e-01   2.128230e+00   1.000000e+00   1.260245e-02
#  41   2    1.082321e+02    6.525834e+01    4.297371e+01   -1.955002e-02   4.426298e+00   1.000000e+00   1.817465e-02
#  42  43    1.082205e+02    6.514038e+01    4.308015e+01   -2.572206e-01   1.621014e+00   5.000000e-01   1.099864e-02
#  43  43    1.081952e+02    6.511708e+01    4.307810e+01   -4.984731e-01   1.774691e+00   1.250000e-01   1.150819e-02
#  44  43    1.081863e+02    6.509396e+01    4.309236e+01   -2.776726e-01   1.466111e+00   1.250000e-01   1.045994e-02
#  45  48    1.081795e+02    6.507295e+01    4.310656e+01   -1.643422e-01   1.306097e+00   1.250000e-01   9.872644e-03
#  46  49    1.081703e+02    6.500025e+01    4.317001e+01   -6.276921e-02   1.262587e+00   5.000000e-01   9.706810e-03
#  47  46    1.081676e+02    6.497840e+01    4.318922e+01   -5.426210e-02   8.623937e-01   2.500000e-01   8.022294e-03
#  48  43    1.081667e+02    6.491578e+01    4.325095e+01   -2.536911e-02   9.433873e-01   1.000000e+00   8.390557e-03
#  49  41    1.081658e+02    6.491356e+01    4.325220e+01   -5.164993e-02   7.528422e-01   2.500000e-01   7.495451e-03
#  50  36    1.081629e+02    6.491378e+01    4.324910e+01   -2.686350e-02   9.324915e-01   5.000000e-01   8.341962e-03
#  51  43    1.081622e+02    6.491295e+01    4.324922e+01   -7.337028e-03   6.080145e-01   1.000000e+00   6.736011e-03
#  52  38    1.081605e+02    6.491523e+01    4.324526e+01   -7.123121e-03   5.481247e-01   1.000000e+00   6.395661e-03
#  53  43    1.081592e+02    6.491618e+01    4.324304e+01   -2.577656e-03   3.194153e-01   1.000000e+00   4.882291e-03
#  54  53    1.081588e+02    6.491899e+01    4.323986e+01   -6.334743e-04   9.426963e-02   1.000000e+00   2.652355e-03
#  55  55    1.081588e+02    6.492000e+01    4.323882e+01   -5.961561e-05   2.213547e-02   1.000000e+00   1.285258e-03
#  56  67    1.081588e+02    6.492008e+01    4.323874e+01   -4.655244e-07   1.985284e-03   1.000000e+00   3.849082e-04
#  57  74    1.081588e+02    6.492008e+01    4.323874e+01   -2.862930e-11   1.628996e-05   5.000000e-01   3.486630e-05
#  58  74    1.081588e+02    6.492008e+01    4.323874e+01   -7.158133e-12   8.145314e-06   1.000000e+00   2.465470e-05
#  59  63    1.081588e+02    6.492008e+01    4.323874e+01   -1.392421e-18   1.675817e-08   9.765625e-04   1.118302e-06
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  1.675816793741513e-08
# Final cost:  108.15881611388888
# 0.19977228807023847 0.3797461798421325
# The relative error is: 16.8 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  92.39181003223217

# %%
# Generate random surface observations
ntargets_6 = 27 
targets_x6 = np.linspace(-180., 0., ntargets_6) 
targets_y6 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_6)
targets_6 = np.zeros([ntargets_6, dim])
targets_6[:,0] = targets_x6; targets_6[:,1] = targets_y6

# Define regularization weights
eps = 1e-7  
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_6, xf, yf, utrue, mtrue, m_6, rel_error_6, lmbda_6, lmbda_R_6, noise_std_dev_6, kl_dist_6 ) = solveInverseProblem(k, targets_6, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 27
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    1.439377e+04    1.434240e+04    5.137260e+01   -2.179467e+05   1.615868e+04   1.000000e+00   5.000000e-01
#   2   1    4.661459e+03    4.609038e+03    5.242165e+01   -1.932905e+04   3.696728e+03   1.000000e+00   4.783060e-01
#   3   3    7.639590e+02    7.145538e+02    4.940520e+01   -7.854390e+03   6.005830e+02   1.000000e+00   1.927896e-01
#   4   5    2.226303e+02    1.735736e+02    4.905667e+01   -1.078959e+03   3.909069e+02   1.000000e+00   1.555370e-01
#   5  12    1.900611e+02    1.447630e+02    4.529808e+01   -1.866306e+02   9.164174e+01   5.000000e-01   7.530846e-02
#   6   1    1.511598e+02    1.056196e+02    4.554019e+01   -7.706772e+01   2.789919e+02   1.000000e+00   1.313993e-01
#   7  22    1.468417e+02    1.019038e+02    4.493794e+01   -6.297976e+01   5.445382e+01   5.000000e-01   5.805121e-02
#   8   1    1.291905e+02    8.407294e+01    4.511753e+01   -3.515084e+01   1.936256e+02   1.000000e+00   1.094658e-01
#   9  43    1.281018e+02    8.405630e+01    4.404547e+01   -7.021223e+02   2.978645e+01   1.953125e-03   4.293451e-02
#  10  15    1.236598e+02    7.617592e+01    4.748391e+01   -1.732647e+01   2.804660e+01   1.000000e+00   4.166173e-02
#  11   1    1.222248e+02    7.468237e+01    4.754248e+01   -2.867007e+00   5.788550e+01   1.000000e+00   5.985246e-02
#  12  55    1.205161e+02    7.485876e+01    4.565736e+01   -6.059843e+01   7.432827e+00   6.250000e-02   2.144737e-02
#  13   6    1.196967e+02    7.445830e+01    4.523836e+01   -1.626673e+00   2.792347e+01   1.000000e+00   4.157017e-02
#  14  51    1.194754e+02    7.423333e+01    4.524206e+01   -1.257245e+01   5.799401e+00   1.250000e-01   1.894474e-02
#  15  33    1.187778e+02    7.410786e+01    4.466995e+01   -1.477902e+01   8.686440e+00   1.250000e-01   2.318558e-02
#  16   6    1.184326e+02    7.352840e+01    4.490422e+01   -6.937900e-01   1.500968e+01   1.000000e+00   3.047774e-02
#  17  59    1.181164e+02    7.347391e+01    4.464251e+01   -6.585311e+00   3.533262e+00   6.250000e-02   1.478717e-02
#  18  37    1.179378e+02    7.309100e+01    4.484676e+01   -2.795097e+00   4.390533e+00   5.000000e-01   1.648374e-02
#  19  15    1.176416e+02    7.315393e+01    4.448768e+01   -1.635591e+00   1.301579e+01   5.000000e-01   2.838131e-02
#  20   2    1.174546e+02    7.295080e+01    4.450379e+01   -3.739158e-01   2.248201e+01   1.000000e+00   3.730050e-02
#  21  55    1.173612e+02    7.294036e+01    4.442086e+01   -4.864034e+00   2.272737e+00   3.125000e-02   1.185964e-02
#  22  36    1.173402e+02    7.291666e+01    4.442355e+01   -1.918580e+00   3.026896e+00   6.250000e-02   1.368661e-02
#  23  44    1.173126e+02    7.290691e+01    4.440572e+01   -2.384530e+00   2.868075e+00   3.125000e-02   1.332270e-02
#  24  33    1.173008e+02    7.285657e+01    4.444426e+01   -1.184448e+00   3.118648e+00   1.250000e-01   1.389250e-02
#  25  39    1.172528e+02    7.284830e+01    4.440454e+01   -2.528601e+00   3.023699e+00   3.125000e-02   1.367938e-02
#  26  33    1.172315e+02    7.268129e+01    4.455019e+01   -5.481839e-01   3.351773e+00   5.000000e-01   1.440238e-02
#  27  32    1.171970e+02    7.267961e+01    4.451736e+01   -2.212626e+00   3.261541e+00   6.250000e-02   1.420720e-02
#  28  30    1.171556e+02    7.267586e+01    4.447974e+01   -2.641728e+00   4.301920e+00   3.125000e-02   1.631655e-02
#  29  21    1.171378e+02    7.266159e+01    4.447626e+01   -3.840031e-01   4.272360e+00   6.250000e-02   1.626039e-02
#  30  10    1.171286e+02    7.262980e+01    4.449879e+01   -1.851398e-02   4.063604e+00   1.000000e+00   1.585816e-02
#  31  50    1.170979e+02    7.253569e+01    4.456224e+01   -6.696494e-02   1.235226e+00   1.000000e+00   8.743197e-03
#  32  34    1.170940e+02    7.253747e+01    4.455649e+01   -2.182134e-02   5.848737e-01   5.000000e-01   6.016281e-03
#  33  36    1.170881e+02    7.253934e+01    4.454872e+01   -2.029224e-02   4.225000e-01   1.000000e+00   5.113408e-03
#  34  49    1.170849e+02    7.253997e+01    4.454495e+01   -1.793769e-02   4.536449e-01   2.500000e-01   5.298527e-03
#  35  49    1.170829e+02    7.252926e+01    4.455360e+01   -3.647167e-03   3.092101e-01   1.000000e+00   4.374455e-03
#  36  60    1.170817e+02    7.251885e+01    4.456281e+01   -2.010801e-03   1.773934e-01   1.000000e+00   3.313339e-03
#  37  65    1.170815e+02    7.251533e+01    4.456622e+01   -2.244125e-04   5.274514e-02   1.000000e+00   1.806709e-03
#  38  57    1.170815e+02    7.251512e+01    4.456643e+01   -3.138063e-06   6.732515e-03   1.000000e+00   6.454844e-04
#  39  70    1.170815e+02    7.251512e+01    4.456643e+01   -8.268446e-09   2.999167e-04   1.000000e+00   1.362377e-04
#  40  89    1.170815e+02    7.251512e+01    4.456643e+01   -1.079157e-13   1.031579e-06   1.000000e+00   7.990030e-06
#  41  73    1.170815e+02    7.251512e+01    4.456643e+01   -3.852205e-18   3.391144e-08   6.250000e-02   1.448673e-06
#  42  68    1.170815e+02    7.251512e+01    4.456643e+01   -1.400763e-17   6.828663e-08   1.000000e+00   2.055725e-06
#  43  74    1.170815e+02    7.251512e+01    4.456643e+01   -1.708815e-18   3.087377e-08   6.250000e-02   1.382267e-06
#  44  73    1.170815e+02    7.251512e+01    4.456643e+01   -2.009608e-18   3.177009e-08   9.765625e-04   1.402188e-06
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  3.1770088921972825e-08
# Final cost:  117.08154717810596
# 0.14560747458214388 0.36490623191251337
# The relative error is: 15.7 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  100.5735725664845

# %%
# Generate random surface observations
ntargets_7 = 33 
targets_x7 = np.linspace(-180., 0., ntargets_7) 
targets_y7 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_7)
targets_7 = np.zeros([ntargets_7, dim])
targets_7[:,0] = targets_x7; targets_7[:,1] = targets_y7

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_7, xf, yf, utrue, mtrue, m_7, rel_error_7, lmbda_7, lmbda_R_7, noise_std_dev_7, kl_dist_7 ) = solveInverseProblem(k, targets_7, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 33
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    1.724426e+04    1.719280e+04    5.146402e+01   -2.681043e+05   1.984899e+04   1.000000e+00   5.000000e-01
#   2   1    5.587177e+03    5.534643e+03    5.253362e+01   -2.314438e+04   4.580353e+03   1.000000e+00   4.803749e-01
#   3   3    8.007559e+02    7.511630e+02    4.959288e+01   -9.637689e+03   7.482132e+02   1.000000e+00   1.941527e-01
#   4   5    2.413569e+02    1.921411e+02    4.921584e+01   -1.116866e+03   4.277983e+02   1.000000e+00   1.468082e-01
#   5  13    1.917285e+02    1.460313e+02    4.569718e+01   -1.923252e+02   1.041790e+02   5.000000e-01   7.244709e-02
#   6   1    1.680111e+02    1.221494e+02    4.586168e+01   -4.710052e+01   2.403251e+02   1.000000e+00   1.100349e-01
#   7  21    1.569876e+02    1.130533e+02    4.393430e+01   -5.854485e+01   5.870970e+01   5.000000e-01   5.438583e-02
#   8   1    1.465769e+02    1.025245e+02    4.405232e+01   -2.074723e+01   1.643909e+02   1.000000e+00   9.100594e-02
#   9  34    1.449372e+02    1.018190e+02    4.311821e+01   -5.204243e+01   3.037206e+01   6.250000e-02   3.911721e-02
#  10   9    1.404305e+02    9.737426e+01    4.305623e+01   -9.183576e+00   3.372205e+01   1.000000e+00   4.121809e-02
#  11  17    1.397733e+02    9.575853e+01    4.401479e+01   -7.773992e+00   1.805353e+01   5.000000e-01   3.015865e-02
#  12   6    1.389180e+02    9.582074e+01    4.309729e+01   -3.306932e+00   3.514355e+01   1.000000e+00   4.207786e-02
#  13   2    1.382596e+02    9.513618e+01    4.312340e+01   -1.315857e+00   4.822760e+01   1.000000e+00   4.929225e-02
#  14  56    1.377731e+02    9.507118e+01    4.270195e+01   -1.450833e+01   8.226054e+00   6.250000e-02   2.035760e-02
#  15  15    1.376150e+02    9.498212e+01    4.263285e+01   -6.051006e+00   1.637582e+01   1.250000e-01   2.872317e-02
#  16   9    1.374772e+02    9.485040e+01    4.262680e+01   -1.144511e+00   1.869086e+01   5.000000e-01   3.068636e-02
#  17  14    1.373542e+02    9.479666e+01    4.255750e+01   -4.973829e+00   1.497201e+01   1.250000e-01   2.746445e-02
#  18   9    1.371838e+02    9.478061e+01    4.240320e+01   -8.932234e-01   1.694383e+01   2.500000e-01   2.921707e-02
#  19   5    1.371062e+02    9.466013e+01    4.244609e+01   -1.551912e-01   1.466912e+01   1.000000e+00   2.718522e-02
#  20  57    1.363682e+02    9.415481e+01    4.221342e+01   -4.672858e+00   3.399117e+00   5.000000e-01   1.308621e-02
#  21  45    1.362244e+02    9.410015e+01    4.212430e+01   -1.067798e+02   1.588729e+01   1.562500e-02   2.829149e-02
#  22  17    1.359567e+02    9.416479e+01    4.179196e+01   -4.482374e+00   1.226856e+01   2.500000e-01   2.486151e-02
#  23  19    1.359491e+02    9.371446e+01    4.223462e+01   -2.013767e+00   1.549119e+01   5.000000e-01   2.793658e-02
#  24  40    1.356054e+02    9.368952e+01    4.191592e+01   -1.353669e+01   1.177518e+01   6.250000e-02   2.435649e-02
#  25  25    1.355413e+02    9.365483e+01    4.188642e+01   -4.535230e+00   1.157055e+01   3.125000e-02   2.414393e-02
#  26  24    1.355240e+02    9.356764e+01    4.195640e+01   -3.196139e+00   1.114691e+01   1.250000e-01   2.369780e-02
#  27  32    1.354007e+02    9.353456e+01    4.186618e+01   -6.064585e+00   9.462746e+00   3.125000e-02   2.183431e-02
#  28  25    1.353960e+02    9.346818e+01    4.192780e+01   -1.708521e+00   8.981021e+00   1.250000e-01   2.127128e-02
#  29  25    1.353353e+02    9.343996e+01    4.189532e+01   -2.874278e+00   7.725238e+00   3.125000e-02   1.972817e-02
#  30  23    1.352947e+02    9.322611e+01    4.206861e+01   -6.286347e-01   7.456566e+00   5.000000e-01   1.938207e-02
#  31  38    1.352239e+02    9.320618e+01    4.201767e+01   -2.917254e+00   3.603951e+00   3.125000e-02   1.347474e-02
#  32  24    1.352163e+02    9.295463e+01    4.226166e+01   -2.121109e-01   3.605597e+00   1.000000e+00   1.347781e-02
#  33  58    1.351720e+02    9.294882e+01    4.222321e+01   -2.878746e+00   1.056226e+00   1.562500e-02   7.294730e-03
#  34  36    1.351700e+02    9.295165e+01    4.221837e+01   -7.006038e-02   1.086636e+00   2.500000e-01   7.398996e-03
#  35  35    1.351695e+02    9.296436e+01    4.220514e+01   -8.951166e-02   1.200730e+00   5.000000e-01   7.777741e-03
#  36  45    1.351662e+02    9.296130e+01    4.220492e+01   -3.583252e-01   6.806477e-01   6.250000e-02   5.855878e-03
#  37  35    1.351598e+02    9.296445e+01    4.219538e+01   -1.790797e-01   1.038374e+00   1.250000e-01   7.232820e-03
#  38  36    1.351551e+02    9.296393e+01    4.219113e+01   -5.346721e-02   7.141996e-01   1.250000e-01   5.998472e-03
#  39  35    1.351502e+02    9.297072e+01    4.217943e+01   -8.348026e-03   4.829897e-01   1.000000e+00   4.932871e-03
#  40  62    1.351482e+02    9.297123e+01    4.217701e+01   -3.221341e-03   1.070571e-01   1.000000e+00   2.322408e-03
#  41  58    1.351476e+02    9.297496e+01    4.217262e+01   -9.720633e-04   4.693782e-02   1.000000e+00   1.537773e-03
#  42  69    1.351470e+02    9.298133e+01    4.216569e+01   -9.532590e-04   2.170725e-02   1.000000e+00   1.045763e-03
#  43  50    1.351470e+02    9.298319e+01    4.216378e+01   -8.513573e-05   3.197364e-02   1.000000e+00   1.269191e-03
#  44  56    1.351470e+02    9.298327e+01    4.216371e+01   -5.525360e-07   2.636468e-03   1.000000e+00   3.644534e-04
#  45  80    1.351470e+02    9.298327e+01    4.216371e+01   -3.623471e-11   1.078489e-05   1.250000e-01   2.330981e-05
#  46  81    1.351470e+02    9.298327e+01    4.216370e+01   -2.774224e-11   9.455108e-06   1.000000e+00   2.182549e-05
#  47  78    1.351470e+02    9.298327e+01    4.216370e+01   -1.669271e-17   7.813383e-08   9.765625e-04   1.984040e-06
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  7.813383314160723e-08
# Final cost:  135.1469738909853
# 0.1900737021378588 0.3693910818666201
# The relative error is: 17.2 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  98.12590627836434

# %%
# Generate random surface observations
ntargets_8 = 38
targets_x8 = np.linspace(-180., 0., ntargets_8) 
targets_y8 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_8)
targets_8 = np.zeros([ntargets_8, dim])
targets_8[:,0] = targets_x8; targets_8[:,1] = targets_y8

# Define regularization weights
eps = 1e-7  
gamma_val_TV = 1.5e-1  
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_8, xf, yf, utrue, mtrue, m_8, rel_error_8, lmbda_8, lmbda_R_8, noise_std_dev_8, kl_dist_8 ) = solveInverseProblem(k, targets_8, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 38
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    1.959890e+04    1.954744e+04    5.146569e+01   -3.078013e+05   2.272034e+04   1.000000e+00   5.000000e-01
#   2   1    6.547800e+03    6.495269e+03    5.253146e+01   -2.590970e+04   4.939856e+03   1.000000e+00   4.662832e-01
#   3   3    1.032238e+03    9.826753e+02    4.956219e+01   -1.111049e+04   8.304999e+02   1.000000e+00   1.911888e-01
#   4   5    2.925848e+02    2.435891e+02    4.899565e+01   -1.474051e+03   5.274987e+02   1.000000e+00   1.523713e-01
#   5  13    2.569851e+02    2.117190e+02    4.526602e+01   -2.499123e+02   1.305772e+02   5.000000e-01   7.580995e-02
#   6   1    1.986110e+02    1.530963e+02    4.551467e+01   -1.156399e+02   4.092875e+02   1.000000e+00   1.342168e-01
#   7  18    1.769626e+02    1.320831e+02    4.487951e+01   -7.780366e+01   7.299144e+01   5.000000e-01   5.667984e-02
#   8   1    1.699016e+02    1.249247e+02    4.497690e+01   -1.408492e+01   1.454589e+02   1.000000e+00   8.001340e-02
#   9  59    1.690279e+02    1.246473e+02    4.438059e+01   -1.216050e+02   3.912094e+01   1.562500e-02   4.149514e-02
#  10  17    1.611041e+02    1.170791e+02    4.402504e+01   -2.357351e+01   3.918251e+01   5.000000e-01   4.152778e-02
#  11   4    1.593725e+02    1.151968e+02    4.417562e+01   -3.454666e+00   5.825248e+01   1.000000e+00   5.063488e-02
#  12  68    1.591331e+02    1.151644e+02    4.396865e+01   -5.131380e+01   1.078763e+01   7.812500e-03   2.178992e-02
#  13  36    1.587976e+02    1.152320e+02    4.356563e+01   -1.077825e+02   1.418833e+01   7.812500e-03   2.498954e-02
#  14  18    1.561693e+02    1.119308e+02    4.423855e+01   -9.756204e+00   1.921606e+01   5.000000e-01   2.908204e-02
#  15   1    1.558117e+02    1.115519e+02    4.425980e+01   -7.148999e-01   3.479870e+01   1.000000e+00   3.913579e-02
#  16  54    1.550217e+02    1.107008e+02    4.432092e+01   -1.180232e+01   5.996593e+00   2.500000e-01   1.624594e-02
#  17   6    1.539262e+02    1.100333e+02    4.389297e+01   -2.159948e+00   3.172920e+01   1.000000e+00   3.736992e-02
#  18  18    1.532440e+02    1.082256e+02    4.501838e+01   -2.986498e+00   1.525555e+01   1.000000e+00   2.591233e-02
#  19  26    1.528278e+02    1.081465e+02    4.468131e+01   -1.012872e+01   1.421944e+01   1.250000e-01   2.501692e-02
#  20  16    1.526554e+02    1.080582e+02    4.459721e+01   -1.972092e+00   1.500807e+01   2.500000e-01   2.570130e-02
#  21  15    1.525714e+02    1.079859e+02    4.458545e+01   -2.686110e+00   1.589047e+01   2.500000e-01   2.644606e-02
#  22  10    1.524806e+02    1.081647e+02    4.431590e+01   -4.514931e-01   1.734438e+01   1.000000e+00   2.762943e-02
#  23  37    1.523920e+02    1.081048e+02    4.428722e+01   -5.842733e+00   6.995162e+00   6.250000e-02   1.754654e-02
#  24  31    1.523322e+02    1.079922e+02    4.434001e+01   -2.112498e+00   8.112016e+00   1.250000e-01   1.889544e-02
#  25  24    1.522326e+02    1.079585e+02    4.427414e+01   -4.514889e+00   8.920494e+00   6.250000e-02   1.981468e-02
#  26  17    1.521611e+02    1.079292e+02    4.423184e+01   -1.212964e+00   9.553438e+00   6.250000e-02   2.050560e-02
#  27  10    1.521006e+02    1.077357e+02    4.436484e+01   -1.207562e-01   9.190737e+00   1.000000e+00   2.011258e-02
#  28  61    1.517645e+02    1.070366e+02    4.472794e+01   -8.110620e-01   2.110216e+00   1.000000e+00   9.637315e-03
#  29  10    1.517404e+02    1.069182e+02    4.482218e+01   -4.800429e-02   4.809576e+00   1.000000e+00   1.454943e-02
#  30  65    1.516919e+02    1.068539e+02    4.483804e+01   -2.305525e-01   1.373997e+00   5.000000e-01   7.776522e-03
#  31  59    1.516851e+02    1.067959e+02    4.488913e+01   -1.024687e-01   7.662828e-01   5.000000e-01   5.807472e-03
#  32  58    1.516645e+02    1.067858e+02    4.487874e+01   -1.837352e-01   6.719431e-01   2.500000e-01   5.438246e-03
#  33  58    1.516620e+02    1.067605e+02    4.490143e+01   -4.808596e-02   4.625761e-01   5.000000e-01   4.512157e-03
#  34  56    1.516554e+02    1.067566e+02    4.489882e+01   -8.491646e-02   5.292855e-01   2.500000e-01   4.826559e-03
#  35  54    1.516532e+02    1.067504e+02    4.490275e+01   -2.783235e-02   4.172524e-01   2.500000e-01   4.285407e-03
#  36  45    1.516485e+02    1.067336e+02    4.491491e+01   -9.947578e-03   4.170221e-01   1.000000e+00   4.284224e-03
#  37  54    1.516414e+02    1.067273e+02    4.491413e+01   -9.514129e-03   2.365758e-01   1.000000e+00   3.226842e-03
#  38  61    1.516320e+02    1.067187e+02    4.491338e+01   -1.477828e-02   1.610707e-01   1.000000e+00   2.662569e-03
#  39  46    1.516305e+02    1.067176e+02    4.491287e+01   -4.521045e-03   1.740669e-01   1.000000e+00   2.767902e-03
#  40  38    1.516299e+02    1.067184e+02    4.491151e+01   -1.732029e-03   2.959611e-01   1.000000e+00   3.609192e-03
#  41  68    1.516298e+02    1.067177e+02    4.491206e+01   -2.168486e-04   6.455025e-02   1.000000e+00   1.685550e-03
#  42  73    1.516298e+02    1.067176e+02    4.491215e+01   -1.595901e-05   1.956061e-02   1.000000e+00   9.278630e-04
#  43  78    1.516298e+02    1.067176e+02    4.491217e+01   -4.730167e-07   2.805715e-03   1.000000e+00   3.514102e-04
#  44  93    1.516298e+02    1.067176e+02    4.491217e+01   -4.243867e-10   8.122418e-05   1.562500e-02   5.979093e-05
#  45  93    1.516298e+02    1.067176e+02    4.491217e+01   -4.112398e-10   7.995508e-05   9.765625e-04   5.932198e-05
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  7.99550808686716e-05
# Final cost:  151.62975603126685
# 0.09207924208104662 0.36038294866869486
# The relative error is: 14.5 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  105.44309093609095

# %%
# Generate random surface observations
ntargets_9 = 43 
targets_x9 = np.linspace(-180., 0., ntargets_9) 
targets_y9 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_9)
targets_9 = np.zeros([ntargets_9, dim])
targets_9[:,0] = targets_x9; targets_9[:,1] = targets_y9

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_9, xf, yf, utrue, mtrue, m_9, rel_error_9, lmbda_9, lmbda_R_9, noise_std_dev_9, kl_dist_9 ) = solveInverseProblem(k, targets_9, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 43
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    2.185521e+04    2.180383e+04    5.138129e+01   -3.495694e+05   2.576096e+04   1.000000e+00   5.000000e-01
#   2   1    7.393408e+03    7.340978e+03    5.243028e+01   -2.872381e+04   5.639697e+03   1.000000e+00   4.678933e-01
#   3   3    1.168749e+03    1.119290e+03    4.945861e+01   -1.254056e+04   9.505987e+02   1.000000e+00   1.920957e-01
#   4   5    3.404002e+02    2.914994e+02    4.890082e+01   -1.650818e+03   5.523161e+02   1.000000e+00   1.464242e-01
#   5  13    2.776457e+02    2.320828e+02    4.556295e+01   -2.926406e+02   1.544233e+02   5.000000e-01   7.742396e-02
#   6   1    2.293361e+02    1.835580e+02    4.577815e+01   -9.582300e+01   3.944113e+02   1.000000e+00   1.237353e-01
#   7  18    2.089307e+02    1.640338e+02    4.489687e+01   -8.962176e+01   8.651450e+01   5.000000e-01   5.795133e-02
#   8   1    1.962621e+02    1.512387e+02    4.502343e+01   -2.525767e+01   2.080246e+02   1.000000e+00   8.986204e-02
#   9  40    1.951372e+02    1.509816e+02    4.415554e+01   -2.312404e+02   4.854196e+01   7.812500e-03   4.340878e-02
#  10  11    1.861021e+02    1.412150e+02    4.488713e+01   -1.748929e+01   4.667797e+01   1.000000e+00   4.256718e-02
#  11  23    1.821831e+02    1.376913e+02    4.449183e+01   -1.235521e+01   1.911329e+01   5.000000e-01   2.723872e-02
#  12   2    1.817343e+02    1.372157e+02    4.451854e+01   -8.970400e-01   3.823952e+01   1.000000e+00   3.852789e-02
#  13  62    1.807598e+02    1.364436e+02    4.431628e+01   -1.826525e+01   5.014037e+00   1.250000e-01   1.395124e-02
#  14  24    1.801794e+02    1.348078e+02    4.537165e+01   -1.624406e+01   1.431220e+01   2.500000e-01   2.357068e-02
#  15   3    1.799179e+02    1.345207e+02    4.539711e+01   -5.229452e-01   2.867029e+01   1.000000e+00   3.336069e-02
#  16  56    1.788733e+02    1.344900e+02    4.438327e+01   -3.726752e+01   4.111992e+00   3.125000e-02   1.263412e-02
#  17  28    1.784914e+02    1.331952e+02    4.529616e+01   -5.981444e+00   1.106428e+01   5.000000e-01   2.072433e-02
#  18   2    1.782556e+02    1.329445e+02    4.531112e+01   -4.714171e-01   3.062174e+01   1.000000e+00   3.447735e-02
#  19  73    1.776856e+02    1.327202e+02    4.496545e+01   -1.538841e+01   3.081125e+00   6.250000e-02   1.093638e-02
#  20  38    1.774687e+02    1.324205e+02    4.504813e+01   -8.951807e+00   4.698162e+00   1.250000e-01   1.350464e-02
#  21  28    1.773207e+02    1.322779e+02    4.504288e+01   -1.011800e+01   1.251280e+01   6.250000e-02   2.203922e-02
#  22  11    1.771224e+02    1.317016e+02    4.542079e+01   -1.941101e+00   1.650693e+01   5.000000e-01   2.531350e-02
#  23   2    1.770398e+02    1.316092e+02    4.543065e+01   -1.651101e-01   1.830273e+01   1.000000e+00   2.665489e-02
#  24  62    1.769619e+02    1.315091e+02    4.545285e+01   -7.319005e+00   2.360388e+00   6.250000e-02   9.572175e-03
#  25  42    1.768383e+02    1.313684e+02    4.546992e+01   -5.160378e+00   4.914648e+00   1.250000e-01   1.381227e-02
#  26  23    1.766354e+02    1.312436e+02    4.539177e+01   -4.198203e+00   1.126744e+01   6.250000e-02   2.091373e-02
#  27  20    1.766148e+02    1.310453e+02    4.556952e+01   -1.764370e+00   1.150590e+01   1.250000e-01   2.113388e-02
#  28  17    1.765407e+02    1.309542e+02    4.558647e+01   -1.891319e+00   1.064256e+01   6.250000e-02   2.032554e-02
#  29  23    1.765333e+02    1.308108e+02    4.572254e+01   -1.618503e+00   1.029325e+01   1.250000e-01   1.998919e-02
#  30  20    1.765061e+02    1.307426e+02    4.576352e+01   -2.111481e+00   9.521134e+00   6.250000e-02   1.922486e-02
#  31  20    1.764569e+02    1.307336e+02    4.572329e+01   -3.037123e+00   9.438231e+00   3.125000e-02   1.914098e-02
#  32   9    1.764022e+02    1.304214e+02    4.598073e+01   -1.214385e-01   9.373946e+00   1.000000e+00   1.907569e-02
#  33  56    1.762672e+02    1.301861e+02    4.608108e+01   -4.007543e-01   1.859065e+00   1.000000e+00   8.495055e-03
#  34  25    1.762498e+02    1.301237e+02    4.612615e+01   -4.045572e-01   4.371454e+00   5.000000e-01   1.302662e-02
#  35  29    1.762358e+02    1.301250e+02    4.611080e+01   -1.485326e+00   2.419516e+00   3.125000e-02   9.691325e-03
#  36  30    1.762219e+02    1.301245e+02    4.609739e+01   -5.451813e-01   2.335226e+00   3.125000e-02   9.521020e-03
#  37  28    1.761925e+02    1.301282e+02    4.606435e+01   -1.127662e-01   2.227499e+00   5.000000e-01   9.298818e-03
#  38  28    1.761812e+02    1.301391e+02    4.604209e+01   -2.051544e-02   1.184506e+00   1.000000e+00   6.780905e-03
#  39  69    1.761777e+02    1.301357e+02    4.604203e+01   -5.642642e-03   1.855169e-01   1.000000e+00   2.683556e-03
#  40  74    1.761768e+02    1.301326e+02    4.604415e+01   -1.658696e-03   5.261680e-02   1.000000e+00   1.429161e-03
#  41  79    1.761767e+02    1.301318e+02    4.604494e+01   -1.011944e-04   1.169932e-02   1.000000e+00   6.739059e-04
#  42  82    1.761767e+02    1.301317e+02    4.604500e+01   -3.960328e-07   7.830424e-04   1.000000e+00   1.743458e-04
#  43  93    1.761767e+02    1.301317e+02    4.604500e+01   -5.699772e-12   3.350331e-06   1.000000e+00   1.140415e-05
#  44  89    1.761767e+02    1.301317e+02    4.604500e+01   -9.322152e-18   5.649412e-08   5.000000e-01   1.480882e-06
#
# Converged in  44  iterations.
# Termination reason:  Norm of the gradient less than tolerance
# Final gradient norm:  1.4848912990601494e-08
# Final cost:  176.1767323157095
# 0.10753500045331753 0.3607457299385698
# The relative error is: 15.0 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  103.24088602101118

# %%
# Generate random surface observations
ntargets_10 = 51 
targets_x10 = np.linspace(-180., 0., ntargets_10) 
targets_y10 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_10)
targets_10 = np.zeros([ntargets_10, dim])
targets_10[:,0] = targets_x10; targets_10[:,1] = targets_y10

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_10, xf, yf, utrue, mtrue, m_10, rel_error_10, lmbda_10, lmbda_R_10, noise_std_dev_10, kl_dist_10 ) = solveInverseProblem(k, targets_10, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 51
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    2.618909e+04    2.613754e+04    5.155660e+01   -4.168471e+05   3.077373e+04   1.000000e+00   5.000000e-01
#   2   1    8.646476e+03    8.593839e+03    5.263754e+01   -3.479791e+04   6.926364e+03   1.000000e+00   4.744196e-01
#   3   3    1.303386e+03    1.253695e+03    4.969087e+01   -1.478790e+04   1.166760e+03   1.000000e+00   1.947156e-01
#   4   5    3.664547e+02    3.171989e+02    4.925581e+01   -1.869632e+03   6.679056e+02   1.000000e+00   1.473220e-01
#   5  11    2.913692e+02    2.454681e+02    4.590111e+01   -2.960102e+02   1.791308e+02   5.000000e-01   7.629483e-02
#   6   1    2.539344e+02    2.078652e+02    4.606917e+01   -7.433672e+01   3.748874e+02   1.000000e+00   1.103724e-01
#   7  21    2.489742e+02    2.036797e+02    4.529449e+01   -1.002321e+02   9.700428e+01   5.000000e-01   5.614427e-02
#   8   1    2.178257e+02    1.723510e+02    4.547465e+01   -6.201947e+01   3.553924e+02   1.000000e+00   1.074642e-01
#   9  51    2.166820e+02    1.723582e+02    4.432382e+01   -5.231859e+02   5.329459e+01   3.906250e-03   4.161516e-02
#  10  15    2.066964e+02    1.608822e+02    4.581417e+01   -2.193473e+01   5.439218e+01   1.000000e+00   4.204150e-02
#  11   1    2.054787e+02    1.596301e+02    4.584864e+01   -2.433458e+00   7.778900e+01   1.000000e+00   5.027697e-02
#  12  65    2.033232e+02    1.576900e+02    4.563317e+01   -2.446270e+01   1.070032e+01   2.500000e-01   1.864698e-02
#  13   2    2.026121e+02    1.569759e+02    4.563621e+01   -1.421586e+00   6.025454e+01   1.000000e+00   4.424914e-02
#  14  67    2.011996e+02    1.570882e+02    4.411137e+01   -2.041440e+02   6.294078e+00   1.562500e-02   1.430132e-02
#  15   6    2.007796e+02    1.565987e+02    4.418085e+01   -8.368910e-01   3.338172e+01   1.000000e+00   3.293550e-02
#  16  76    2.004712e+02    1.562008e+02    4.427044e+01   -1.464042e+01   8.144139e+00   6.250000e-02   1.626794e-02
#  17  45    2.001094e+02    1.556970e+02    4.441242e+01   -2.182079e+01   1.284828e+01   1.250000e-01   2.043301e-02
#  18   2    1.999280e+02    1.555079e+02    4.442009e+01   -3.627349e-01   3.138726e+01   1.000000e+00   3.193645e-02
#  19  75    1.995835e+02    1.552977e+02    4.428582e+01   -1.700988e+01   6.895339e+00   6.250000e-02   1.496883e-02
#  20  21    1.994669e+02    1.548715e+02    4.459535e+01   -1.049896e+01   2.499973e+01   2.500000e-01   2.850215e-02
#  21   2    1.991161e+02    1.545122e+02    4.460390e+01   -7.013730e-01   4.377160e+01   1.000000e+00   3.771431e-02
#  22  70    1.984695e+02    1.542926e+02    4.417699e+01   -1.284707e+01   5.784916e+00   6.250000e-02   1.371066e-02
#  23  22    1.978939e+02    1.516709e+02    4.622306e+01   -2.450282e+00   1.667573e+01   1.000000e+00   2.327836e-02
#  24  10    1.974158e+02    1.518142e+02    4.560159e+01   -2.202795e+00   2.410185e+01   5.000000e-01   2.798563e-02
#  25   2    1.972499e+02    1.516476e+02    4.560231e+01   -3.317112e-01   2.932387e+01   1.000000e+00   3.086886e-02
#  26  67    1.972317e+02    1.514851e+02    4.574667e+01   -3.348107e+00   3.238757e+00   1.250000e-01   1.025886e-02
#  27  26    1.969605e+02    1.513535e+02    4.560699e+01   -4.890963e+00   1.047121e+01   1.250000e-01   1.844627e-02
#  28   3    1.969097e+02    1.513116e+02    4.559813e+01   -1.015933e-01   1.625810e+01   1.000000e+00   2.298502e-02
#  29  72    1.968368e+02    1.512313e+02    4.560548e+01   -2.273727e+00   2.400164e+00   6.250000e-02   8.831417e-03
#  30  47    1.967678e+02    1.509395e+02    4.582831e+01   -3.622752e+00   3.638138e+00   2.500000e-01   1.087300e-02
#  31  11    1.965766e+02    1.505080e+02    4.606857e+01   -3.294256e-01   1.496282e+01   1.000000e+00   2.205041e-02
#  32  29    1.964924e+02    1.504421e+02    4.605026e+01   -7.624571e-01   5.419179e+00   1.250000e-01   1.327018e-02
#  33  21    1.963698e+02    1.500493e+02    4.632056e+01   -2.433791e-01   5.938521e+00   1.000000e+00   1.389150e-02
#  34  72    1.962753e+02    1.499646e+02    4.631068e+01   -3.228101e-01   1.290277e+00   5.000000e-01   6.475174e-03
#  35  70    1.962619e+02    1.499441e+02    4.631782e+01   -7.939018e-01   1.199039e+00   1.250000e-01   6.242041e-03
#  36  63    1.962603e+02    1.499170e+02    4.634325e+01   -1.849769e-01   8.397634e-01   2.500000e-01   5.223823e-03
#  37  71    1.962562e+02    1.499009e+02    4.635528e+01   -1.122230e+00   9.961860e-01   1.250000e-01   5.689580e-03
#  38  60    1.962240e+02    1.498842e+02    4.633979e+01   -1.461549e-01   6.168058e-01   2.500000e-01   4.476970e-03
#  39  70    1.962192e+02    1.498752e+02    4.634397e+01   -4.833812e-02   4.559179e-01   1.250000e-01   3.849048e-03
#  40  61    1.962121e+02    1.498096e+02    4.640251e+01   -1.361347e-02   3.663575e-01   1.000000e+00   3.450345e-03
#  41  60    1.962119e+02    1.498071e+02    4.640482e+01   -4.013055e-04   7.825096e-02   1.000000e+00   1.594611e-03
#  42  91    1.962119e+02    1.498070e+02    4.640492e+01   -1.783781e-05   1.223305e-02   1.000000e+00   6.304888e-04
#  43 100    1.962119e+02    1.498070e+02    4.640492e+01   -1.039015e-07   9.428151e-04   1.000000e+00   1.750343e-04
#  44 100    1.962119e+02    1.498070e+02    4.640492e+01   -8.075057e-12   8.892830e-06   9.765625e-04   1.699926e-05
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  8.892830436767018e-06
# Final cost:  196.21187690453397
# 0.1656625109483194 0.36265263100362005
# The relative error is: 14.6 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  115.86203035008174

# %%
# Generate random surface observations
ntargets_11 = 56 
targets_x11 = np.linspace(-180., 0., ntargets_11) 
targets_y11 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_11)
targets_11 = np.zeros([ntargets_11, dim])
targets_11[:,0] = targets_x11; targets_11[:,1] = targets_y11

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_11, xf, yf, utrue, mtrue, m_11, rel_error_11, lmbda_11, lmbda_R_11, noise_std_dev_11, kl_dist_11 ) = solveInverseProblem(k, targets_11, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 56
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    2.861684e+04    2.856520e+04    5.163642e+01   -4.621293e+05   3.398847e+04   1.000000e+00   5.000000e-01
#   2   1    9.720277e+03    9.667546e+03    5.273140e+01   -3.743829e+04   7.343752e+03   1.000000e+00   4.648290e-01
#   3   3    1.520135e+03    1.470437e+03    4.969813e+01   -1.652756e+04   1.353412e+03   1.000000e+00   1.995488e-01
#   4   5    4.376492e+02    3.885474e+02    4.910185e+01   -2.157111e+03   7.419396e+02   1.000000e+00   1.477469e-01
#   5  13    3.479678e+02    3.021578e+02    4.580997e+01   -3.883935e+02   2.188278e+02   5.000000e-01   8.023898e-02
#   6   1    2.900262e+02    2.440100e+02    4.601614e+01   -1.149163e+02   4.910750e+02   1.000000e+00   1.202010e-01
#   7  17    2.553563e+02    2.095053e+02    4.585104e+01   -1.140160e+02   1.221415e+02   5.000000e-01   5.994678e-02
#   8   2    2.463283e+02    2.002941e+02    4.603416e+01   -1.793665e+01   1.837971e+02   1.000000e+00   7.353660e-02
#   9  54    2.446136e+02    1.995985e+02    4.501507e+01   -3.291887e+02   4.962933e+01   7.812500e-03   3.821232e-02
#  10  37    2.438751e+02    1.989289e+02    4.494615e+01   -4.649248e+02   5.444649e+01   7.812500e-03   4.002388e-02
#  11  24    2.402725e+02    1.952067e+02    4.506574e+01   -7.401401e+01   7.794373e+01   1.250000e-01   4.788779e-02
#  12   3    2.346152e+02    1.892735e+02    4.534177e+01   -1.125286e+01   1.225802e+02   1.000000e+00   6.005433e-02
#  13  39    2.308182e+02    1.846911e+02    4.612711e+01   -6.766161e+01   3.055627e+01   1.250000e-01   2.998364e-02
#  14  28    2.300327e+02    1.843499e+02    4.568281e+01   -4.255615e+02   5.627655e+01   1.953125e-03   4.069096e-02
#  15  11    2.247758e+02    1.779595e+02    4.681629e+01   -1.030809e+01   5.345704e+01   1.000000e+00   3.965853e-02
#  16  67    2.231023e+02    1.772865e+02    4.581580e+01   -2.392400e+01   7.038587e+00   1.250000e-01   1.439054e-02
#  17  15    2.213114e+02    1.743292e+02    4.698218e+01   -3.754007e+00   4.129569e+01   1.000000e+00   3.485672e-02
#  18  59    2.201551e+02    1.732322e+02    4.692290e+01   -9.603859e+00   7.355856e+00   2.500000e-01   1.471129e-02
#  19  45    2.197976e+02    1.730241e+02    4.677351e+01   -1.035947e+01   1.613940e+01   6.250000e-02   2.179104e-02
#  20  44    2.194290e+02    1.718789e+02    4.755015e+01   -6.370322e+00   1.456960e+01   2.500000e-01   2.070418e-02
#  21  39    2.191807e+02    1.714759e+02    4.770480e+01   -5.313454e+00   1.017796e+01   2.500000e-01   1.730472e-02
#  22  37    2.189300e+02    1.714184e+02    4.751155e+01   -2.319338e+01   1.153357e+01   3.125000e-02   1.842113e-02
#  23  37    2.187463e+02    1.713104e+02    4.743589e+01   -6.096185e+00   1.216907e+01   6.250000e-02   1.892182e-02
#  24  29    2.186519e+02    1.712288e+02    4.742309e+01   -8.581747e+00   1.202563e+01   3.125000e-02   1.880997e-02
#  25  27    2.185812e+02    1.711781e+02    4.740314e+01   -3.227577e+00   1.177551e+01   3.125000e-02   1.861333e-02
#  26  15    2.183284e+02    1.705399e+02    4.778856e+01   -5.055409e-01   1.148078e+01   1.000000e+00   1.837892e-02
#  27  71    2.181070e+02    1.701080e+02    4.799894e+01   -6.473736e-01   2.073706e+00   5.000000e-01   7.811021e-03
#  28  59    2.180398e+02    1.698905e+02    4.814930e+01   -3.124572e-01   2.113400e+00   5.000000e-01   7.885424e-03
#  29  59    2.180097e+02    1.698183e+02    4.819142e+01   -2.307800e-01   1.635541e+00   2.500000e-01   6.936891e-03
#  30  56    2.179907e+02    1.697110e+02    4.827969e+01   -1.402538e-01   1.664835e+00   5.000000e-01   6.998740e-03
#  31  58    2.179880e+02    1.696176e+02    4.837041e+01   -1.543133e-01   1.215697e+00   5.000000e-01   5.980630e-03
#  32  54    2.179821e+02    1.695962e+02    4.838586e+01   -2.699633e-01   1.363483e+00   2.500000e-01   6.333724e-03
#  33  57    2.179630e+02    1.695637e+02    4.839932e+01   -2.132551e-01   1.609711e+00   2.500000e-01   6.881897e-03
#  34  48    2.179510e+02    1.695529e+02    4.839809e+01   -8.637927e-02   1.516517e+00   2.500000e-01   6.679714e-03
#  35  47    2.179400e+02    1.695077e+02    4.843238e+01   -1.849818e-02   1.100519e+00   1.000000e+00   5.690271e-03
#  36  59    2.179341e+02    1.695201e+02    4.841404e+01   -9.800346e-03   2.897970e-01   1.000000e+00   2.919989e-03
#  37  59    2.179325e+02    1.695251e+02    4.840744e+01   -2.698094e-03   2.441719e-01   1.000000e+00   2.680291e-03
#  38  58    2.179324e+02    1.695271e+02    4.840527e+01   -2.473216e-04   1.248003e-01   1.000000e+00   1.916205e-03
#  39  59    2.179324e+02    1.695272e+02    4.840521e+01   -2.033030e-06   1.438500e-02   1.000000e+00   6.505628e-04
#  40 100    2.179324e+02    1.695272e+02    4.840521e+01   -1.559795e-09   1.228294e-04   5.000000e-01   6.011534e-05
#  41 100    2.179324e+02    1.695272e+02    4.840521e+01   -3.899549e-10   6.139858e-05   9.765625e-04   4.250239e-05
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  6.139858239586504e-05
# Final cost:  217.93241159940186
# 0.13640133261810528 0.3623550852742437
# The relative error is: 14.3 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  119.55162014780332

# %%
# Generate random surface observations
ntargets_12 = 61 
targets_x12 = np.linspace(-180., 0., ntargets_12) 
targets_y12 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_12)
targets_12 = np.zeros([ntargets_12, dim])
targets_12[:,0] = targets_x12; targets_12[:,1] = targets_y12

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_12, xf, yf, utrue, mtrue, m_12, rel_error_12, lmbda_12, lmbda_R_12, noise_std_dev_12, kl_dist_12 ) = solveInverseProblem(k, targets_12, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 61
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    3.130719e+04    3.125568e+04    5.151296e+01   -5.003162e+05   3.684137e+04   1.000000e+00   5.000000e-01
#   2   1    1.061055e+04    1.055798e+04    5.257849e+01   -4.107496e+04   8.107269e+03   1.000000e+00   4.691043e-01
#   3   3    1.685309e+03    1.635700e+03    4.960954e+01   -1.799105e+04   1.403357e+03   1.000000e+00   1.951714e-01
#   4   5    4.798995e+02    4.307151e+02    4.918442e+01   -2.405567e+03   8.521019e+02   1.000000e+00   1.520820e-01
#   5  14    4.575272e+02    4.121545e+02    4.537265e+01   -4.354874e+02   2.047586e+02   5.000000e-01   7.455096e-02
#   6   1    3.144964e+02    2.688034e+02    4.569294e+01   -2.827880e+02   8.124724e+02   1.000000e+00   1.485034e-01
#   7  15    2.875957e+02    2.383967e+02    4.919897e+01   -1.163563e+02   1.272634e+02   1.000000e+00   5.877382e-02
#   8   1    2.582905e+02    2.088994e+02    4.939111e+01   -5.840728e+01   3.744596e+02   1.000000e+00   1.008172e-01
#   9  27    2.554062e+02    2.068975e+02    4.850867e+01   -2.621136e+03   3.689249e+01   1.953125e-03   3.164471e-02
#  10   4    2.536342e+02    2.051916e+02    4.844266e+01   -3.530105e+00   7.309307e+01   1.000000e+00   4.454205e-02
#  11  68    2.507281e+02    2.036481e+02    4.707997e+01   -5.568808e+01   1.376537e+01   1.250000e-01   1.932974e-02
#  12   2    2.485946e+02    2.014742e+02    4.712042e+01   -4.263584e+00   1.115554e+02   1.000000e+00   5.502721e-02
#  13  69    2.461729e+02    1.991230e+02    4.704992e+01   -3.644535e+01   1.166249e+01   1.250000e-01   1.779212e-02
#  14   2    2.455529e+02    1.984920e+02    4.706090e+01   -1.239485e+00   6.358178e+01   1.000000e+00   4.154306e-02
#  15  83    2.447960e+02    1.977399e+02    4.705601e+01   -5.374817e+01   1.131665e+01   6.250000e-02   1.752633e-02
#  16   2    2.442168e+02    1.971431e+02    4.707369e+01   -1.157904e+00   5.922209e+01   1.000000e+00   4.009350e-02
#  17  66    2.428680e+02    1.956719e+02    4.719616e+01   -2.999251e+01   1.014904e+01   1.250000e-01   1.659757e-02
#  18   2    2.422659e+02    1.950561e+02    4.720981e+01   -1.203597e+00   6.171897e+01   1.000000e+00   4.092997e-02
#  19  71    2.415461e+02    1.944679e+02    4.707817e+01   -3.907631e+01   9.521359e+00   6.250000e-02   1.607613e-02
#  20   7    2.400911e+02    1.922749e+02    4.781616e+01   -2.881354e+00   4.552846e+01   1.000000e+00   3.515391e-02
#  21  64    2.396949e+02    1.917004e+02    4.799454e+01   -2.022816e+01   1.131657e+01   6.250000e-02   1.752627e-02
#  22  23    2.394224e+02    1.907917e+02    4.863067e+01   -1.205780e+01   1.712381e+01   2.500000e-01   2.155919e-02
#  23   2    2.387640e+02    1.901261e+02    4.863788e+01   -1.316268e+00   6.332049e+01   1.000000e+00   4.145761e-02
#  24  74    2.379790e+02    1.897623e+02    4.821670e+01   -2.116329e+01   8.937010e+00   6.250000e-02   1.557501e-02
#  25  18    2.367405e+02    1.870469e+02    4.969361e+01   -5.825287e+00   2.487199e+01   5.000000e-01   2.598289e-02
#  26  15    2.363817e+02    1.864637e+02    4.991798e+01   -4.477975e+00   2.656446e+01   5.000000e-01   2.685237e-02
#  27   2    2.360068e+02    1.860806e+02    4.992620e+01   -7.496470e-01   4.759685e+01   1.000000e+00   3.594357e-02
#  28  78    2.354981e+02    1.859672e+02    4.953089e+01   -9.587082e+00   3.803010e+00   6.250000e-02   1.016005e-02
#  29  18    2.347552e+02    1.842450e+02    5.051027e+01   -1.501911e+00   1.616583e+01   1.000000e+00   2.094745e-02
#  30  49    2.344601e+02    1.841541e+02    5.030601e+01   -2.450534e+00   5.363248e+00   2.500000e-01   1.206552e-02
#  31  53    2.343120e+02    1.839890e+02    5.032298e+01   -1.651147e+00   5.592340e+00   2.500000e-01   1.232052e-02
#  32  17    2.342024e+02    1.839548e+02    5.024765e+01   -1.834088e+00   9.290318e+00   1.250000e-01   1.587989e-02
#  33  16    2.341549e+02    1.838687e+02    5.028615e+01   -3.596854e-01   1.153150e+01   2.500000e-01   1.769192e-02
#  34  26    2.341516e+02    1.835790e+02    5.057257e+01   -1.050197e+00   9.572325e+00   5.000000e-01   1.611910e-02
#  35   2    2.341242e+02    1.835487e+02    5.057549e+01   -5.478429e-02   1.297752e+01   1.000000e+00   1.876843e-02
#  36  91    2.340377e+02    1.835527e+02    5.048503e+01   -1.379692e+00   1.427268e+00   1.250000e-01   6.224218e-03
#  37  21    2.340055e+02    1.835543e+02    5.045123e+01   -1.433869e+00   9.538920e+00   6.250000e-02   1.609095e-02
#  38  18    2.339896e+02    1.835408e+02    5.044881e+01   -2.181528e-01   9.513143e+00   1.250000e-01   1.606919e-02
#  39   2    2.339782e+02    1.835281e+02    5.045017e+01   -2.270817e-02   8.547434e+00   1.000000e+00   1.523176e-02
#  40  79    2.339511e+02    1.834794e+02    5.047177e+01   -2.035568e-01   1.220868e+00   1.000000e+00   5.756604e-03
#  41  68    2.339216e+02    1.834763e+02    5.044534e+01   -9.829868e-01   1.106807e+00   3.125000e-02   5.481103e-03
#  42  43    2.339135e+02    1.834637e+02    5.044985e+01   -9.076498e-02   1.288977e+00   2.500000e-01   5.915000e-03
#  43  49    2.339096e+02    1.834615e+02    5.044811e+01   -1.205082e-02   7.716973e-01   5.000000e-01   4.576733e-03
#  44  38    2.339081e+02    1.834558e+02    5.045227e+01   -2.519731e-03   3.600244e-01   1.000000e+00   3.126065e-03
#  45  82    2.339077e+02    1.834552e+02    5.045247e+01   -7.187066e-04   5.659057e-02   1.000000e+00   1.239379e-03
#  46  69    2.339077e+02    1.834548e+02    5.045291e+01   -5.740582e-05   1.834137e-02   1.000000e+00   7.055828e-04
#  47  96    2.339077e+02    1.834547e+02    5.045296e+01   -8.105217e-07   1.493984e-03   1.000000e+00   2.013748e-04
#  48 100    2.339077e+02    1.834547e+02    5.045296e+01   -3.119200e-10   3.178927e-05   1.000000e+00   2.937463e-05
#  49 100    2.339077e+02    1.834547e+02    5.045296e+01   -7.007522e-17   4.941992e-08   1.000000e+00   1.158199e-06
#  50 100    2.339077e+02    1.834547e+02    5.045296e+01   -4.990356e-18   3.733233e-08   1.000000e+00   1.006641e-06
#
# Converged in  50  iterations.
# Termination reason:  Norm of the gradient less than tolerance
# Final gradient norm:  2.065852785598961e-08
# Final cost:  233.90767858357043
# 0.12855613295765994 0.3592530428295967
# The relative error is: 14.1 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  122.01335026490706

# %%
# Generate random surface observations
ntargets_13 = 66 
targets_x13 = np.linspace(-180., 0., ntargets_13) 
targets_y13 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_13)
targets_13 = np.zeros([ntargets_13, dim])
targets_13[:,0] = targets_x13; targets_13[:,1] = targets_y13

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_13, xf, yf, utrue, mtrue, m_13, rel_error_13, lmbda_13, lmbda_R_13, noise_std_dev_13, kl_dist_13 ) = solveInverseProblem(k, targets_13, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 66
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    3.366910e+04    3.361740e+04    5.170389e+01   -5.476578e+05   4.029097e+04   1.000000e+00   5.000000e-01
#   2   1    1.133009e+04    1.127729e+04    5.279970e+01   -4.424523e+04   8.873680e+03   1.000000e+00   4.692973e-01
#   3   3    1.796869e+03    1.747143e+03    4.972598e+01   -1.920880e+04   1.619234e+03   1.000000e+00   2.004707e-01
#   4   5    5.114519e+02    4.622157e+02    4.923623e+01   -2.564803e+03   8.954111e+02   1.000000e+00   1.490759e-01
#   5  12    3.969417e+02    3.508022e+02    4.613947e+01   -4.459972e+02   2.399305e+02   5.000000e-01   7.716828e-02
#   6   1    3.419428e+02    2.956231e+02    4.631971e+01   -1.091709e+02   5.183241e+02   1.000000e+00   1.134219e-01
#   7  19    3.238821e+02    2.777979e+02    4.608425e+01   -1.487623e+02   1.330421e+02   5.000000e-01   5.746332e-02
#   8   1    2.876850e+02    2.414288e+02    4.625619e+01   -7.209356e+01   4.374663e+02   1.000000e+00   1.042002e-01
#   9  33    2.849371e+02    2.396219e+02    4.531517e+01   -2.614245e+02   7.469521e+01   1.562500e-02   4.305688e-02
#  10  10    2.728035e+02    2.267592e+02    4.604434e+01   -2.386951e+01   7.743106e+01   1.000000e+00   4.383830e-02
#  11  49    2.647739e+02    2.152415e+02    4.953240e+01   -3.925180e+01   1.806366e+01   5.000000e-01   2.117381e-02
#  12   2    2.624255e+02    2.127905e+02    4.963504e+01   -4.691605e+00   9.952239e+01   1.000000e+00   4.970002e-02
#  13  74    2.622954e+02    2.127673e+02    4.952810e+01   -1.437593e+02   1.303761e+01   6.250000e-02   1.798851e-02
#  14   5    2.612458e+02    2.114782e+02    4.976752e+01   -2.089323e+00   6.130093e+01   1.000000e+00   3.900585e-02
#  15  86    2.591539e+02    2.112801e+02    4.787375e+01   -1.382864e+02   1.134219e+01   3.125000e-02   1.677817e-02
#  16  16    2.582494e+02    2.055592e+02    5.269014e+01   -7.658134e+00   3.136726e+01   1.000000e+00   2.790194e-02
#  17   7    2.567693e+02    2.055487e+02    5.122060e+01   -4.915465e+00   6.336336e+01   1.000000e+00   3.965658e-02
#  18   2    2.562063e+02    2.049685e+02    5.123783e+01   -1.125673e+00   6.231548e+01   1.000000e+00   3.932730e-02
#  19 100    2.559186e+02    2.049625e+02    5.095613e+01   -6.771882e+01   8.153172e+00   1.562500e-02   1.422523e-02
#  20 100    2.557842e+02    2.049086e+02    5.087565e+01   -6.907137e+01   1.156394e+01   7.812500e-03   1.694139e-02
#  21  66    2.556353e+02    2.047985e+02    5.083679e+01   -2.171464e+01   8.581056e+00   6.250000e-02   1.459374e-02
#  22  43    2.546017e+02    2.037567e+02    5.084508e+01   -6.463324e+00   2.381090e+01   5.000000e-01   2.430995e-02
#  23  37    2.541066e+02    2.034792e+02    5.062742e+01   -6.729185e+00   2.894881e+01   2.500000e-01   2.680474e-02
#  24  42    2.540524e+02    2.033277e+02    5.072476e+01   -1.239685e+01   2.648596e+01   1.250000e-01   2.563917e-02
#  25  42    2.540104e+02    2.032480e+02    5.076243e+01   -9.282832e+00   2.260346e+01   1.250000e-01   2.368556e-02
#  26  65    2.536440e+02    2.032192e+02    5.042485e+01   -2.968023e+01   1.932586e+01   3.125000e-02   2.190108e-02
#  27  74    2.535234e+02    2.032134e+02    5.030994e+01   -3.246905e+01   1.776663e+01   7.812500e-03   2.099900e-02
#  28  37    2.533994e+02    2.031249e+02    5.027449e+01   -2.187423e+00   1.750532e+01   1.250000e-01   2.084401e-02
#  29  34    2.533769e+02    2.030653e+02    5.031156e+01   -1.656333e+00   1.500410e+01   1.250000e-01   1.929750e-02
#  30  43    2.533496e+02    2.030590e+02    5.029062e+01   -4.905521e+00   1.322815e+01   3.125000e-02   1.811948e-02
#  31  42    2.532981e+02    2.030528e+02    5.024532e+01   -5.666888e+00   1.279308e+01   1.562500e-02   1.781901e-02
#  32  34    2.532880e+02    2.029154e+02    5.037257e+01   -5.533421e-01   1.261499e+01   5.000000e-01   1.769455e-02
#  33  59    2.531816e+02    2.029123e+02    5.026930e+01   -3.508796e+01   6.164524e+00   3.906250e-03   1.236932e-02
#  34  34    2.531710e+02    2.028945e+02    5.027643e+01   -3.370144e-01   6.144992e+00   1.250000e-01   1.234971e-02
#  35  42    2.531691e+02    2.028723e+02    5.029680e+01   -4.988196e-01   5.386923e+00   1.250000e-01   1.156289e-02
#  36  45    2.531439e+02    2.028710e+02    5.027292e+01   -1.850020e+00   4.747773e+00   1.562500e-02   1.085528e-02
#  37  34    2.530986e+02    2.027548e+02    5.034375e+01   -8.097969e-02   4.582235e+00   1.000000e+00   1.066436e-02
#  38  81    2.530823e+02    2.027425e+02    5.033975e+01   -2.905785e-02   2.947548e-01   1.000000e+00   2.704747e-03
#  39  86    2.530785e+02    2.027394e+02    5.033902e+01   -6.423175e-03   1.178867e-01   1.000000e+00   1.710521e-03
#  40  96    2.530780e+02    2.027389e+02    5.033915e+01   -8.209005e-04   4.078973e-02   1.000000e+00   1.006171e-03
#  41  93    2.530780e+02    2.027388e+02    5.033918e+01   -8.925065e-06   4.687139e-03   1.000000e+00   3.410752e-04
#  42 100    2.530780e+02    2.027388e+02    5.033917e+01   -2.654376e-09   7.874298e-05   1.000000e+00   4.420812e-05
#  43 100    2.530780e+02    2.027388e+02    5.033917e+01   -8.426076e-16   1.267948e-07   9.765625e-04   1.773972e-06
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  1.2679476186143714e-07
# Final cost:  253.0780240720119
# 0.07922999996742555 0.36246352427205847
# The relative error is: 15.5 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  123.85377228577295

# %%
# Generate random surface observations
ntargets_14 = 73 
targets_x14 = np.linspace(-180., 0., ntargets_14) 
targets_y14 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_14)
targets_14 = np.zeros([ntargets_14, dim])
targets_14[:,0] = targets_x14; targets_14[:,1] = targets_y14

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_14, xf, yf, utrue, mtrue, m_14, rel_error_14, lmbda_14, lmbda_R_14, noise_std_dev_14, kl_dist_14 ) = solveInverseProblem(k, targets_14, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 73
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    3.709447e+04    3.704279e+04    5.167502e+01   -6.049768e+05   4.435871e+04   1.000000e+00   5.000000e-01
#   2   3    2.285388e+03    2.236034e+03    4.935429e+01   -7.028079e+04   9.584351e+03   1.000000e+00   4.648276e-01
#   3   4    7.738191e+02    7.239099e+02    4.990919e+01   -3.023826e+03   1.770021e+03   1.000000e+00   1.997560e-01
#   4  10    5.284681e+02    4.819463e+02    4.652179e+01   -8.620645e+02   3.480130e+02   1.000000e+00   8.857442e-02
#   5   1    3.521083e+02    3.052937e+02    4.681463e+01   -3.529157e+02   9.781571e+02   1.000000e+00   1.484960e-01
#   6   6    3.317727e+02    2.853717e+02    4.640095e+01   -4.104517e+01   2.489146e+02   1.000000e+00   7.490930e-02
#   7 100    3.314525e+02    2.835466e+02    4.790584e+01   -8.983004e+02   3.328698e+01   3.906250e-03   2.739351e-02
#   8  23    3.139087e+02    2.658493e+02    4.805935e+01   -7.909513e+01   5.129980e+01   5.000000e-01   3.400700e-02
#   9   4    3.059146e+02    2.578403e+02    4.807433e+01   -1.597111e+01   1.779292e+02   1.000000e+00   6.333361e-02
#  10  67    3.032256e+02    2.567269e+02    4.649870e+01   -7.801074e+01   1.991514e+01   1.250000e-01   2.118860e-02
#  11   3    3.007233e+02    2.541461e+02    4.657724e+01   -4.999592e+00   9.243678e+01   1.000000e+00   4.564918e-02
#  12  64    2.995266e+02    2.532135e+02    4.631301e+01   -9.317155e+01   1.636487e+01   6.250000e-02   1.920733e-02
#  13  20    2.964736e+02    2.506449e+02    4.582876e+01   -2.475559e+01   3.317940e+01   2.500000e-01   2.734921e-02
#  14   4    2.955559e+02    2.496909e+02    4.586494e+01   -1.831627e+00   5.832768e+01   1.000000e+00   3.626168e-02
#  15  71    2.949426e+02    2.490585e+02    4.588416e+01   -3.993632e+01   1.380226e+01   6.250000e-02   1.763947e-02
#  16  17    2.938974e+02    2.479515e+02    4.594593e+01   -1.446791e+01   3.820000e+01   2.500000e-01   2.934555e-02
#  17   2    2.934246e+02    2.474660e+02    4.595858e+01   -9.454196e-01   5.780199e+01   1.000000e+00   3.609790e-02
#  18  71    2.926705e+02    2.473362e+02    4.533432e+01   -6.937878e+01   1.214401e+01   1.562500e-02   1.654594e-02
#  19  42    2.917775e+02    2.438707e+02    4.790680e+01   -1.593321e+01   1.668896e+01   5.000000e-01   1.939658e-02
#  20   1    2.905497e+02    2.426039e+02    4.794585e+01   -2.454245e+00   8.897745e+01   1.000000e+00   4.478685e-02
#  21  76    2.891342e+02    2.426928e+02    4.644144e+01   -4.193729e+01   7.761252e+00   6.250000e-02   1.322746e-02
#  22   3    2.887092e+02    2.422545e+02    4.645471e+01   -8.500287e-01   5.106987e+01   1.000000e+00   3.393071e-02
#  23  75    2.885891e+02    2.421786e+02    4.641055e+01   -7.019208e+01   8.129733e+00   1.562500e-02   1.353782e-02
#  24  48    2.885438e+02    2.420298e+02    4.651395e+01   -3.101642e+01   8.726014e+00   3.125000e-02   1.402551e-02
#  25  27    2.882699e+02    2.419013e+02    4.636858e+01   -2.827503e+01   1.146090e+01   3.125000e-02   1.607385e-02
#  26  29    2.880415e+02    2.417628e+02    4.627873e+01   -1.553613e+01   1.363290e+01   3.125000e-02   1.753092e-02
#  27  37    2.879218e+02    2.416200e+02    4.630185e+01   -1.109085e+01   1.419469e+01   3.125000e-02   1.788848e-02
#  28  37    2.878620e+02    2.413369e+02    4.652514e+01   -8.475888e+00   1.406675e+01   6.250000e-02   1.780769e-02
#  29  27    2.877506e+02    2.412097e+02    4.654082e+01   -1.686853e+01   1.390407e+01   3.125000e-02   1.770441e-02
#  30  26    2.876817e+02    2.411037e+02    4.657801e+01   -1.358566e+01   1.450803e+01   3.125000e-02   1.808484e-02
#  31  26    2.876429e+02    2.409883e+02    4.665465e+01   -1.483792e+01   1.493067e+01   3.125000e-02   1.834637e-02
#  32  26    2.875559e+02    2.408969e+02    4.665902e+01   -1.290696e+01   1.534139e+01   3.125000e-02   1.859700e-02
#  33  26    2.875163e+02    2.407845e+02    4.673178e+01   -1.331483e+01   1.570785e+01   3.125000e-02   1.881780e-02
#  34  26    2.874524e+02    2.406953e+02    4.675710e+01   -1.207824e+01   1.591051e+01   3.125000e-02   1.893881e-02
#  35  26    2.874161e+02    2.405930e+02    4.682315e+01   -1.290171e+01   1.614839e+01   3.125000e-02   1.907986e-02
#  36  26    2.873559e+02    2.405111e+02    4.684486e+01   -1.162045e+01   1.633349e+01   3.125000e-02   1.918890e-02
#  37  26    2.873234e+02    2.404163e+02    4.690710e+01   -1.236736e+01   1.652713e+01   3.125000e-02   1.930231e-02
#  38  26    2.872702e+02    2.403403e+02    4.692994e+01   -1.123723e+01   1.663914e+01   3.125000e-02   1.936761e-02
#  39  26    2.872425e+02    2.402535e+02    4.698903e+01   -1.204884e+01   1.678342e+01   3.125000e-02   1.945140e-02
#  40  26    2.871930e+02    2.401838e+02    4.700927e+01   -1.097717e+01   1.687420e+01   3.125000e-02   1.950393e-02
#  41  26    2.871687e+02    2.401030e+02    4.706570e+01   -1.175497e+01   1.698515e+01   3.125000e-02   1.956795e-02
#  42  26    2.871238e+02    2.400385e+02    4.708521e+01   -1.074538e+01   1.706091e+01   3.125000e-02   1.961154e-02
#  43  26    2.871027e+02    2.399637e+02    4.713901e+01   -1.154025e+01   1.716968e+01   3.125000e-02   1.967395e-02
#  44  22    2.870561e+02    2.399020e+02    4.715413e+01   -1.044511e+01   1.722385e+01   3.125000e-02   1.970497e-02
#  45  26    2.870393e+02    2.398316e+02    4.720772e+01   -1.115466e+01   1.731103e+01   3.125000e-02   1.975477e-02
#  46  25    2.869989e+02    2.397738e+02    4.722508e+01   -1.026886e+01   1.732078e+01   3.125000e-02   1.976033e-02
#  47  22    2.869783e+02    2.397033e+02    4.727498e+01   -1.091561e+01   1.739227e+01   3.125000e-02   1.980107e-02
#  48  24    2.869461e+02    2.396488e+02    4.729733e+01   -1.006923e+01   1.739426e+01   3.125000e-02   1.980220e-02
#  49  23    2.869310e+02    2.395846e+02    4.734640e+01   -1.094954e+01   1.744522e+01   3.125000e-02   1.983119e-02
#  50  25    2.868994e+02    2.395360e+02    4.736340e+01   -1.009948e+01   1.746244e+01   3.125000e-02   1.984098e-02
#  51  25    2.868889e+02    2.394777e+02    4.741121e+01   -1.096186e+01   1.751913e+01   3.125000e-02   1.987315e-02
#  52  25    2.868575e+02    2.394342e+02    4.742330e+01   -1.010907e+01   1.753669e+01   3.125000e-02   1.988311e-02
#  53  25    2.868507e+02    2.393811e+02    4.746964e+01   -1.094395e+01   1.759947e+01   3.125000e-02   1.991867e-02
#  54  21    2.868154e+02    2.393394e+02    4.747603e+01   -9.992670e+00   1.761572e+01   3.125000e-02   1.992786e-02
#  55  25    2.868122e+02    2.392897e+02    4.752257e+01   -1.071629e+01   1.766610e+01   3.125000e-02   1.995634e-02
#  56  18    2.867629e+02    2.392397e+02    4.752320e+01   -9.522545e+00   1.765812e+01   3.125000e-02   1.995183e-02
#  57  25    2.867607e+02    2.391897e+02    4.757098e+01   -9.822527e+00   1.763730e+01   3.125000e-02   1.994007e-02
#  58  24    2.867505e+02    2.391548e+02    4.759574e+01   -9.762193e+00   1.754108e+01   3.125000e-02   1.988560e-02
#  59  23    2.866064e+02    2.391339e+02    4.747247e+01   -1.116688e+01   1.755935e+01   1.562500e-02   1.989596e-02
#  60  10    2.864804e+02    2.386111e+02    4.786933e+01   -2.508871e-01   1.740781e+01   1.000000e+00   1.980992e-02
#  61  68    2.863078e+02    2.381361e+02    4.817164e+01   -9.973276e-01   2.799553e+00   1.000000e+00   7.944287e-03
#  62   2    2.862245e+02    2.380438e+02    4.818077e+01   -1.665107e-01   2.346984e+01   1.000000e+00   2.300200e-02
#  63  81    2.860534e+02    2.380280e+02    4.802538e+01   -3.382334e+00   2.394867e+00   1.250000e-01   7.347697e-03
#  64  62    2.860242e+02    2.380268e+02    4.799739e+01   -2.156752e+00   1.645216e+00   3.125000e-02   6.090067e-03
#  65  60    2.860233e+02    2.380176e+02    4.800567e+01   -4.038876e-01   1.669931e+00   2.500000e-01   6.135640e-03
#  66  63    2.860104e+02    2.380173e+02    4.799311e+01   -4.902452e+00   1.303556e+00   1.562500e-02   5.420951e-03
#  67  58    2.859905e+02    2.380169e+02    4.797361e+01   -3.008685e+00   1.493409e+00   1.562500e-02   5.802297e-03
#  68  58    2.859825e+02    2.380137e+02    4.796881e+01   -2.777891e-01   1.260882e+00   1.250000e-01   5.331481e-03
#  69  57    2.859726e+02    2.380123e+02    4.796027e+01   -3.657705e-01   1.322937e+00   6.250000e-02   5.461100e-03
#  70  57    2.859609e+02    2.380025e+02    4.795843e+01   -7.810985e-02   1.058469e+00   5.000000e-01   4.884833e-03
#  71  57    2.859516e+02    2.380019e+02    4.794967e+01   -2.241364e-01   1.020829e+00   6.250000e-02   4.797191e-03
#  72  63    2.859445e+02    2.379932e+02    4.795122e+01   -1.340953e-02   5.285619e-01   1.000000e+00   3.451902e-03
#  73  42    2.859438e+02    2.379932e+02    4.795064e+01   -1.178551e-03   1.717557e-01   1.000000e+00   1.967733e-03
#  74  92    2.859437e+02    2.379929e+02    4.795089e+01   -8.648318e-05   1.910255e-02   1.000000e+00   6.562302e-04
#  75 100    2.859437e+02    2.379929e+02    4.795088e+01   -2.117361e-07   1.022828e-03   1.000000e+00   1.518489e-04
#  76 100    2.859437e+02    2.379929e+02    4.795088e+01   -2.511239e-12   3.915235e-06   9.765625e-04   9.394841e-06
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  3.915234529428153e-06
# Final cost:  285.94374872267576
# 0.1492315239329645 0.35911399241475206
# The relative error is: 14.0 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  116.4861684552111

# %%
# Generate random surface observations
ntargets_15 = 78 
targets_x15 = np.linspace(-180., 0., ntargets_15) 
targets_y15 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_15)
targets_15 = np.zeros([ntargets_15, dim])
targets_15[:,0] = targets_x15; targets_15[:,1] = targets_y15

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_15, xf, yf, utrue, mtrue, m_15, rel_error_15, lmbda_15, lmbda_R_15, noise_std_dev_15, kl_dist_15 ) = solveInverseProblem(k, targets_15, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 78
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    3.959014e+04    3.953846e+04    5.167673e+01   -6.467014e+05   4.744485e+04   1.000000e+00   5.000000e-01
#   2   3    2.411356e+03    2.361978e+03    4.937758e+01   -7.505403e+04   1.029785e+04   1.000000e+00   4.658851e-01
#   3   4    8.026783e+02    7.526927e+02    4.998559e+01   -3.218477e+03   1.886688e+03   1.000000e+00   1.994139e-01
#   4  10    6.629455e+02    6.166815e+02    4.626409e+01   -8.705111e+02   3.703378e+02   1.000000e+00   8.834957e-02
#   5   1    3.836334e+02    3.370190e+02    4.661446e+01   -5.590129e+02   1.285053e+03   1.000000e+00   1.645758e-01
#   6   5    3.567097e+02    3.104814e+02    4.622833e+01   -5.449567e+01   3.030501e+02   1.000000e+00   7.992132e-02
#   7  56    3.497249e+02    3.029664e+02    4.675849e+01   -7.511479e+02   5.026485e+01   1.562500e-02   3.254900e-02
#   8   6    3.422318e+02    2.950600e+02    4.717180e+01   -1.495272e+01   1.144790e+02   1.000000e+00   4.912112e-02
#   9  77    3.366963e+02    2.883815e+02    4.831478e+01   -1.096793e+02   3.309375e+01   2.500000e-01   2.641061e-02
#  10   1    3.271170e+02    2.786990e+02    4.841795e+01   -1.912167e+01   2.345683e+02   1.000000e+00   7.031372e-02
#  11  25    3.245599e+02    2.782931e+02    4.626681e+01   -6.035524e+02   4.139855e+01   1.562500e-02   2.953915e-02
#  12   1    3.216591e+02    2.753403e+02    4.631882e+01   -5.795684e+00   1.344530e+02   1.000000e+00   5.323419e-02
#  13  21    3.192666e+02    2.743571e+02    4.490949e+01   -4.019889e+02   2.816483e+01   7.812500e-03   2.436459e-02
#  14  17    3.098785e+02    2.609500e+02    4.892850e+01   -2.081477e+01   4.776247e+01   1.000000e+00   3.172845e-02
#  15  21    3.086279e+02    2.602393e+02    4.838865e+01   -4.663361e+01   4.002132e+01   6.250000e-02   2.904365e-02
#  16   5    3.077533e+02    2.593250e+02    4.842833e+01   -1.747190e+00   4.601941e+01   1.000000e+00   3.114411e-02
#  17  76    3.072672e+02    2.596145e+02    4.765267e+01   -3.219428e+01   9.807041e+00   6.250000e-02   1.437720e-02
#  18   2    3.065332e+02    2.588487e+02    4.768454e+01   -1.467526e+00   7.524855e+01   1.000000e+00   3.982488e-02
#  19  77    3.061881e+02    2.590356e+02    4.715253e+01   -3.700288e+01   9.940897e+00   6.250000e-02   1.447499e-02
#  20   2    3.055247e+02    2.583469e+02    4.717781e+01   -1.326586e+00   7.255354e+01   1.000000e+00   3.910522e-02
#  21  67    3.045887e+02    2.578304e+02    4.675831e+01   -1.528225e+01   9.459483e+00   1.250000e-01   1.412014e-02
#  22   2    3.041391e+02    2.573592e+02    4.677982e+01   -8.990110e-01   5.750919e+01   1.000000e+00   3.481562e-02
#  23  71    3.038439e+02    2.572084e+02    4.663546e+01   -3.731771e+01   8.698634e+00   3.125000e-02   1.354038e-02
#  24  23    3.012500e+02    2.527082e+02    4.854180e+01   -5.104626e+00   2.609374e+01   1.000000e+00   2.345166e-02
#  25  36    3.010207e+02    2.505338e+02    5.048685e+01   -3.497917e+00   1.117353e+01   1.000000e+00   1.534619e-02
#  26   9    3.006248e+02    2.509528e+02    4.967199e+01   -2.441433e+00   2.623635e+01   5.000000e-01   2.351566e-02
#  27   2    3.004101e+02    2.507254e+02    4.968477e+01   -4.292661e-01   3.967690e+01   1.000000e+00   2.891840e-02
#  28  78    3.001448e+02    2.507473e+02    4.939745e+01   -1.427124e+01   3.940760e+00   6.250000e-02   9.113715e-03
#  29  23    3.000020e+02    2.507442e+02    4.925777e+01   -3.667668e+00   1.402930e+01   1.250000e-01   1.719584e-02
#  30   9    2.998830e+02    2.504626e+02    4.942035e+01   -2.321016e-01   1.852346e+01   1.000000e+00   1.975907e-02
#  31  64    2.998129e+02    2.504314e+02    4.938151e+01   -1.121271e+00   3.099989e+00   2.500000e-01   8.083241e-03
#  32  65    2.997545e+02    2.504362e+02    4.931830e+01   -7.424231e+00   3.920940e+00   6.250000e-02   9.090767e-03
#  33  15    2.997502e+02    2.504413e+02    4.930893e+01   -3.069099e-01   1.139558e+01   5.000000e-01   1.549793e-02
#  34  18    2.996977e+02    2.504265e+02    4.927121e+01   -2.143370e+00   1.395157e+01   1.250000e-01   1.714814e-02
#  35   2    2.996664e+02    2.503918e+02    4.927468e+01   -6.248119e-02   1.542350e+01   1.000000e+00   1.803005e-02
#  36  84    2.996188e+02    2.503864e+02    4.923247e+01   -1.626357e+00   1.697892e+00   3.125000e-02   5.982193e-03
#  37  52    2.995077e+02    2.502440e+02    4.926374e+01   -3.649530e-01   2.065169e+00   1.000000e+00   6.597558e-03
#  38  63    2.994688e+02    2.502312e+02    4.923760e+01   -1.216999e+00   2.317254e+00   1.250000e-01   6.988633e-03
#  39  66    2.994500e+02    2.502279e+02    4.922211e+01   -7.043120e-01   2.195488e+00   6.250000e-02   6.802537e-03
#  40  62    2.994389e+02    2.502191e+02    4.921977e+01   -5.653007e-01   2.128446e+00   6.250000e-02   6.697872e-03
#  41  61    2.994305e+02    2.502150e+02    4.921556e+01   -3.744794e-01   1.906950e+00   6.250000e-02   6.339793e-03
#  42  58    2.994277e+02    2.501885e+02    4.923913e+01   -2.185089e-01   1.890784e+00   2.500000e-01   6.312863e-03
#  43  72    2.994182e+02    2.501872e+02    4.923097e+01   -6.128981e-01   1.416217e+00   6.250000e-02   5.463493e-03
#  44  66    2.994127e+02    2.501815e+02    4.923121e+01   -5.281056e-01   1.447733e+00   6.250000e-02   5.523949e-03
#  45  71    2.994073e+02    2.501793e+02    4.922803e+01   -3.390414e-01   1.250656e+00   6.250000e-02   5.134218e-03
#  46  66    2.994038e+02    2.501716e+02    4.923216e+01   -1.775091e-01   1.319805e+00   1.250000e-01   5.274246e-03
#  47  65    2.993963e+02    2.501692e+02    4.922712e+01   -1.749699e-01   1.113630e+00   6.250000e-02   4.844801e-03
#  48  58    2.993855e+02    2.501217e+02    4.926388e+01   -2.196385e-02   9.422069e-01   1.000000e+00   4.456343e-03
#  49  62    2.993840e+02    2.501209e+02    4.926307e+01   -4.958901e-03   2.942484e-01   1.000000e+00   2.490362e-03
#  50  94    2.993834e+02    2.501188e+02    4.926457e+01   -5.296385e-03   2.002871e-01   5.000000e-01   2.054622e-03
#  51  93    2.993828e+02    2.501200e+02    4.926275e+01   -3.159764e-03   1.873163e-01   5.000000e-01   1.986979e-03
#  52  72    2.993825e+02    2.501200e+02    4.926256e+01   -4.895813e-04   1.213456e-01   1.000000e+00   1.599254e-03
#  53  99    2.993825e+02    2.501202e+02    4.926235e+01   -3.710326e-05   2.805407e-02   1.000000e+00   7.689594e-04
#  54 100    2.993825e+02    2.501202e+02    4.926230e+01   -2.108726e-06   5.244081e-03   1.000000e+00   3.324606e-04
#  55 100    2.993825e+02    2.501202e+02    4.926230e+01   -6.946518e-09   2.832829e-04   1.000000e+00   7.727084e-05
#  56 100    2.993825e+02    2.501202e+02    4.926230e+01   -7.311224e-14   9.198485e-07   2.500000e-01   4.403151e-06
#  57 100    2.993825e+02    2.501202e+02    4.926230e+01   -4.115875e-14   6.918404e-07   3.125000e-02   3.818637e-06
#  58 100    2.993825e+02    2.501202e+02    4.926230e+01   -3.864549e-14   6.667174e-07   9.765625e-04   3.748662e-06
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  6.667173821456387e-07
# Final cost:  299.38252719718804
# 0.15078476725713144 0.35976674773166606
# The relative error is: 14.5 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  121.66899947166905

# %%
# Generate random surface observations
ntargets_16 = 86 
targets_x16 = np.linspace(-180., 0., ntargets_16) 
targets_y16 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_16)
targets_16 = np.zeros([ntargets_16, dim])
targets_16[:,0] = targets_x16; targets_16[:,1] = targets_y16

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_16, xf, yf, utrue, mtrue, m_16, rel_error_16, lmbda_16, lmbda_R_16, noise_std_dev_16, kl_dist_16 ) = solveInverseProblem(k, targets_16, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 86
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    4.400490e+04    4.395323e+04    5.167721e+01   -7.143575e+05   5.240258e+04   1.000000e+00   5.000000e-01
#   2   3    2.660953e+03    2.611547e+03    4.940635e+01   -8.347617e+04   1.139830e+04   1.000000e+00   4.663841e-01
#   3   4    9.561382e+02    9.062480e+02    4.989023e+01   -3.410480e+03   2.050672e+03   1.000000e+00   1.978207e-01
#   4  10    8.099916e+02    7.636688e+02    4.632279e+01   -1.072252e+03   4.228791e+02   1.000000e+00   8.983215e-02
#   5   1    4.407583e+02    3.940541e+02    4.670421e+01   -7.389996e+02   1.555047e+03   1.000000e+00   1.722644e-01
#   6   6    4.035162e+02    3.573189e+02    4.619732e+01   -7.498700e+01   3.579808e+02   1.000000e+00   8.265203e-02
#   7  47    3.887542e+02    3.423767e+02    4.637744e+01   -6.439383e+02   3.728343e+01   3.125000e-02   2.667359e-02
#   8  10    3.692020e+02    3.215221e+02    4.767991e+01   -3.892095e+01   9.660573e+01   1.000000e+00   4.293635e-02
#   9  32    3.510919e+02    3.014181e+02    4.967375e+01   -6.491901e+01   4.225298e+01   5.000000e-01   2.839568e-02
#  10   2    3.465610e+02    2.967891e+02    4.977194e+01   -9.050819e+00   1.651248e+02   1.000000e+00   5.613449e-02
#  11  62    3.439267e+02    2.945769e+02    4.934979e+01   -5.009215e+01   1.509876e+01   1.250000e-01   1.697439e-02
#  12  26    3.419159e+02    2.907531e+02    5.116280e+01   -3.541390e+01   4.147125e+01   2.500000e-01   2.813178e-02
#  13   1    3.410460e+02    2.898536e+02    5.119231e+01   -1.739162e+00   7.936841e+01   1.000000e+00   3.891773e-02
#  14 100    3.403081e+02    2.897809e+02    5.052716e+01   -1.487974e+02   1.103822e+01   1.562500e-02   1.451354e-02
#  15  22    3.381854e+02    2.879516e+02    5.023374e+01   -1.645394e+01   2.839700e+01   2.500000e-01   2.327876e-02
#  16   2    3.376553e+02    2.874014e+02    5.025389e+01   -1.059742e+00   6.421416e+01   1.000000e+00   3.500572e-02
#  17 100    3.372690e+02    2.873679e+02    4.990113e+01   -1.390926e+02   8.043432e+00   3.906250e-03   1.238923e-02
#  18  62    3.372640e+02    2.854818e+02    5.178224e+01   -2.022016e+01   1.013371e+01   2.500000e-01   1.390618e-02
#  19   9    3.354887e+02    2.844405e+02    5.104818e+01   -6.760767e+00   5.262167e+01   5.000000e-01   3.168881e-02
#  20   2    3.349050e+02    2.838364e+02    5.106860e+01   -1.166969e+00   6.820259e+01   1.000000e+00   3.607647e-02
#  21 100    3.347738e+02    2.837363e+02    5.103748e+01   -6.945363e+01   6.582463e+00   3.125000e-02   1.120774e-02
#  22  33    3.340275e+02    2.829890e+02    5.103851e+01   -1.755619e+01   2.364179e+01   1.250000e-01   2.124045e-02
#  23   9    3.339861e+02    2.819335e+02    5.205255e+01   -3.757330e+00   3.637512e+01   5.000000e-01   2.634668e-02
#  24  17    3.331888e+02    2.817791e+02    5.140968e+01   -1.839268e+01   4.168228e+01   6.250000e-02   2.820327e-02
#  25   1    3.329600e+02    2.815363e+02    5.142363e+01   -4.575566e-01   4.343909e+01   1.000000e+00   2.879148e-02
#  26  81    3.329307e+02    2.814537e+02    5.147704e+01   -1.104181e+01   5.251777e+00   3.125000e-02   1.001098e-02
#  27  82    3.328940e+02    2.813804e+02    5.151365e+01   -2.773632e+01   6.427845e+00   3.125000e-02   1.107532e-02
#  28  38    3.325308e+02    2.807583e+02    5.177250e+01   -4.357991e+00   1.254997e+01   2.500000e-01   1.547551e-02
#  29  21    3.324994e+02    2.806663e+02    5.183316e+01   -9.160641e+00   2.488741e+01   1.250000e-01   2.179282e-02
#  30   4    3.323417e+02    2.805149e+02    5.182680e+01   -3.154066e-01   3.506134e+01   1.000000e+00   2.586651e-02
#  31  98    3.320361e+02    2.804970e+02    5.153913e+01   -1.995203e+01   2.991839e+00   1.562500e-02   7.556014e-03
#  32  61    3.320297e+02    2.804526e+02    5.157706e+01   -5.551210e+00   6.576942e+00   3.125000e-02   1.120303e-02
#  33  59    3.319629e+02    2.804289e+02    5.153403e+01   -1.733847e+01   7.177081e+00   1.562500e-02   1.170301e-02
#  34  53    3.319380e+02    2.803900e+02    5.154803e+01   -5.196209e+00   7.637416e+00   3.125000e-02   1.207249e-02
#  35  59    3.318735e+02    2.803675e+02    5.150599e+01   -1.327423e+01   8.156004e+00   1.562500e-02   1.247563e-02
#  36  42    3.318120e+02    2.803470e+02    5.146505e+01   -4.083343e+00   8.333046e+00   1.562500e-02   1.261030e-02
#  37  46    3.312367e+02    2.792054e+02    5.203130e+01   -1.513880e+00   8.284409e+00   1.000000e+00   1.257345e-02
#  38  34    3.311123e+02    2.791802e+02    5.193213e+01   -1.456935e+00   9.441218e+00   2.500000e-01   1.342263e-02
#  39  42    3.310681e+02    2.791616e+02    5.190653e+01   -1.882368e+00   6.369506e+00   1.250000e-01   1.102495e-02
#  40  42    3.310096e+02    2.791573e+02    5.185229e+01   -8.012679e-01   5.935573e+00   2.500000e-01   1.064278e-02
#  41  42    3.310092e+02    2.790671e+02    5.194209e+01   -1.781624e-01   4.671107e+00   5.000000e-01   9.441338e-03
#  42  64    3.309876e+02    2.790557e+02    5.193187e+01   -2.013041e+00   2.844835e+00   1.250000e-01   7.368043e-03
#  43  44    3.309439e+02    2.790183e+02    5.192562e+01   -2.834189e-01   2.896342e+00   5.000000e-01   7.434445e-03
#  44  46    3.309356e+02    2.790136e+02    5.192203e+01   -1.427413e-01   1.971709e+00   2.500000e-01   6.134018e-03
#  45  43    3.309287e+02    2.790027e+02    5.192595e+01   -2.948449e-01   1.682403e+00   2.500000e-01   5.666158e-03
#  46  62    3.309268e+02    2.789993e+02    5.192747e+01   -6.317313e-02   1.219417e+00   2.500000e-01   4.823916e-03
#  47  41    3.309221e+02    2.789891e+02    5.193296e+01   -1.224240e-01   1.254175e+00   5.000000e-01   4.892183e-03
#  48  63    3.309212e+02    2.789904e+02    5.193076e+01   -5.288670e-02   6.680140e-01   2.500000e-01   3.570396e-03
#  49  41    3.309161e+02    2.789837e+02    5.193243e+01   -8.328964e-02   8.977440e-01   5.000000e-01   4.139043e-03
#  50  74    3.309118e+02    2.789847e+02    5.192704e+01   -2.820018e-02   4.083728e-01   2.500000e-01   2.791593e-03
#  51  67    3.309038e+02    2.789833e+02    5.192046e+01   -1.141094e-02   2.700456e-01   1.000000e+00   2.270085e-03
#  52  88    3.308973e+02    2.789858e+02    5.191155e+01   -1.037789e-02   1.251625e-01   1.000000e+00   1.545471e-03
#  53  65    3.308954e+02    2.789841e+02    5.191126e+01   -3.515401e-03   3.010292e-01   1.000000e+00   2.396779e-03
#  54  98    3.308953e+02    2.789843e+02    5.191094e+01   -1.786540e-04   1.964665e-02   1.000000e+00   6.123051e-04
#  55  91    3.308953e+02    2.789843e+02    5.191098e+01   -4.367785e-07   2.062896e-03   1.000000e+00   1.984094e-04
#  56 100    3.308953e+02    2.789843e+02    5.191098e+01   -9.025241e-11   2.327447e-05   9.765625e-04   2.107481e-05
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  2.3274473618266213e-05
# Final cost:  330.8952806761907
# 0.04671205508457866 0.35956930034922024
# The relative error is: 12.9 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  129.71928299570365

# %%
# Generate random surface observations
ntargets_17 = 93  
targets_x17 = np.linspace(-180., 0., ntargets_17) 
targets_y17 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_17)
targets_17 = np.zeros([ntargets_17, dim])
targets_17[:,0] = targets_x17; targets_17[:,1] = targets_y17

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_17, xf, yf, utrue, mtrue, m_17, rel_error_17, lmbda_17, lmbda_R_17, noise_std_dev_17, kl_dist_17 ) = solveInverseProblem(k, targets_17, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 93
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    4.736501e+04    4.731336e+04    5.165341e+01   -7.702254e+05   5.652083e+04   1.000000e+00   5.000000e-01
#   2   1    1.609635e+04    1.604359e+04    5.275570e+01   -6.193265e+04   1.229740e+04   1.000000e+00   4.664470e-01
#   3   3    2.509385e+03    2.459649e+03    4.973643e+01   -2.738655e+04   2.270424e+03   1.000000e+00   2.004237e-01
#   4   5    7.276140e+02    6.783710e+02    4.924299e+01   -3.554730e+03   1.267321e+03   1.000000e+00   1.497404e-01
#   5  14    6.409947e+02    5.953186e+02    4.567605e+01   -6.621297e+02   3.178077e+02   5.000000e-01   7.498561e-02
#   6   1    4.768468e+02    4.309015e+02    4.594527e+01   -3.249241e+02   1.074206e+03   1.000000e+00   1.378604e-01
#   7  21    4.221073e+02    3.757568e+02    4.635050e+01   -2.039629e+02   1.927138e+02   5.000000e-01   5.839184e-02
#   8   1    4.011463e+02    3.546806e+02    4.646572e+01   -4.180090e+01   3.866088e+02   1.000000e+00   8.270496e-02
#   9  36    3.972927e+02    3.509166e+02    4.637612e+01   -2.620568e+02   1.103234e+02   3.125000e-02   4.418040e-02
#  10   7    3.829049e+02    3.364382e+02    4.646663e+01   -2.814182e+01   1.429732e+02   1.000000e+00   5.029479e-02
#  11  51    3.817027e+02    3.361634e+02    4.553925e+01   -6.195996e+02   3.523132e+01   3.906250e-03   2.496665e-02
#  12  36    3.715291e+02    3.199865e+02    5.154260e+01   -5.429066e+01   3.701050e+01   5.000000e-01   2.558929e-02
#  13   3    3.686248e+02    3.170046e+02    5.162025e+01   -5.804365e+00   1.154418e+02   1.000000e+00   4.519364e-02
#  14  85    3.658702e+02    3.176165e+02    4.825366e+01   -1.673943e+02   1.636169e+01   3.125000e-02   1.701413e-02
#  15   2    3.648836e+02    3.166048e+02    4.827881e+01   -1.972483e+00   9.471732e+01   1.000000e+00   4.093647e-02
#  16  66    3.645387e+02    3.158314e+02    4.870739e+01   -3.210648e+01   1.534690e+01   6.250000e-02   1.647806e-02
#  17  17    3.626784e+02    3.139065e+02    4.877195e+01   -1.643901e+01   3.744533e+01   2.500000e-01   2.573917e-02
#  18  10    3.605070e+02    3.098786e+02    5.062846e+01   -5.028574e+00   6.439211e+01   1.000000e+00   3.375297e-02
#  19  20    3.600538e+02    3.095445e+02    5.050928e+01   -1.184585e+01   2.474923e+01   1.250000e-01   2.092553e-02
#  20  11    3.595947e+02    3.086902e+02    5.090448e+01   -2.325123e+00   3.414545e+01   5.000000e-01   2.457888e-02
#  21  18    3.592753e+02    3.083672e+02    5.090805e+01   -9.754934e+00   2.832913e+01   1.250000e-01   2.238785e-02
#  22  11    3.592705e+02    3.076562e+02    5.161433e+01   -1.866060e+00   3.295850e+01   5.000000e-01   2.414790e-02
#  23  15    3.588890e+02    3.076466e+02    5.124239e+01   -7.858037e+00   3.070387e+01   1.250000e-01   2.330732e-02
#  24   2    3.587419e+02    3.074877e+02    5.125423e+01   -2.941729e-01   3.455563e+01   1.000000e+00   2.472607e-02
#  25  97    3.586291e+02    3.074393e+02    5.118978e+01   -2.240518e+01   5.074135e+00   1.562500e-02   9.474946e-03
#  26  79    3.586004e+02    3.073025e+02    5.129792e+01   -2.088058e+01   5.558609e+00   1.250000e-01   9.916966e-03
#  27   7    3.578990e+02    3.069676e+02    5.093146e+01   -1.048081e+00   3.802594e+01   1.000000e+00   2.593795e-02
#  28  16    3.576742e+02    3.068200e+02    5.085418e+01   -2.377492e+00   2.386549e+01   1.250000e-01   2.054854e-02
#  29   9    3.575360e+02    3.066755e+02    5.086059e+01   -2.762931e-01   2.282288e+01   1.000000e+00   2.009467e-02
#  30 100    3.564067e+02    3.058113e+02    5.059546e+01   -4.775372e+00   3.537287e+00   5.000000e-01   7.910991e-03
#  31   3    3.563105e+02    3.056923e+02    5.061822e+01   -1.924364e-01   2.240468e+01   1.000000e+00   1.990972e-02
#  32  99    3.561903e+02    3.056253e+02    5.056499e+01   -1.329182e+01   3.554410e+00   6.250000e-02   7.930115e-03
#  33  76    3.560908e+02    3.056140e+02    5.047687e+01   -2.634608e+01   4.609011e+00   1.562500e-02   9.030247e-03
#  34  67    3.559728e+02    3.055967e+02    5.037610e+01   -7.718652e+00   5.692734e+00   1.562500e-02   1.003590e-02
#  35  57    3.558000e+02    3.053422e+02    5.045786e+01   -1.703700e+00   5.920576e+00   2.500000e-01   1.023476e-02
#  36  47    3.557497e+02    3.052518e+02    5.049794e+01   -4.257592e+00   7.095414e+00   1.250000e-01   1.120430e-02
#  37  20    3.555726e+02    3.045285e+02    5.104401e+01   -3.848022e-01   1.356151e+01   1.000000e+00   1.548994e-02
#  38  70    3.554972e+02    3.045891e+02    5.090811e+01   -8.483679e-01   2.476261e+00   2.500000e-01   6.619023e-03
#  39  65    3.554649e+02    3.045738e+02    5.089112e+01   -3.538110e-01   2.087838e+00   5.000000e-01   6.077768e-03
#  40  69    3.554316e+02    3.045751e+02    5.085658e+01   -4.238157e+00   2.578513e+00   6.250000e-02   6.754300e-03
#  41  38    3.553570e+02    3.045371e+02    5.081988e+01   -3.481498e-01   4.815318e+00   2.500000e-01   9.230138e-03
#  42  41    3.553435e+02    3.045370e+02    5.080652e+01   -2.284472e-01   4.373235e+00   6.250000e-02   8.796241e-03
#  43  38    3.553055e+02    3.045400e+02    5.076554e+01   -7.818338e-02   4.129652e+00   1.000000e+00   8.547762e-03
#  44  60    3.552951e+02    3.045161e+02    5.077895e+01   -2.021530e-02   7.687996e-01   1.000000e+00   3.688097e-03
#  45  68    3.552941e+02    3.045167e+02    5.077733e+01   -1.650159e-03   1.918392e-01   1.000000e+00   1.842317e-03
#  46  88    3.552938e+02    3.045152e+02    5.077856e+01   -5.026113e-04   2.768120e-02   1.000000e+00   6.998229e-04
#  47  67    3.552938e+02    3.045151e+02    5.077867e+01   -1.018487e-05   2.460507e-02   1.000000e+00   6.597935e-04
#  48 100    3.552938e+02    3.045151e+02    5.077868e+01   -8.246705e-09   5.273514e-04   1.000000e+00   9.659302e-05
#  49 100    3.552938e+02    3.045151e+02    5.077868e+01   -5.305994e-14   8.492035e-07   5.000000e-01   3.876159e-06
#  50 100    3.552938e+02    3.045151e+02    5.077868e+01   -1.328401e-14   4.183338e-07   5.000000e-01   2.720553e-06
#  51 100    3.552938e+02    3.045151e+02    5.077868e+01   -3.366910e-15   2.281070e-07   1.250000e-01   2.008931e-06
#  52 100    3.552938e+02    3.045151e+02    5.077868e+01   -2.564997e-15   1.822885e-07   1.250000e-01   1.795872e-06
#  53 100    3.552938e+02    3.045151e+02    5.077868e+01   -1.953046e-15   1.530663e-07   9.765625e-04   1.645642e-06
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  1.5306625467955484e-07
# Final cost:  355.29378562370266
# 0.027446333359659836 0.3547807819020244
# The relative error is: 13.2 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  127.1258221861743

# %%
# Generate random surface observations
ntargets_18 = 100 
targets_x18 = np.linspace(-180., 0., ntargets_18) 
targets_y18 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_18)
targets_18 = np.zeros([ntargets_18, dim])
targets_18[:,0] = targets_x18; targets_18[:,1] = targets_y18

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_18, xf, yf, utrue, mtrue, m_18, rel_error_18, lmbda_18, lmbda_R_18, noise_std_dev_18, kl_dist_18 ) = solveInverseProblem(k, targets_18, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 100
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    5.133316e+04    5.128158e+04    5.157637e+01   -8.231095e+05   6.059185e+04   1.000000e+00   5.000000e-01
#   2   1    1.720466e+04    1.715200e+04    5.266323e+01   -6.771449e+04   1.354957e+04   1.000000e+00   4.728852e-01
#   3   3    2.690467e+03    2.640759e+03    4.970766e+01   -2.925528e+04   2.340189e+03   1.000000e+00   1.965252e-01
#   4   5    7.548935e+02    7.056080e+02    4.928549e+01   -3.863028e+03   1.383657e+03   1.000000e+00   1.511148e-01
#   5  11    5.858719e+02    5.395952e+02    4.627671e+01   -6.453222e+02   3.722766e+02   5.000000e-01   7.838370e-02
#   6   1    5.099730e+02    4.635237e+02    4.644932e+01   -1.506874e+02   7.415289e+02   1.000000e+00   1.106259e-01
#   7  21    4.610999e+02    4.151918e+02    4.590814e+01   -2.026885e+02   2.132446e+02   5.000000e-01   5.932421e-02
#   8   1    4.340831e+02    3.880575e+02    4.602560e+01   -5.385096e+01   4.571068e+02   1.000000e+00   8.685639e-02
#   9  36    4.189640e+02    3.719132e+02    4.705074e+01   -1.174035e+02   1.153435e+02   2.500000e-01   4.363043e-02
#  10   1    4.123433e+02    3.652435e+02    4.709979e+01   -1.322455e+01   2.364844e+02   1.000000e+00   6.247325e-02
#  11  41    4.107095e+02    3.648593e+02    4.585020e+01   -1.051083e+03   7.360626e+01   1.953125e-03   3.485381e-02
#  12  21    3.968320e+02    3.479902e+02    4.884188e+01   -3.329035e+01   7.274531e+01   1.000000e+00   3.464938e-02
#  13   1    3.937958e+02    3.449074e+02    4.888840e+01   -6.068111e+00   1.606592e+02   1.000000e+00   5.149270e-02
#  14  80    3.920480e+02    3.439375e+02    4.811045e+01   -3.556107e+01   1.307657e+01   1.250000e-01   1.469061e-02
#  15   3    3.913045e+02    3.431709e+02    4.813357e+01   -1.486643e+00   8.629802e+01   1.000000e+00   3.773926e-02
#  16  93    3.907240e+02    3.425179e+02    4.820610e+01   -3.606832e+01   1.190574e+01   6.250000e-02   1.401752e-02
#  17  11    3.892434e+02    3.406634e+02    4.857996e+01   -6.540033e+00   4.555498e+01   5.000000e-01   2.741958e-02
#  18   2    3.889614e+02    3.403692e+02    4.859219e+01   -5.637154e-01   5.450113e+01   1.000000e+00   2.999133e-02
#  19  93    3.889206e+02    3.397581e+02    4.916247e+01   -1.766311e+01   7.159146e+00   1.250000e-01   1.086985e-02
#  20   3    3.883888e+02    3.392526e+02    4.913617e+01   -1.062298e+00   7.224982e+01   1.000000e+00   3.453117e-02
#  21  92    3.877401e+02    3.393856e+02    4.835450e+01   -1.816885e+02   8.928817e+00   7.812500e-03   1.213919e-02
#  22   2    3.875626e+02    3.391996e+02    4.836300e+01   -3.549193e-01   4.246585e+01   1.000000e+00   2.647359e-02
#  23  91    3.872852e+02    3.387157e+02    4.856950e+01   -1.509806e+01   7.322085e+00   6.250000e-02   1.099285e-02
#  24  37    3.864307e+02    3.372923e+02    4.913839e+01   -1.041522e+01   1.923318e+01   2.500000e-01   1.781634e-02
#  25   3    3.861280e+02    3.369609e+02    4.916710e+01   -6.052199e-01   5.614702e+01   1.000000e+00   3.044081e-02
#  26  87    3.858067e+02    3.367598e+02    4.904689e+01   -1.420507e+01   7.015885e+00   6.250000e-02   1.076054e-02
#  27  11    3.855828e+02    3.350029e+02    5.057989e+01   -2.460425e+00   3.562884e+01   1.000000e+00   2.424899e-02
#  28   9    3.849853e+02    3.349199e+02    5.006542e+01   -1.023075e+00   3.815756e+01   1.000000e+00   2.509477e-02
#  29  26    3.848616e+02    3.346954e+02    5.016619e+01   -2.466667e+00   1.676437e+01   1.250000e-01   1.663361e-02
#  30  27    3.847333e+02    3.344920e+02    5.024137e+01   -4.962608e+00   1.754732e+01   1.250000e-01   1.701760e-02
#  31  14    3.846246e+02    3.343317e+02    5.029293e+01   -1.193810e+00   2.123402e+01   2.500000e-01   1.872014e-02
#  32  22    3.845728e+02    3.342222e+02    5.035056e+01   -3.895948e+00   2.186123e+01   1.250000e-01   1.899460e-02
#  33  11    3.844887e+02    3.341256e+02    5.036313e+01   -9.268768e-01   2.393943e+01   2.500000e-01   1.987695e-02
#  34  20    3.844197e+02    3.339986e+02    5.042109e+01   -3.223160e+00   2.246251e+01   1.250000e-01   1.925405e-02
#  35  14    3.843099e+02    3.339475e+02    5.036243e+01   -9.385618e-01   2.270883e+01   1.250000e-01   1.935933e-02
#  36   3    3.842684e+02    3.339022e+02    5.036619e+01   -8.302978e-02   2.111038e+01   1.000000e+00   1.866556e-02
#  37  86    3.837713e+02    3.335971e+02    5.017414e+01   -1.555803e+00   3.186554e+00   5.000000e-01   7.251929e-03
#  38  61    3.837633e+02    3.333744e+02    5.038885e+01   -1.205619e+00   3.978727e+00   5.000000e-01   8.103357e-03
#  39  54    3.835920e+02    3.333564e+02    5.023562e+01   -2.891562e+00   6.376496e+00   6.250000e-02   1.025850e-02
#  40   9    3.835809e+02    3.332882e+02    5.029263e+01   -2.227284e-02   8.816476e+00   1.000000e+00   1.206259e-02
#  41 100    3.835736e+02    3.331806e+02    5.039298e+01   -2.883150e-01   1.660331e+00   5.000000e-01   5.234682e-03
#  42  78    3.835688e+02    3.331782e+02    5.039065e+01   -2.007186e+00   1.918100e+00   1.250000e-01   5.626373e-03
#  43  26    3.835295e+02    3.331786e+02    5.035092e+01   -3.364551e-01   5.769232e+00   1.250000e-01   9.757800e-03
#  44  22    3.835147e+02    3.331754e+02    5.033937e+01   -2.460041e-01   6.561827e+00   6.250000e-02   1.040651e-02
#  45   3    3.835107e+02    3.331695e+02    5.034124e+01   -8.080943e-03   6.352711e+00   1.000000e+00   1.023935e-02
#  46 100    3.835042e+02    3.331569e+02    5.034730e+01   -7.752423e-02   8.607641e-01   2.500000e-01   3.769077e-03
#  47  91    3.834990e+02    3.331435e+02    5.035551e+01   -1.374212e-01   9.002111e-01   2.500000e-01   3.854474e-03
#  48  88    3.834926e+02    3.331424e+02    5.035022e+01   -2.275681e-01   6.148603e-01   3.125000e-02   3.185526e-03
#  49  79    3.834847e+02    3.331038e+02    5.038089e+01   -1.408909e-02   5.033596e-01   1.000000e+00   2.882253e-03
#  50  97    3.834837e+02    3.331042e+02    5.037945e+01   -1.912486e-03   1.405609e-01   1.000000e+00   1.523089e-03
#  51 100    3.834837e+02    3.331044e+02    5.037922e+01   -4.233491e-05   2.468790e-02   1.000000e+00   6.383149e-04
#  52 100    3.834837e+02    3.331045e+02    5.037920e+01   -7.320268e-08   1.265160e-03   1.000000e+00   1.444992e-04
#  53 100    3.834837e+02    3.331045e+02    5.037920e+01   -1.125901e-12   7.827301e-06   9.765625e-04   1.136577e-05
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  7.827300711223144e-06
# Final cost:  383.48365425981484
# 0.10705478852558914 0.35939967980845045
# The relative error is: 14.7 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  131.8152469905191

# %%
# Generate random surface observations
ntargets_19 = 113  
targets_x19 = np.linspace(-180., 0., ntargets_19) 
targets_y19 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_19)
targets_19 = np.zeros([ntargets_19, dim])
targets_19[:,0] = targets_x19; targets_19[:,1] = targets_y19

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_19, xf, yf, utrue, mtrue, m_19, rel_error_19, lmbda_19, lmbda_R_19, noise_std_dev_19, kl_dist_19 ) = solveInverseProblem(k, targets_19, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 113
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    5.728194e+04    5.723035e+04    5.159079e+01   -9.322696e+05   6.853541e+04   1.000000e+00   5.000000e-01
#   2   1    1.925300e+04    1.920032e+04    5.268116e+01   -7.537187e+04   1.514380e+04   1.000000e+00   4.700671e-01
#   3   3    2.937564e+03    2.887858e+03    4.970550e+01   -3.287510e+04   2.727554e+03   1.000000e+00   1.994937e-01
#   4   5    8.448845e+02    7.956818e+02    4.920266e+01   -4.174457e+03   1.471819e+03   1.000000e+00   1.465445e-01
#   5  11    6.654719e+02    6.194751e+02    4.599682e+01   -7.405089e+02   4.101992e+02   5.000000e-01   7.736417e-02
#   6   1    5.620486e+02    5.158613e+02    4.618728e+01   -2.052250e+02   9.276173e+02   1.000000e+00   1.163394e-01
#   7  21    5.123893e+02    4.665260e+02    4.586329e+01   -2.345415e+02   2.271946e+02   5.000000e-01   5.757600e-02
#   8   1    4.751941e+02    4.291997e+02    4.599438e+01   -7.412856e+01   5.749740e+02   1.000000e+00   9.159391e-02
#   9  37    4.730676e+02    4.278160e+02    4.525158e+01   -4.000382e+02   1.242065e+02   7.812500e-03   4.257108e-02
#  10  11    4.505758e+02    4.042752e+02    4.630061e+01   -4.428969e+01   1.230841e+02   1.000000e+00   4.237829e-02
#  11  20    4.401856e+02    3.905642e+02    4.962138e+01   -2.493309e+01   5.705544e+01   1.000000e+00   2.885300e-02
#  12   2    4.387559e+02    3.890831e+02    4.967277e+01   -2.857641e+00   9.972030e+01   1.000000e+00   3.814471e-02
#  13  77    4.381853e+02    3.895004e+02    4.868493e+01   -3.886428e+01   1.858307e+01   1.250000e-01   1.646650e-02
#  14   1    4.364485e+02    3.877304e+02    4.871811e+01   -3.471863e+00   1.302178e+02   1.000000e+00   4.358908e-02
#  15  79    4.355685e+02    3.875617e+02    4.800674e+01   -9.967529e+01   1.648557e+01   3.125000e-02   1.550938e-02
#  16  20    4.342150e+02    3.851240e+02    4.909096e+01   -7.754635e+00   3.807517e+01   5.000000e-01   2.357021e-02
#  17  14    4.331174e+02    3.844158e+02    4.870166e+01   -9.897773e+00   5.711264e+01   2.500000e-01   2.886746e-02
#  18   2    4.326991e+02    3.839689e+02    4.873018e+01   -8.365088e-01   6.065045e+01   1.000000e+00   2.974812e-02
#  19  93    4.323328e+02    3.838822e+02    4.845062e+01   -3.691841e+01   1.001986e+01   1.562500e-02   1.209131e-02
#  20  62    4.311631e+02    3.827786e+02    4.838448e+01   -1.069706e+01   1.153192e+01   2.500000e-01   1.297159e-02
#  21  48    4.306299e+02    3.823573e+02    4.827254e+01   -1.542925e+01   1.789192e+01   1.250000e-01   1.615738e-02
#  22  25    4.302998e+02    3.821559e+02    4.814393e+01   -1.312881e+01   2.288340e+01   6.250000e-02   1.827270e-02
#  23  17    4.300672e+02    3.818064e+02    4.826081e+01   -4.079730e+00   2.501407e+01   1.250000e-01   1.910446e-02
#  24  25    4.299804e+02    3.816380e+02    4.834241e+01   -8.855561e+00   2.404578e+01   6.250000e-02   1.873104e-02
#  25  14    4.298486e+02    3.814180e+02    4.843067e+01   -3.376644e+00   2.443208e+01   1.250000e-01   1.888090e-02
#  26  23    4.297108e+02    3.813600e+02    4.835086e+01   -8.815583e+00   2.355455e+01   3.125000e-02   1.853873e-02
#  27  11    4.294790e+02    3.799688e+02    4.951024e+01   -1.049367e+00   2.339240e+01   1.000000e+00   1.847481e-02
#  28  90    4.293726e+02    3.799703e+02    4.940228e+01   -7.878171e+01   5.789342e+00   3.906250e-03   9.190880e-03
#  29  86    4.293224e+02    3.799667e+02    4.935567e+01   -1.725136e+01   5.854939e+00   7.812500e-03   9.242803e-03
#  30  77    4.292792e+02    3.799517e+02    4.932747e+01   -6.340931e+00   5.883918e+00   6.250000e-02   9.265648e-03
#  31  85    4.291274e+02    3.799487e+02    4.917873e+01   -2.026480e+01   5.829172e+00   7.812500e-03   9.222442e-03
#  32  55    4.285556e+02    3.798855e+02    4.867013e+01   -1.722971e+00   5.934261e+00   5.000000e-01   9.305202e-03
#  33   5    4.285173e+02    3.798556e+02    4.866169e+01   -7.661668e-02   1.698959e+01   1.000000e+00   1.574468e-02
#  34  88    4.285085e+02    3.797558e+02    4.875270e+01   -6.627295e-01   2.054715e+00   1.000000e+00   5.475430e-03
#  35   3    4.284956e+02    3.797394e+02    4.875620e+01   -2.584508e-02   1.108538e+01   1.000000e+00   1.271797e-02
#  36  79    4.282995e+02    3.797668e+02    4.853270e+01   -1.154257e+00   1.692288e+00   2.500000e-01   4.969122e-03
#  37  66    4.282805e+02    3.797469e+02    4.853367e+01   -9.397744e-02   1.308839e+00   5.000000e-01   4.370043e-03
#  38  54    4.282745e+02    3.797306e+02    4.854388e+01   -7.721931e-02   1.019413e+00   5.000000e-01   3.856715e-03
#  39  75    4.282722e+02    3.797300e+02    4.854221e+01   -1.276387e-01   6.389930e-01   1.250000e-01   3.053448e-03
#  40  63    4.282711e+02    3.797270e+02    4.854411e+01   -1.057323e-01   8.299647e-01   2.500000e-01   3.479944e-03
#  41  80    4.282633e+02    3.797267e+02    4.853652e+01   -1.451260e-01   5.901251e-01   6.250000e-02   2.934368e-03
#  42  72    4.282596e+02    3.797183e+02    4.854130e+01   -6.297839e-03   3.135748e-01   1.000000e+00   2.139011e-03
#  43  93    4.282589e+02    3.797175e+02    4.854136e+01   -1.182679e-03   9.471855e-02   1.000000e+00   1.175601e-03
#  44  97    4.282587e+02    3.797173e+02    4.854132e+01   -3.267032e-04   3.444711e-02   1.000000e+00   7.089554e-04
#  45 100    4.282587e+02    3.797173e+02    4.854137e+01   -2.967073e-05   8.770241e-03   1.000000e+00   3.577241e-04
#  46 100    4.282587e+02    3.797173e+02    4.854138e+01   -6.640108e-08   4.906546e-04   1.000000e+00   8.461170e-05
#  47 100    4.282587e+02    3.797173e+02    4.854138e+01   -4.626467e-13   1.495529e-06   2.500000e-01   4.671323e-06
#  48 100    4.282587e+02    3.797173e+02    4.854138e+01   -2.602092e-13   1.119019e-06   9.765625e-04   4.040743e-06
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  1.11901928463276e-06
# Final cost:  428.258651821045
# 0.19131698662632626 0.3567651844640612
# The relative error is: 13.0 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  121.21843374315469

# %%
# Generate random surface observations
ntargets_20 = 123 
targets_x20 = np.linspace(-180., 0., ntargets_20) 
targets_y20 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_20)
targets_20 = np.zeros([ntargets_20, dim])
targets_20[:,0] = targets_x20; targets_20[:,1] = targets_y20

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_20, xf, yf, utrue, mtrue, m_20, rel_error_20, lmbda_20, lmbda_R_20, noise_std_dev_20, kl_dist_20 ) = solveInverseProblem(k, targets_20, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 123
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    6.229204e+04    6.224050e+04    5.153536e+01   -1.013736e+06   7.455295e+04   1.000000e+00   5.000000e-01
#   2   1    2.113097e+04    2.107835e+04    5.261716e+01   -8.160298e+04   1.633178e+04   1.000000e+00   4.680415e-01
#   3   3    3.199307e+03    3.149663e+03    4.964400e+01   -3.614159e+04   2.934943e+03   1.000000e+00   1.984118e-01
#   4   5    8.982751e+02    8.491164e+02    4.915871e+01   -4.592984e+03   1.643327e+03   1.000000e+00   1.484669e-01
#   5  13    7.286529e+02    6.826572e+02    4.599564e+01   -7.760654e+02   4.276148e+02   5.000000e-01   7.573453e-02
#   6   1    6.051314e+02    5.589424e+02    4.618899e+01   -2.451129e+02   1.063771e+03   1.000000e+00   1.194515e-01
#   7  17    5.338021e+02    4.879044e+02    4.589766e+01   -2.184380e+02   2.465742e+02   5.000000e-01   5.750974e-02
#   8   4    5.147809e+02    4.688006e+02    4.598027e+01   -3.791197e+01   3.281166e+02   1.000000e+00   6.634095e-02
#   9  73    5.107078e+02    4.610096e+02    4.969814e+01   -1.512700e+02   7.134098e+01   2.500000e-01   3.093407e-02
#  10   2    4.919381e+02    4.420468e+02    4.989137e+01   -3.744682e+01   3.758887e+02   1.000000e+00   7.100636e-02
#  11  70    4.888580e+02    4.425827e+02    4.627529e+01   -7.033825e+02   6.500879e+01   7.812500e-03   2.952933e-02
#  12  43    4.820136e+02    4.342247e+02    4.778897e+01   -7.073191e+01   6.293362e+01   2.500000e-01   2.905420e-02
#  13   3    4.772190e+02    4.293101e+02    4.790884e+01   -9.578069e+00   2.051128e+02   1.000000e+00   5.245223e-02
#  14  24    4.740631e+02    4.273381e+02    4.672508e+01   -2.450380e+02   4.750265e+01   3.125000e-02   2.524216e-02
#  15  10    4.670120e+02    4.181371e+02    4.887493e+01   -1.371594e+01   8.372677e+01   1.000000e+00   3.351195e-02
#  16  42    4.629755e+02    4.124566e+02    5.051893e+01   -2.210949e+01   2.500124e+01   5.000000e-01   1.831253e-02
#  17  20    4.627914e+02    4.120811e+02    5.071027e+01   -6.995965e+02   5.229485e+01   3.906250e-03   2.648482e-02
#  18  19    4.616875e+02    4.114505e+02    5.023704e+01   -2.609180e+01   5.381916e+01   1.250000e-01   2.686804e-02
#  19  12    4.610165e+02    4.103983e+02    5.061821e+01   -4.702474e+01   5.049297e+01   6.250000e-02   2.602454e-02
#  20  22    4.599939e+02    4.102482e+02    4.974571e+01   -4.645204e+01   4.394206e+01   3.125000e-02   2.427771e-02
#  21   6    4.596239e+02    4.098055e+02    4.981841e+01   -7.381469e-01   4.255767e+01   1.000000e+00   2.389222e-02
#  22  81    4.594029e+02    4.097533e+02    4.964957e+01   -2.827836e+01   8.775213e+00   3.125000e-02   1.084917e-02
#  23  93    4.591401e+02    4.097334e+02    4.940663e+01   -1.080015e+02   8.595095e+00   3.906250e-03   1.073725e-02
#  24  84    4.591370e+02    4.096759e+02    4.946109e+01   -1.781584e+01   8.589857e+00   3.125000e-02   1.073397e-02
#  25  93    4.589736e+02    4.096556e+02    4.931803e+01   -1.079196e+02   8.462975e+00   3.906250e-03   1.065440e-02
#  26  95    4.589254e+02    4.096532e+02    4.927222e+01   -6.595690e+01   8.470688e+00   3.906250e-03   1.065926e-02
#  27  84    4.589002e+02    4.096385e+02    4.926172e+01   -5.682212e+01   8.460647e+00   3.906250e-03   1.065294e-02
#  28  94    4.588598e+02    4.096346e+02    4.922517e+01   -5.190301e+01   8.440845e+00   3.906250e-03   1.064046e-02
#  29  84    4.588177e+02    4.096218e+02    4.919593e+01   -4.062582e+01   8.422300e+00   3.906250e-03   1.062877e-02
#  30  83    4.588011e+02    4.096081e+02    4.919299e+01   -2.380459e+01   8.395773e+00   7.812500e-03   1.061202e-02
#  31  86    4.587701e+02    4.095950e+02    4.917516e+01   -4.479910e+01   8.343836e+00   3.906250e-03   1.057914e-02
#  32  85    4.587218e+02    4.095895e+02    4.913225e+01   -3.544943e+01   8.319855e+00   3.906250e-03   1.056393e-02
#  33  78    4.587126e+02    4.095501e+02    4.916256e+01   -1.516938e+01   8.294187e+00   1.562500e-02   1.054762e-02
#  34  97    4.586865e+02    4.095475e+02    4.913904e+01   -6.273928e+01   8.186205e+00   3.906250e-03   1.047874e-02
#  35  83    4.586833e+02    4.095327e+02    4.915068e+01   -6.319213e+01   8.174250e+00   3.906250e-03   1.047108e-02
#  36  92    4.586511e+02    4.095306e+02    4.912054e+01   -6.498190e+01   8.160851e+00   3.906250e-03   1.046250e-02
#  37  93    4.586470e+02    4.095158e+02    4.913124e+01   -6.349447e+01   8.151128e+00   3.906250e-03   1.045626e-02
#  38  95    4.586124e+02    4.095137e+02    4.909871e+01   -6.417504e+01   8.138126e+00   3.906250e-03   1.044792e-02
#  39  86    4.586072e+02    4.094992e+02    4.910801e+01   -6.148239e+01   8.128065e+00   3.906250e-03   1.044146e-02
#  40 100    4.585737e+02    4.094968e+02    4.907688e+01   -6.196163e+01   8.114120e+00   3.906250e-03   1.043250e-02
#  41  94    4.585665e+02    4.094826e+02    4.908385e+01   -5.892680e+01   8.102614e+00   3.906250e-03   1.042510e-02
#  42  94    4.585357e+02    4.094802e+02    4.905550e+01   -5.919318e+01   8.087676e+00   3.906250e-03   1.041548e-02
#  43  85    4.585272e+02    4.094664e+02    4.906076e+01   -5.624893e+01   8.074693e+00   3.906250e-03   1.040712e-02
#  44  93    4.584985e+02    4.094639e+02    4.903460e+01   -5.636737e+01   8.058655e+00   3.906250e-03   1.039678e-02
#  45  95    4.584875e+02    4.094504e+02    4.903710e+01   -5.322274e+01   8.044002e+00   3.906250e-03   1.038732e-02
#  46  85    4.584606e+02    4.094477e+02    4.901291e+01   -5.279891e+01   8.026570e+00   3.906250e-03   1.037606e-02
#  47  85    4.584466e+02    4.094348e+02    4.901180e+01   -4.907314e+01   8.010022e+00   3.906250e-03   1.036536e-02
#  48  86    4.584196e+02    4.094315e+02    4.898806e+01   -4.746677e+01   7.990735e+00   3.906250e-03   1.035287e-02
#  49  89    4.583971e+02    4.094195e+02    4.897765e+01   -4.151109e+01   7.971509e+00   3.906250e-03   1.034041e-02
#  50  84    4.583599e+02    4.094149e+02    4.894502e+01   -3.455688e+01   7.949143e+00   3.906250e-03   1.032590e-02
#  51  77    4.583458e+02    4.093961e+02    4.894970e+01   -1.779683e+01   7.923943e+00   7.812500e-03   1.030952e-02
#  52  88    4.583032e+02    4.093910e+02    4.891218e+01   -2.884313e+01   7.867578e+00   3.906250e-03   1.027278e-02
#  53  77    4.582724e+02    4.093574e+02    4.891503e+01   -9.484108e+00   7.840314e+00   1.562500e-02   1.025497e-02
#  54  78    4.582286e+02    4.093522e+02    4.887642e+01   -2.574610e+01   7.719997e+00   3.906250e-03   1.017598e-02
#  55  78    4.581877e+02    4.092273e+02    4.896041e+01   -6.549511e+00   7.692600e+00   6.250000e-02   1.015791e-02
#  56  97    4.580748e+02    4.092272e+02    4.884758e+01   -6.989640e+01   7.161867e+00   3.906250e-03   9.801233e-03
#  57  92    4.580655e+02    4.092161e+02    4.884941e+01   -4.213418e+01   7.162786e+00   3.906250e-03   9.801862e-03
#  58  95    4.580461e+02    4.092132e+02    4.883293e+01   -4.012249e+01   7.145137e+00   3.906250e-03   9.789778e-03
#  59  82    4.580233e+02    4.092031e+02    4.882027e+01   -3.304746e+01   7.124968e+00   3.906250e-03   9.775951e-03
#  60  86    4.579796e+02    4.091983e+02    4.878131e+01   -2.079647e+01   7.104187e+00   3.906250e-03   9.761685e-03
#  61  75    4.578287e+02    4.084428e+02    4.938588e+01   -3.228090e+00   7.076972e+00   5.000000e-01   9.742969e-03
#  62  54    4.574730e+02    4.084549e+02    4.901808e+01   -1.654067e+02   1.442591e+01   3.906250e-03   1.391039e-02
#  63  50    4.573719e+02    4.084480e+02    4.892395e+01   -9.632407e+01   1.411593e+01   1.953125e-03   1.376013e-02
#  64  36    4.573584e+02    4.084437e+02    4.891472e+01   -1.222112e+01   1.407496e+01   7.812500e-03   1.374014e-02
#  65  36    4.573379e+02    4.084358e+02    4.890213e+01   -1.012606e+01   1.395754e+01   7.812500e-03   1.368271e-02
#  66  36    4.573136e+02    4.084243e+02    4.888929e+01   -4.480307e+00   1.384423e+01   1.562500e-02   1.362705e-02
#  67  34    4.573027e+02    4.083732e+02    4.892946e+01   -2.330384e+00   1.362253e+01   6.250000e-02   1.351750e-02
#  68  49    4.572989e+02    4.083742e+02    4.892466e+01   -3.467872e+01   1.279125e+01   3.906250e-03   1.309858e-02
#  69  42    4.572938e+02    4.083684e+02    4.892541e+01   -3.284289e+01   1.273184e+01   3.906250e-03   1.306812e-02
#  70  42    4.572792e+02    4.083692e+02    4.891000e+01   -2.951739e+01   1.267708e+01   3.906250e-03   1.303999e-02
#  71  42    4.572439e+02    4.083647e+02    4.887920e+01   -1.757995e+01   1.261987e+01   3.906250e-03   1.301053e-02
#  72  20    4.571895e+02    4.076893e+02    4.950023e+01   -3.778213e-01   1.257026e+01   1.000000e+00   1.298493e-02
#  73  96    4.571350e+02    4.076870e+02    4.944806e+01   -4.495602e+01   2.090482e+00   1.953125e-03   5.295303e-03
#  74  76    4.571307e+02    4.076945e+02    4.943621e+01   -1.294070e+00   2.105446e+00   1.250000e-01   5.314221e-03
#  75  96    4.570806e+02    4.076917e+02    4.938889e+01   -5.302690e+01   1.856004e+00   1.953125e-03   4.989499e-03
#  76  78    4.570674e+02    4.076933e+02    4.937406e+01   -3.461634e+00   1.876811e+00   1.562500e-02   5.017390e-03
#  77  81    4.570560e+02    4.076928e+02    4.936315e+01   -1.725239e+00   1.827656e+00   3.125000e-02   4.951250e-03
#  78  78    4.570494e+02    4.076949e+02    4.935453e+01   -1.956138e+00   1.803647e+00   3.125000e-02   4.918621e-03
#  79  81    4.570390e+02    4.076939e+02    4.934509e+01   -3.493468e+00   1.732268e+00   1.562500e-02   4.820311e-03
#  80  78    4.570377e+02    4.076962e+02    4.934148e+01   -2.128499e+00   1.735617e+00   3.125000e-02   4.824969e-03
#  81  79    4.570122e+02    4.076952e+02    4.931700e+01   -5.644979e+00   1.665667e+00   7.812500e-03   4.726739e-03
#  82  68    4.569954e+02    4.077223e+02    4.927319e+01   -4.788738e-01   1.673785e+00   5.000000e-01   4.738244e-03
#  83  94    4.569646e+02    4.077200e+02    4.924458e+01   -2.188645e+01   1.582124e+00   3.906250e-03   4.606678e-03
#  84  68    4.569466e+02    4.077210e+02    4.922562e+01   -3.040338e+00   1.565181e+00   1.562500e-02   4.581944e-03
#  85  72    4.569406e+02    4.077185e+02    4.922211e+01   -7.013610e-01   1.551941e+00   1.250000e-01   4.562525e-03
#  86  93    4.569304e+02    4.077202e+02    4.921014e+01   -9.144981e+00   1.278666e+00   7.812500e-03   4.141391e-03
#  87  78    4.569028e+02    4.077193e+02    4.918349e+01   -4.272254e+00   1.276304e+00   7.812500e-03   4.137563e-03
#  88  70    4.569018e+02    4.077220e+02    4.917981e+01   -9.434479e-02   1.171403e+00   1.000000e+00   3.963882e-03
#  89  80    4.568561e+02    4.077359e+02    4.912019e+01   -1.700714e-01   7.076039e-01   5.000000e-01   3.080794e-03
#  90  78    4.568498e+02    4.077258e+02    4.912400e+01   -8.282653e-02   4.371008e-01   2.500000e-01   2.421355e-03
#  91  84    4.568422e+02    4.077221e+02    4.912004e+01   -8.321034e-02   4.781559e-01   2.500000e-01   2.532517e-03
#  92  76    4.568401e+02    4.077144e+02    4.912568e+01   -5.564551e-02   5.138336e-01   2.500000e-01   2.625299e-03
#  93  79    4.568365e+02    4.077131e+02    4.912337e+01   -8.669997e-02   5.339197e-01   2.500000e-01   2.676120e-03
#  94  65    4.568299e+02    4.077098e+02    4.912002e+01   -6.440304e-02   4.777294e-01   1.250000e-01   2.531387e-03
#  95  64    4.568256e+02    4.076961e+02    4.912955e+01   -8.126130e-03   2.717888e-01   1.000000e+00   1.909340e-03
#  96   6    4.568256e+02    4.076960e+02    4.912955e+01   -1.092381e-04   7.411251e-01   1.000000e+00   3.152923e-03
#  97 100    4.568254e+02    4.076974e+02    4.912803e+01   -2.218615e-04   5.254578e-02   1.000000e+00   8.395306e-04
#  98  82    4.568254e+02    4.076975e+02    4.912798e+01   -1.375691e-05   1.384776e-02   1.000000e+00   4.309803e-04
#  99 100    4.568254e+02    4.076975e+02    4.912798e+01   -2.039561e-07   1.453537e-03   1.000000e+00   1.396306e-04
# 100 100    4.568254e+02    4.076975e+02    4.912798e+01   -4.561872e-11   2.165883e-05   1.000000e+00   1.704453e-05
#
# Not Converged
# Termination reason:  Maximum number of Iteration reached
# Final gradient norm:  2.16588299454157e-05
# Final cost:  456.82543505119247
# 0.11818157932448349 0.3596070848846303
# The relative error is: 13.8 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  124.39892262541477

# %%
# Generate random surface observations
ntargets_21 = 145 
targets_x21 = np.linspace(-180., 0., ntargets_21) 
targets_y21 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_21)
targets_21 = np.zeros([ntargets_21, dim])
targets_21[:,0] = targets_x21; targets_21[:,1] = targets_y21

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_21, xf, yf, utrue, mtrue, m_21, rel_error_21, lmbda_21, lmbda_R_21, noise_std_dev_21, kl_dist_21 ) = solveInverseProblem(k, targets_21, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 145
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    7.329465e+04    7.324308e+04    5.156563e+01   -1.194835e+06   8.792377e+04   1.000000e+00   5.000000e-01
#   2   1    2.476815e+04    2.471551e+04    5.264519e+01   -9.617718e+04   1.933020e+04   1.000000e+00   4.688836e-01
#   3   3    3.875291e+03    3.825624e+03    4.966696e+01   -4.210291e+04   3.468240e+03   1.000000e+00   1.986101e-01
#   4   5    1.118167e+03    1.069050e+03    4.911658e+01   -5.497822e+03   1.912820e+03   1.000000e+00   1.474972e-01
#   5  13    8.783672e+02    8.323607e+02    4.600648e+01   -1.028867e+03   5.724582e+02   5.000000e-01   8.068982e-02
#   6   1    7.283017e+02    6.820896e+02    4.621208e+01   -2.976607e+02   1.271706e+03   1.000000e+00   1.202653e-01
#   7  17    6.274072e+02    5.807749e+02    4.663225e+01   -3.113095e+02   3.224751e+02   5.000000e-01   6.056127e-02
#   8   4    6.019583e+02    5.551204e+02    4.683787e+01   -5.044522e+01   4.161566e+02   1.000000e+00   6.879791e-02
#   9  45    5.886754e+02    5.421181e+02    4.655722e+01   -1.488577e+02   8.753939e+01   2.500000e-01   3.155358e-02
#  10   1    5.721970e+02    5.255490e+02    4.664798e+01   -3.289297e+01   4.241031e+02   1.000000e+00   6.945165e-02
#  11  33    5.693229e+02    5.235052e+02    4.581770e+01   -4.828699e+02   8.406611e+01   7.812500e-03   3.092127e-02
#  12  15    5.464092e+02    4.969093e+02    4.949991e+01   -4.413272e+01   9.903218e+01   1.000000e+00   3.356101e-02
#  13  61    5.421647e+02    4.923318e+02    4.983288e+01   -3.487654e+01   2.714656e+01   2.500000e-01   1.757132e-02
#  14   2    5.409688e+02    4.911145e+02    4.985423e+01   -2.391015e+00   1.305963e+02   1.000000e+00   3.854006e-02
#  15  26    5.390071e+02    4.898074e+02    4.919973e+01   -2.628821e+02   2.067086e+01   1.562500e-02   1.533296e-02
#  16  15    5.347495e+02    4.837899e+02    5.095960e+01   -8.108993e+00   7.565107e+01   1.000000e+00   2.933286e-02
#  17  87    5.340585e+02    4.824453e+02    5.161315e+01   -1.221888e+01   1.253775e+01   2.500000e-01   1.194144e-02
#  18  58    5.330700e+02    4.823615e+02    5.070852e+01   -2.200008e+01   1.911855e+01   1.250000e-01   1.474600e-02
#  19  31    5.322766e+02    4.813112e+02    5.096542e+01   -6.682045e+00   2.652335e+01   2.500000e-01   1.736845e-02
#  20  36    5.321136e+02    4.808445e+02    5.126906e+01   -7.890003e+00   2.712088e+01   2.500000e-01   1.756300e-02
#  21   6    5.315950e+02    4.805013e+02    5.109372e+01   -1.031998e+00   5.361118e+01   1.000000e+00   2.469304e-02
#  22  71    5.314133e+02    4.805032e+02    5.091014e+01   -4.710666e+01   4.724263e+00   3.906250e-03   7.330168e-03
#  23 100    5.311105e+02    4.804510e+02    5.065956e+01   -1.057531e+01   4.662654e+00   3.125000e-02   7.282214e-03
#  24  65    5.306565e+02    4.797006e+02    5.095591e+01   -2.217482e+00   9.583363e+00   5.000000e-01   1.044013e-02
#  25  43    5.304491e+02    4.795362e+02    5.091295e+01   -2.167350e+00   1.687057e+01   2.500000e-01   1.385197e-02
#  26   4    5.303802e+02    4.794650e+02    5.091518e+01   -1.379026e-01   3.241782e+01   1.000000e+00   1.920166e-02
#  27 100    5.303325e+02    4.794320e+02    5.090047e+01   -2.427997e+00   2.089675e+00   6.250000e-02   4.875131e-03
#  28  54    5.302944e+02    4.793655e+02    5.092891e+01   -2.000349e+00   7.770908e+00   1.250000e-01   9.401188e-03
#  29  34    5.302921e+02    4.792688e+02    5.102327e+01   -6.294818e-01   1.269172e+01   2.500000e-01   1.201454e-02
#  30  33    5.302191e+02    4.792368e+02    5.098237e+01   -1.463952e+00   1.631849e+01   1.250000e-01   1.362344e-02
#  31  18    5.301641e+02    4.788262e+02    5.133783e+01   -1.428688e-01   1.768727e+01   1.000000e+00   1.418330e-02
#  32  82    5.300355e+02    4.788553e+02    5.118025e+01   -3.418475e-01   2.242216e+00   1.000000e+00   5.049933e-03
#  33   2    5.300161e+02    4.788330e+02    5.118310e+01   -3.887279e-02   1.581279e+01   1.000000e+00   1.341069e-02
#  34  92    5.300021e+02    4.788313e+02    5.117089e+01   -1.361119e-01   1.202168e+00   1.250000e-01   3.697681e-03
#  35  85    5.299940e+02    4.788167e+02    5.117731e+01   -1.561348e-02   8.928188e-01   1.000000e+00   3.186607e-03
#  36  81    5.299931e+02    4.788154e+02    5.117763e+01   -1.602193e-03   2.125336e-01   1.000000e+00   1.554750e-03
#  37  98    5.299930e+02    4.788158e+02    5.117717e+01   -1.327440e-04   5.385455e-02   1.000000e+00   7.826328e-04
#  38 100    5.299930e+02    4.788159e+02    5.117707e+01   -9.626327e-07   6.078373e-03   1.000000e+00   2.629302e-04
#  39 100    5.299930e+02    4.788159e+02    5.117707e+01   -8.941075e-11   6.028905e-05   5.000000e-01   2.618581e-05
#  40 100    5.299930e+02    4.788159e+02    5.117707e+01   -2.236431e-11   3.024071e-05   1.000000e+00   1.854568e-05
#  41 100    5.299930e+02    4.788159e+02    5.117707e+01   -2.538890e-15   1.298997e-07   1.000000e+00   1.215489e-06
#  42 100    5.299930e+02    4.788159e+02    5.117707e+01   -1.980664e-16   6.017629e-07   1.000000e+00   2.616131e-06
#  43 100    5.299930e+02    4.788159e+02    5.117707e+01   -3.438721e-16   7.143922e-07   1.000000e+00   2.850462e-06
#  44 100    5.299930e+02    4.788159e+02    5.117707e+01   -1.047954e-16   3.223795e-07   5.000000e-01   1.914831e-06
#  45 100    5.299930e+02    4.788159e+02    5.117707e+01   -1.852937e-17   1.069842e-07   1.000000e+00   1.103079e-06
#
# Converged in  45  iterations.
# Termination reason:  Norm of the gradient less than tolerance
# Final gradient norm:  5.1063252726984185e-08
# Final cost:  529.9930088654966
# 0.05897696144982438 0.3580834962477148
# The relative error is: 15.2 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  137.8495962672077

# %%
# Generate random surface observations
ntargets_22 = 172 
targets_x22 = np.linspace(-180., 0., ntargets_22) 
targets_y22 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_22)
targets_22 = np.zeros([ntargets_22, dim])
targets_22[:,0] = targets_x22; targets_22[:,1] = targets_y22

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_22, xf, yf, utrue, mtrue, m_22, rel_error_22, lmbda_22, lmbda_R_22, noise_std_dev_22, kl_dist_22 ) = solveInverseProblem(k, targets_22, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 172
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    8.655249e+04    8.650089e+04    5.159887e+01   -1.425832e+06   1.048943e+05   1.000000e+00   5.000000e-01
#   2   1    2.947688e+04    2.942420e+04    5.267886e+01   -1.130787e+05   2.284262e+04   1.000000e+00   4.666563e-01
#   3   3    4.597521e+03    4.547873e+03    4.964818e+01   -5.014815e+04   4.200490e+03   1.000000e+00   2.001124e-01
#   4   5    1.282296e+03    1.233158e+03    4.913839e+01   -6.614987e+03   2.316383e+03   1.000000e+00   1.486036e-01
#   5  12    1.015668e+03    9.696026e+02    4.606508e+01   -1.154110e+03   6.172352e+02   5.000000e-01   7.670956e-02
#   6   1    8.464015e+02    8.001396e+02    4.626187e+01   -3.358462e+02   1.473513e+03   1.000000e+00   1.185226e-01
#   7  21    7.471838e+02    7.006977e+02    4.648607e+01   -3.540459e+02   3.483260e+02   5.000000e-01   5.762582e-02
#   8   1    7.135990e+02    6.670098e+02    4.658919e+01   -6.697732e+01   6.739285e+02   1.000000e+00   8.015508e-02
#   9  28    6.777017e+02    6.297057e+02    4.799604e+01   -1.378986e+02   1.952054e+02   5.000000e-01   4.313900e-02
#  10   1    6.622375e+02    6.141603e+02    4.807721e+01   -3.088556e+01   4.515544e+02   1.000000e+00   6.561138e-02
#  11  34    6.490480e+02    5.974264e+02    5.162160e+01   -5.671177e+01   1.186939e+02   5.000000e-01   3.363864e-02
#  12   1    6.417392e+02    5.900581e+02    5.168102e+01   -1.460720e+01   3.234312e+02   1.000000e+00   5.552839e-02
#  13  61    6.407894e+02    5.896478e+02    5.114160e+01   -7.586161e+01   4.705544e+01   3.125000e-02   2.118015e-02
#  14  17    6.350766e+02    5.794273e+02    5.564936e+01   -1.363573e+01   5.885928e+01   1.000000e+00   2.368817e-02
#  15  28    6.344174e+02    5.790680e+02    5.534938e+01   -1.411746e+01   3.839476e+01   2.500000e-01   1.913199e-02
#  16   3    6.338212e+02    5.784268e+02    5.539440e+01   -1.192246e+00   8.505562e+01   1.000000e+00   2.847578e-02
#  17 100    6.329051e+02    5.783375e+02    5.456761e+01   -3.791506e+01   8.159438e+00   3.125000e-02   8.819709e-03
#  18  53    6.321175e+02    5.776967e+02    5.442081e+01   -1.088228e+01   2.778105e+01   2.500000e-01   1.627415e-02
#  19  24    6.320845e+02    5.778557e+02    5.422880e+01   -1.150852e+01   4.716857e+01   2.500000e-01   2.120560e-02
#  20   1    6.315846e+02    5.773374e+02    5.424722e+01   -9.996671e-01   8.585289e+01   1.000000e+00   2.860893e-02
#  21 100    6.309594e+02    5.772396e+02    5.371986e+01   -2.454663e+01   6.082371e+00   6.250000e-02   7.614836e-03
#  22  24    6.304426e+02    5.770053e+02    5.343727e+01   -6.103275e+00   4.005897e+01   1.250000e-01   1.954222e-02
#  23   5    6.302924e+02    5.768028e+02    5.348955e+01   -3.003671e-01   4.311672e+01   1.000000e+00   2.027435e-02
#  24 100    6.302396e+02    5.766913e+02    5.354831e+01   -1.042636e+01   5.335484e+00   6.250000e-02   7.131995e-03
#  25  79    6.300289e+02    5.766651e+02    5.336379e+01   -1.578213e+01   1.082027e+01   6.250000e-02   1.015648e-02
#  26  24    6.296122e+02    5.764183e+02    5.319397e+01   -2.549211e+00   2.738596e+01   2.500000e-01   1.615802e-02
#  27  27    6.296010e+02    5.759402e+02    5.366084e+01   -3.576957e+00   3.348428e+01   2.500000e-01   1.786671e-02
#  28  18    6.291903e+02    5.758325e+02    5.335783e+01   -4.139319e+00   3.213210e+01   1.250000e-01   1.750224e-02
#  29   3    6.291165e+02    5.757499e+02    5.336660e+01   -1.476858e-01   3.418216e+01   1.000000e+00   1.805194e-02
#  30 100    6.288934e+02    5.756352e+02    5.325824e+01   -3.918264e+00   3.582215e+00   2.500000e-01   5.843862e-03
#  31  78    6.288810e+02    5.756650e+02    5.321597e+01   -3.093217e+01   7.834913e+00   3.125000e-02   8.642536e-03
#  32  17    6.286545e+02    5.756393e+02    5.301521e+01   -2.012793e+00   2.526355e+01   2.500000e-01   1.551927e-02
#  33  18    6.286373e+02    5.756262e+02    5.301108e+01   -5.027302e+00   3.318105e+01   6.250000e-02   1.778563e-02
#  34  17    6.285106e+02    5.755887e+02    5.292190e+01   -2.168670e+00   3.310042e+01   6.250000e-02   1.776400e-02
#  35   3    6.284455e+02    5.755156e+02    5.292991e+01   -1.303560e-01   3.177635e+01   1.000000e+00   1.740508e-02
#  36 100    6.280551e+02    5.754148e+02    5.264025e+01   -1.129662e+00   2.478667e+00   5.000000e-01   4.861085e-03
#  37   9    6.280406e+02    5.753602e+02    5.268036e+01   -2.897699e-02   1.113356e+01   1.000000e+00   1.030246e-02
#  38 100    6.280304e+02    5.752898e+02    5.274053e+01   -4.209582e-01   1.292888e+00   1.000000e+00   3.510788e-03
#  39  51    6.279175e+02    5.752330e+02    5.268445e+01   -1.034425e+00   7.017946e+00   5.000000e-01   8.179545e-03
#  40  73    6.278787e+02    5.752748e+02    5.260389e+01   -2.148034e-01   5.043426e+00   1.000000e+00   6.934050e-03
#  41  63    6.278385e+02    5.752782e+02    5.256026e+01   -4.622954e-01   2.892546e+00   2.500000e-01   5.251269e-03
#  42  50    6.278232e+02    5.752667e+02    5.255645e+01   -4.716447e-02   4.391869e+00   1.000000e+00   6.470663e-03
#  43  64    6.278170e+02    5.752646e+02    5.255245e+01   -9.127293e-02   1.527240e+00   2.500000e-01   3.815732e-03
#  44  64    6.278167e+02    5.752620e+02    5.255478e+01   -1.076725e-02   1.222414e+00   5.000000e-01   3.413762e-03
#  45  61    6.278154e+02    5.752606e+02    5.255480e+01   -2.758647e-02   9.881994e-01   5.000000e-01   3.069350e-03
#  46  59    6.278137e+02    5.752600e+02    5.255370e+01   -8.342642e-03   5.475865e-01   2.500000e-01   2.284812e-03
#  47  65    6.278135e+02    5.752575e+02    5.255595e+01   -6.910254e-04   4.254348e-01   1.000000e+00   2.013913e-03
#  48 100    6.278134e+02    5.752572e+02    5.255616e+01   -1.585749e-04   1.186128e-01   1.000000e+00   1.063384e-03
#  49 100    6.278134e+02    5.752572e+02    5.255617e+01   -1.467068e-05   2.771911e-02   1.000000e+00   5.140600e-04
#  50 100    6.278134e+02    5.752572e+02    5.255617e+01   -2.993502e-07   3.430401e-03   1.000000e+00   1.808409e-04
#  51 100    6.278134e+02    5.752572e+02    5.255617e+01   -1.417703e-10   7.265514e-05   2.500000e-01   2.631827e-05
#  52 100    6.278134e+02    5.752572e+02    5.255617e+01   -7.977147e-11   5.449062e-05   1.562500e-02   2.279213e-05
#  53 100    6.278134e+02    5.752572e+02    5.255617e+01   -7.729845e-11   5.364420e-05   9.765625e-04   2.261442e-05
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  5.364419753246063e-05
# Final cost:  627.8133760958473
# 0.17051236021591745 0.3537434939424187
# The relative error is: 13.1 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  142.83057327575406

# %%
# Generate random surface observations
ntargets_23 = 230 
targets_x23 = np.linspace(-180., 0., ntargets_23) 
targets_y23 = (ymax-dl.DOLFIN_EPS)*np.ones(ntargets_23)
targets_23 = np.zeros([ntargets_23, dim])
targets_23[:,0] = targets_x23; targets_23[:,1] = targets_y23

# Define regularization weights
eps = 1e-7 
gamma_val_TV = 1.5e-1 
gamma_val_H1 = 0.0
delta_val_L2 = 1e-3 

# Solve the inverse problem
( mesh, Vh, targets_23, xf, yf, utrue, mtrue, m_23, rel_error_23, lmbda_23, lmbda_R_23, noise_std_dev_23, kl_dist_23 ) = solveInverseProblem(k, targets_23, noise_std_dev, mtrue_expr, gamma_val_TV, gamma_val_H1, delta_val_L2, eps)
# Out:
# ################################################################################
#  Set up the mesh and finite element spaces
# ################################################################################
#
# Number of dofs: STATE=21717, PARAMETER=1246, ADJOINT=21717
# Number of STATE and ADJOINT dofs: STRESS=14544, DISPLACEMENT=4782, ROTATION=2391
# Number of observation points: 230
# The MAX displacement (m) is: 2.6328 and standard deviation of the noise (m) is: 0.002000
# Noise variance = 4e-06
#
# ################################################################################
#  Solve the deterministic inverse problem
# ################################################################################
#
#  ---
#  GN_iter (5): Number of Gauss Newton iterations before switching to Newton
#  ---
#  LS (ParameterList): Sublist containing LS globalization parameters
#      ---
#      c_armijo (1e-05): Armijo constant for sufficient reduction
#      ---
#      max_backtracking_iter (10): Maximum number of backtracking iterations
#      ---
#  ---
#  TR (ParameterList): Sublist containing TR globalization parameters
#      ---
#      eta (0.05): Reject step if (actual reduction)/(predicted reduction) < eta
#      ---
#  ---
#  abs_tolerance (1e-09): we converge when sqrt(g,g) <= abs_tolerance
#  ---
#  cg_coarse_tolerance (0.5): Coarsest tolerance for the CG method (Eisenstat-Walker)
#  ---
#  cg_max_iter (100): Maximum CG iterations
#  ---
#  gdm_tolerance (1e-18): we converge when (g,dm) <= gdm_tolerance
#  ---
#  globalization (LS): Globalization technique: line search (LS)  or trust region (TR)
#  ---
#  max_iter (100): maximum number of iterations
#  ---
#  print_level (0): Control verbosity of printing screen
#  ---
#  rel_tolerance (1e-12): we converge when sqrt(g,g)/sqrt(g_0,g_0) <= rel_tolerance
#  ---
#
# It  cg_it cost            misfit          reg             (g,dm)          ||g||L2        alpha          tolcg
#   1   1    1.156894e+05    1.156377e+05    5.162241e+01   -1.910529e+06   1.405246e+05   1.000000e+00   5.000000e-01
#   2   1    3.942701e+04    3.937430e+04    5.270605e+01   -1.510906e+05   3.066582e+04   1.000000e+00   4.671443e-01
#   3   3    6.109802e+03    6.060122e+03    4.968027e+01   -6.716500e+04   5.641428e+03   1.000000e+00   2.003634e-01
#   4   5    1.720487e+03    1.671300e+03    4.918736e+01   -8.762646e+03   3.046113e+03   1.000000e+00   1.472302e-01
#   5  12    1.352562e+03    1.306395e+03    4.616645e+01   -1.545228e+03   8.453569e+02   5.000000e-01   7.756108e-02
#   6   1    1.136125e+03    1.089765e+03    4.636025e+01   -4.294417e+02   1.923085e+03   1.000000e+00   1.169831e-01
#   7  21    1.006148e+03    9.589163e+02    4.723166e+01   -5.215842e+02   4.779661e+02   5.000000e-01   5.832065e-02
#   8   1    9.422594e+02    8.948980e+02    4.736139e+01   -1.273589e+02   1.074988e+03   1.000000e+00   8.746325e-02
#   9  33    8.832995e+02    8.332459e+02    5.005364e+01   -1.818416e+02   2.644879e+02   5.000000e-01   4.338371e-02
#  10   4    8.695865e+02    8.192297e+02    5.035677e+01   -2.742953e+01   3.733343e+02   1.000000e+00   5.154336e-02
#  11  68    8.668526e+02    8.181976e+02    4.865499e+01   -1.091080e+02   5.395661e+01   3.125000e-02   1.959504e-02
#  12  15    8.535361e+02    8.023323e+02    5.120379e+01   -2.510393e+01   1.016014e+02   1.000000e+00   2.688894e-02
#  13  21    8.432634e+02    7.899510e+02    5.331242e+01   -2.071704e+01   8.451021e+01   1.000000e+00   2.452327e-02
#  14  23    8.371997e+02    7.831841e+02    5.401555e+01   -1.239687e+01   4.419298e+01   1.000000e+00   1.773374e-02
#  15  44    8.351752e+02    7.815199e+02    5.365532e+01   -1.077669e+01   4.106148e+01   5.000000e-01   1.709390e-02
#  16   2    8.347331e+02    7.810635e+02    5.366958e+01   -8.841082e-01   1.004299e+02   1.000000e+00   2.673347e-02
#  17 100    8.345239e+02    7.811782e+02    5.334568e+01   -2.389688e+01   7.586413e+00   1.250000e-01   7.347541e-03
#  18  63    8.342957e+02    7.813040e+02    5.299171e+01   -9.467205e+02   7.090682e+01   1.953125e-03   2.246300e-02
#  19   3    8.338888e+02    7.808790e+02    5.300979e+01   -8.135974e-01   8.262852e+01   1.000000e+00   2.424872e-02
#  20 100    8.331470e+02    7.808420e+02    5.230497e+01   -1.329004e+01   6.340137e+00   6.250000e-02   6.716966e-03
#  21  55    8.328904e+02    7.804398e+02    5.245059e+01   -2.515511e+00   1.397461e+01   1.000000e+00   9.972263e-03
#  22   1    8.324916e+02    7.800292e+02    5.246247e+01   -7.973121e-01   8.923751e+01   1.000000e+00   2.519982e-02
#  23  94    8.321983e+02    7.800178e+02    5.218045e+01   -9.501190e+00   4.325092e+00   1.250000e-01   5.547809e-03
#  24  76    8.320049e+02    7.800126e+02    5.199229e+01   -2.906030e+00   6.984759e+00   1.250000e-01   7.050169e-03
#  25  63    8.319747e+02    7.800002e+02    5.197450e+01   -2.009475e+00   8.824453e+00   1.250000e-01   7.924424e-03
#  26  60    8.319464e+02    7.799982e+02    5.194818e+01   -5.502162e+00   8.021260e+00   1.562500e-02   7.555185e-03
#  27  61    8.319196e+02    7.799963e+02    5.192329e+01   -3.284640e+00   7.923854e+00   1.562500e-02   7.509172e-03
#  28  60    8.318943e+02    7.799712e+02    5.192307e+01   -4.899370e-01   7.781266e+00   2.500000e-01   7.441302e-03
#  29  65    8.318838e+02    7.799699e+02    5.191388e+01   -2.711497e+00   6.333025e+00   3.125000e-02   6.713197e-03
#  30  65    8.318826e+02    7.799693e+02    5.191332e+01   -4.194742e+00   6.116728e+00   1.562500e-02   6.597560e-03
#  31  70    8.318678e+02    7.799686e+02    5.189917e+01   -4.069689e+00   6.055962e+00   1.562500e-02   6.564707e-03
#  32  66    8.318603e+02    7.799674e+02    5.189290e+01   -1.378857e+00   5.944453e+00   3.125000e-02   6.503988e-03
#  33  63    8.318525e+02    7.799651e+02    5.188739e+01   -8.238877e-01   5.792652e+00   6.250000e-02   6.420406e-03
#  34  66    8.318386e+02    7.799640e+02    5.187455e+01   -1.012596e+00   5.430739e+00   3.125000e-02   6.216605e-03
#  35  66    8.318296e+02    7.799443e+02    5.188530e+01   -1.915348e-01   5.288857e+00   1.000000e+00   6.134860e-03
#  36  76    8.317856e+02    7.799443e+02    5.184132e+01   -8.951965e+00   2.967599e+00   7.812500e-03   4.595432e-03
#  37  74    8.317843e+02    7.799466e+02    5.183769e+01   -1.521522e-01   2.988176e+00   2.500000e-01   4.611337e-03
#  38  69    8.317769e+02    7.799469e+02    5.183000e+01   -4.064821e-01   2.292601e+00   6.250000e-02   4.039132e-03
#  39  70    8.317701e+02    7.799478e+02    5.182230e+01   -8.797436e-02   2.214753e+00   2.500000e-01   3.969963e-03
#  40  69    8.317649e+02    7.799454e+02    5.181947e+01   -3.376157e-02   1.678075e+00   5.000000e-01   3.455647e-03
#  41  69    8.317610e+02    7.799421e+02    5.181886e+01   -1.366885e-02   1.068026e+00   1.000000e+00   2.756860e-03
#  42  96    8.317585e+02    7.799422e+02    5.181632e+01   -4.894136e-03   4.319394e-01   1.000000e+00   1.753215e-03
#  43 100    8.317576e+02    7.799429e+02    5.181465e+01   -1.521281e-03   9.401810e-02   1.000000e+00   8.179552e-04
#  44 100    8.317574e+02    7.799434e+02    5.181393e+01   -3.839221e-04   3.620773e-02   1.000000e+00   5.076033e-04
#  45 100    8.317574e+02    7.799435e+02    5.181381e+01   -2.483065e-05   1.017618e-02   1.000000e+00   2.691015e-04
#  46 100    8.317574e+02    7.799436e+02    5.181381e+01   -1.310954e-07   8.653213e-04   1.000000e+00   7.847159e-05
#  47 100    8.317574e+02    7.799436e+02    5.181381e+01   -5.627441e-12   8.341422e-06   1.000000e+00   7.704489e-06
#  48 100    8.317574e+02    7.799436e+02    5.181381e+01   -8.718424e-16   5.987767e-07   2.500000e-01   2.064221e-06
#  49 100    8.317574e+02    7.799436e+02    5.181381e+01   -1.960709e-15   1.799301e-06   1.250000e-01   3.578292e-06
#  50 100    8.317574e+02    7.799436e+02    5.181381e+01   -3.450400e-16   1.545197e-07   1.250000e-01   1.048614e-06
#  51 100    8.317574e+02    7.799436e+02    5.181381e+01   -8.467551e-16   1.199245e-06   9.765625e-04   2.921310e-06
#
# Not Converged
# Termination reason:  Maximum number of backtracking reached
# Final gradient norm:  1.1992446208030679e-06
# Final cost:  831.7573577810114
# 0.11947223673170625 0.37090060698172
# The relative error is: 13.1 per cent
# Single/Double Pass Algorithm. Requested eigenvectors: 80; Oversampling 20
# KL-Distance from prior:  143.46139140458783

# %% [markdown]
# ## Combine all results for plotting

# %%
# Compute the metric LDPDH, which is the log-determinant of the pre-conditioned data misfit Hessian
lmbda_0 = 1e0
LDPDH_1 = 0.5*np.sum( np.log(1.+lmbda_1[(lmbda_1 > lmbda_0)] ) )
LDPDH_2 = 0.5*np.sum( np.log(1.+lmbda_2[(lmbda_2 > lmbda_0)] ) )
LDPDH_3 = 0.5*np.sum( np.log(1.+lmbda_3[(lmbda_3 > lmbda_0)] ) )
LDPDH_4 = 0.5*np.sum( np.log(1.+lmbda_4[(lmbda_4 > lmbda_0)] ) )
LDPDH_5 = 0.5*np.sum( np.log(1.+lmbda_5[(lmbda_5 > lmbda_0)] ) )
LDPDH_6 = 0.5*np.sum( np.log(1.+lmbda_6[(lmbda_6 > lmbda_0)] ) )
LDPDH_7 = 0.5*np.sum( np.log(1.+lmbda_7[(lmbda_7 > lmbda_0)] ) )
LDPDH_8 = 0.5*np.sum( np.log(1.+lmbda_8[(lmbda_8 > lmbda_0)] ) )
LDPDH_9 = 0.5*np.sum( np.log(1.+lmbda_9[(lmbda_9 > lmbda_0)] ) )
LDPDH_10 = 0.5*np.sum( np.log(1.+lmbda_10[(lmbda_10 > lmbda_0)] ) )
LDPDH_11 = 0.5*np.sum( np.log(1.+lmbda_11[(lmbda_11 > lmbda_0)] ) )
LDPDH_12 = 0.5*np.sum( np.log(1.+lmbda_12[(lmbda_12 > lmbda_0)] ) )
LDPDH_13 = 0.5*np.sum( np.log(1.+lmbda_13[(lmbda_13 > lmbda_0)] ) )
LDPDH_14 = 0.5*np.sum( np.log(1.+lmbda_14[(lmbda_14 > lmbda_0)] ) )
LDPDH_15 = 0.5*np.sum( np.log(1.+lmbda_15[(lmbda_15 > lmbda_0)] ) )
LDPDH_16 = 0.5*np.sum( np.log(1.+lmbda_16[(lmbda_16 > lmbda_0)] ) )
LDPDH_17 = 0.5*np.sum( np.log(1.+lmbda_17[(lmbda_17 > lmbda_0)] ) )
LDPDH_18 = 0.5*np.sum( np.log(1.+lmbda_18[(lmbda_18 > lmbda_0)] ) )
LDPDH_19 = 0.5*np.sum( np.log(1.+lmbda_19[(lmbda_19 > lmbda_0)] ) )
LDPDH_20 = 0.5*np.sum( np.log(1.+lmbda_20[(lmbda_20 > lmbda_0)] ) )
LDPDH_21 = 0.5*np.sum( np.log(1.+lmbda_21[(lmbda_21 > lmbda_0)] ) )
LDPDH_22 = 0.5*np.sum( np.log(1.+lmbda_22[(lmbda_22 > lmbda_0)] ) )
LDPDH_23 = 0.5*np.sum( np.log(1.+lmbda_23[(lmbda_23 > lmbda_0)] ) )


# Put number of observations sorted out
N_obs = np.array([ ntargets_1, ntargets_2, ntargets_3, ntargets_4, ntargets_5,
                 ntargets_6, ntargets_7, ntargets_8, ntargets_9, ntargets_10,
                 ntargets_11, ntargets_12, ntargets_13, ntargets_14, ntargets_15,
                 ntargets_16, ntargets_17, ntargets_18, ntargets_19, ntargets_20,
                 ntargets_21, ntargets_22, ntargets_23 ])

targetss = np.array([ targets_1, targets_2, targets_3, targets_4, targets_5,
                 targets_6, targets_7, targets_8, targets_9, targets_10,
                 targets_11, targets_12, targets_13, targets_14, targets_15,
                 targets_16, targets_17, targets_18, targets_19, targets_20,
                 targets_21, targets_22, targets_23 ], dtype=object)

LDPDH = np.array([ LDPDH_1, LDPDH_2, LDPDH_3, LDPDH_4, LDPDH_5,
              LDPDH_6, LDPDH_7, LDPDH_8, LDPDH_9, LDPDH_10,
              LDPDH_11, LDPDH_12, LDPDH_13, LDPDH_14, LDPDH_15,
              LDPDH_16, LDPDH_17, LDPDH_18, LDPDH_19, LDPDH_20,
              LDPDH_21, LDPDH_22, LDPDH_23 ])

ms = np.array([ m_1, m_2, m_3, m_4, m_5, 
              m_6, m_7, m_8, m_9, m_10, 
              m_11, m_12, m_13, m_14, m_15,
              m_16, m_17, m_18, m_19, m_20,
              m_21, m_22, m_23 ])

rel_errors = np.array([ rel_error_1, rel_error_2, rel_error_3, rel_error_4, rel_error_5, 
               rel_error_6, rel_error_7, rel_error_8, rel_error_9, rel_error_10,
               rel_error_11, rel_error_12, rel_error_13, rel_error_14, rel_error_15,
               rel_error_16, rel_error_17, rel_error_18, rel_error_19, rel_error_20, 
               rel_error_21, rel_error_22, rel_error_23 ])

# %% [markdown]
# ## Plot

# %%
# Exract slip magnitude to plot
V_slip = dl.FunctionSpace(mesh, "CG", 1)
slip_int = dl.interpolate(slip, V_slip).vector()
bc1 = dl.DirichletBC(V_slip, 10, boundaries, fault)
um = dl.Function(V_slip)
bc1.apply(um.vector())    
# Extract x,y coordinates of the fault and values
xslip = dl.interpolate(dl.Expression("x[0]", degree=5), V_slip)
yslip = dl.interpolate(dl.Expression("x[1]", degree=5), V_slip)
xf = xslip.vector()[um.vector() == 10] # x coordinate fault
yf = yslip.vector()[um.vector() == 10] # y coordinate fault
# Sort the values
idx = np.argsort(xf)
xf = xf[idx]; yf = yf[idx]
# Sort value of slip
slip_mag_ = slip_int[um.vector() == 10]
slip_mag = slip_mag_[idx]

# Plot slip magnitude
bounds = np.linspace(0., 10., 21)
cmap_slip = plt.cm.copper 
norm = mpl.colors.BoundaryNorm(bounds, cmap_slip.N, extend='max')
# Define fault segments to plot gradient line
fault_segments = [np.column_stack([xf[i:i+2], yf[i:i+2]]) for i in range(len(xf)-1)]

# %%
# Write routine for plotting insets
def plot_inset(mesh, m, location, marker, n_obs, targets, label_left=False, label_bottom=False, triangles=False):
    # Convert solution for plotting
    triang = tri.Triangulation(*mesh.coordinates().reshape((-1, 2)).T, triangles=mesh.cells())
    nu_m = m.compute_vertex_values(mesh)
    # Calculate remove mean
    aa = dl.Function(Vh[hp.PARAMETER])
    aa.vector()[:] = m.vector()[:] - np.mean(m.vector()[:])
    aa_m = aa.compute_vertex_values(mesh)
    # Define fault segments to plot gradient line
    fault_segments = [np.column_stack([xf[i:i+2], yf[i:i+2]]) for i in range(len(xf)-1)]

    # Make a new Axes instance [left, bottom, width, height]
    axins = ax.inset_axes(location)
    axins.set_aspect('equal')
    
    CS = axins.tricontourf(triang, nu_m, levels=levels_m, cmap=cmap_1, extend='both')
    lc = LineCollection(fault_segments, cmap=cmap_slip, array=abs(slip_mag), norm=norm, lw=3., )
    line = axins.add_collection(lc)
    axins.add_patch(Polygon(xy_triangle, facecolor="None", edgecolor="black", linestyle="--"))
    
    # Put label
    x_text, y_text = 80, -20
    x1_text, y1_text = -190, -125
    axins.plot(x_text, y_text, marker='o', mfc='antiquewhite', mec='k', ms=30)
    axins.plot(x_text, y_text, marker=marker, mfc='gray', mec='k', ms=14)
    axins.text(x1_text, y1_text, r"$N^\circ$ obs $= %d$"%(n_obs), fontsize=18)
    
    if triangles:
        axins.plot([lef, rig], [0.0, 0.0], 'k', linewidth=1.0, zorder=4)
        axins.plot(targets[:,0], targets[:,1]+3, marker="^", linestyle='None',
             markersize=6, markerfacecolor="grey", markeredgecolor="black", zorder=2)
        axins.set_xlim((lef, rig))
        axins.set_ylim((bot, topp+10.))
    else:
        axins.plot([lef, rig], [0.0, 0.0], 'k', linewidth=1.0, zorder=4)
        axins.plot(targets[:,0], targets[:,1]+3, marker="^", linestyle='None',
             markersize=6, markerfacecolor="grey", markeredgecolor="black", zorder=2)
        axins.set_xlim((lef, rig))
        axins.set_ylim((bot, topp+10.))

    axins.tick_params(axis='x', direction='out', labelsize=14)
    axins.tick_params(axis='y', direction='out', labelsize=14)
    axins.yaxis.tick_right()
    axins.yaxis.set_label_position('right')
    axins.set_xticks([-150, -100, -50, 0., 50.])
    axins.set_yticks([0, -50, -100])
    
    # Decide if plot labels inset
    if label_left:
        axins.tick_params(color='k', labelcolor='k',  
                          left=True, right=True, 
                          labelleft=False, labelright=True) 
        axins.set_ylabel('Depth [km]', fontsize=16)
    else:
        axins.tick_params(color='k', labelcolor='k', 
                          left=True, right=True,
                          labelleft=False, labelright=False)
            
    if label_bottom:
        axins.tick_params(color='k', labelcolor='k',
                          labelbottom=True) 
        axins.set_xlabel('Length [km]', fontsize=16)
    else:
        axins.tick_params(color='k', labelcolor='k',
                          labelbottom=False)

    
    return CS, line

# %%
# Plot
fig, ax = plt.subplots(1, 1, figsize=(12,9))

# Choose which to plot
choices = [0, 2, 4, 11, 17, 22] 
L, W = 0.45, 0.5
markers = ['$A$', '$B$', '$C$', '$D$', '$E$', '$F$']
cmap_5 = plt.get_cmap("RdGy_r")

# Plot
ax.plot(N_obs, LDPDH, marker='o', ls='solid', color='black', mfc='gray', mec='k')
ax.set_xlabel('$N^{o}$ obs')
ax.set_ylabel(r'$\mathrm{LDPDH}$')
ax.set_xlim((-8., 240.))
ax.set_ylim((-20., 165.)) 
ax.xaxis.set_ticks(np.arange(0, 250., 25.0))

# Define location
XX = [-0.2, 0.275, 0.75]
YY = [0.9575, 0.6075, 0.285, -0.065] 
X = [XX[0], XX[1], XX[0], XX[2], XX[1], XX[2]]
Y = [YY[0], YY[0], YY[1], YY[2], YY[3], YY[3]]

# Loop 
for i, j in enumerate(choices):
    
    ax.plot(N_obs[j], LDPDH[j], marker='o', mfc='antiquewhite', mec='k', ms=30)
    ax.plot(N_obs[j], LDPDH[j], marker=markers[i], mfc='gray', mec='k', ms=14)
    location = [X[i], Y[i], L, W]
    
    if i == 0:
        _, _ = plot_inset(mesh, ms[j], location, markers[i], N_obs[j], targetss[j], 
                          label_left=False, label_bottom=False, triangles=True)
        
    if i == 1:
        _, _ = plot_inset(mesh, ms[j], location, markers[i], N_obs[j], targetss[j], 
                          label_left=True, label_bottom=True, triangles=True)
        
    if i == 2:
        _, _ = plot_inset(mesh, ms[j], location, markers[i], N_obs[j], targetss[j], 
                          label_left=False, label_bottom=False, triangles=True)
    
    if i == 3:
        _, _ = plot_inset(mesh, ms[j], location, markers[i], N_obs[j], targetss[j], 
                          label_left=True, label_bottom=False, triangles=False)
    
    if i == 4:
        _, _ = plot_inset(mesh, ms[j], location, markers[i], N_obs[j], targetss[j], 
                              label_left=False, label_bottom=False, triangles=False)
        
    if i == 5:
        CS, line = plot_inset(mesh, ms[j], location, markers[i], N_obs[j], targetss[j], 
                          label_left=True, label_bottom=False, triangles=False)

    
# Make a new Axes instance [left, bottom, width, height]
cbar_ax = plt.gcf().add_axes([0.97, 0.8, 0.0125, 0.25])
cbar = plt.colorbar( CS, cax=cbar_ax, orientation="vertical",
                    ticks=[0.2, 0.23, 0.26, 0.29, 0.32, 0.35],
                    format="%.2f", label=r'$\mathrm{\nu}$' )
cbar.ax.tick_params(labelsize=16)
cbar.ax.yaxis.set_label_position('left')
cbar.ax.yaxis.set_ticks_position('left')


# Make a new Axes instance [left, bottom, width, height]
cbar_ax2 = plt.gcf().add_axes([1.0, 0.8, 0.0125, 0.25])
cbar2 = plt.colorbar( line, cax=cbar_ax2, orientation="vertical",
                    ticks=[0., 2., 4., 6., 8., 10.],
                    format="%d" )
cbar2.set_label(label=r'$\mathbf{s}$ [m]', size=18)
cbar2.ax.tick_params(labelsize=16)
cbar2.ax.xaxis.set_ticks_position('bottom')
cbar2.ax.xaxis.set_label_position('top')


plt.show()

# %%
# Save eigenvalues
lmbda_all = np.array([ lmbda_1, lmbda_2, lmbda_3, lmbda_4, lmbda_5, 
                       lmbda_6, lmbda_7, lmbda_8, lmbda_9, lmbda_10,
                       lmbda_11, lmbda_12, lmbda_13, lmbda_14, lmbda_15,
                       lmbda_16, lmbda_17, lmbda_18, lmbda_19, lmbda_20,
                       lmbda_21, lmbda_22, lmbda_23 ])

i_lmbda_all = np.arange(1, len(lmbda_1)+1)


# Save it as pandas dataframe
tosave = pd.DataFrame(lmbda_all.T, columns=['1', '5', '10', '17', '23', 
                                            '27', '33', '38', '43', '51', 
                                            '56', '61', '66', '73', '78', 
                                            '86', '93', '100', '113', '123', 
                                            '145', '172', '230'])
if False:
    savepath = "../Figures/"
    outFileName = 'eigenvalues_Nobs_mu_nu.txt'
    tosave.to_csv(savepath + outFileName, sep=' ', index=False)
